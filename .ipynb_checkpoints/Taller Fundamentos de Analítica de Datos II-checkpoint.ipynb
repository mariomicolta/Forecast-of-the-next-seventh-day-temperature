# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from math import sqrt
import math

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from bayes_opt import BayesianOptimization

# %%
def r2adj(y_real, y_pred, numFeatures):
    return 1 - (1-r2_score(y_real, y_pred))*(len(y_real)-1) / (len(y_real) - numFeatures - 1)

# %%
df = pd.read_csv("datos_clima.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  PresionAire (mbar)  PresionVapor (mbar)  HumedadRelativa (%)  \
# 0  01.01.2010          970.000208             4.348264            94.777778
# 1  02.01.2010          985.915486             3.793889            91.520833
# 2  03.01.2010          990.590625             4.049236            92.757639
# 3  04.01.2010          988.882014             3.467292            90.650694
# 4  05.01.2010          981.295347             2.385556            85.181528
#
#    ConcentracionVapor (mmol/mol)  DensidadAire (g/m**3)  \
# 0                       4.483333            1252.657986
# 1                       3.849444            1280.425208
# 2                       4.087569            1283.044514
# 3                       3.505417            1289.135417
# 4                       2.431111            1299.386597
#
#    DireccionViento (grado)  Temperatura (C)
# 0                64.320278        -3.863403
# 1               238.964236        -5.296667
# 2               132.256944        -4.605903
# 3               145.993472        -6.284306
# 4               165.373125       -10.286736

# %% [markdown]
# # INGENIERÍA DE CARACTERÍSTICAS

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PresionAire (mbar)', 'PresionVapor (mbar)',
#        'HumedadRelativa (%)', 'ConcentracionVapor (mmol/mol)',
#        'DensidadAire (g/m**3)', 'DireccionViento (grado)', 'Temperatura (C)'],
#       dtype='object')

# %%
colnames = ['Fecha', 'PresionAire (mbar)', 'PresionVapor (mbar)',
       'HumedadRelativa (%)', 'ConcentracionVapor (mmol/mol)',
       'DensidadAire (g/m**3)', 'DireccionViento (grado)', 'Temperatura (C)']
df.columns = colnames

# %%
df.describe(include="all").T
# Out:
#                               count unique         top freq     mean      std  \
# Fecha                          2193   2190  21.03.2014    2      NaN      NaN
# PresionAire (mbar)             2193    NaN         NaN  NaN  989.292  7.91317
# PresionVapor (mbar)            2193    NaN         NaN  NaN  9.52868  4.10651
# HumedadRelativa (%)            2193    NaN         NaN  NaN  75.8395  11.5927
# ConcentracionVapor (mmol/mol)  2193    NaN         NaN  NaN  9.63515  4.15792
# DensidadAire (g/m**3)          2193    NaN         NaN  NaN  1216.12  37.6223
# DireccionViento (grado)        2193    NaN         NaN  NaN   174.25  54.4839
# Temperatura (C)                2193    NaN         NaN  NaN  9.46232  7.86111
#
#                                    min      25%      50%      75%      max
# Fecha                              NaN      NaN      NaN      NaN      NaN
# PresionAire (mbar)             951.558  984.379  989.457  994.386   1011.2
# PresionVapor (mbar)            1.29861  6.28368  8.90917  12.2335  23.8035
# HumedadRelativa (%)            38.5029  67.5226  76.7469  84.4424      100
# ConcentracionVapor (mmol/mol)  1.28799   6.3441  8.98326  12.3573  24.1188
# DensidadAire (g/m**3)          1133.43  1188.26  1212.65  1242.08  1368.36
# DireccionViento (grado)        22.5692  141.965  187.765  211.457  279.368
# Temperatura (C)               -16.5831  3.89944  9.71771  15.3599  29.4507

# %%
fechas = df.loc[:,'Fecha']

# %%
df_ori = df.copy(deep=True)

# %%
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Fecha                          2193 non-null   object
#  1   PresionAire (mbar)             2193 non-null   float64
#  2   PresionVapor (mbar)            2193 non-null   float64
#  3   HumedadRelativa (%)            2193 non-null   float64
#  4   ConcentracionVapor (mmol/mol)  2193 non-null   float64
#  5   DensidadAire (g/m**3)          2193 non-null   float64
#  6   DireccionViento (grado)        2193 non-null   float64
#  7   Temperatura (C)                2193 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 137.2+ KB

# %% [markdown]
# # Parte 1: Modelos Shallow

# %% [markdown]
# Creación del dataset de corte transversal para SVR y Redes sencillas

# %% [markdown]
# Función para crear variables nuevas a partir de las series. Se busca el valor mínimo, máximo, promedio, media de los últimos 3 días y mínimo de los últimos 7 días según el número de "pasos" a elegir.

# %%
def split_corte_transversal(sequences, n_steps, var, label):

    X = pd.DataFrame()
    y = pd.DataFrame()
    
    for i in range(len(sequences)):
        end_ix = i + n_steps
        if end_ix > len(sequences)-1:
            break
        #seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, 7]
        seq_x = sequences[i:end_ix, :]
        minn = seq_x[:, var].min()
        maxx = seq_x[:, var].max()
        meann = seq_x[:, var].mean()
        min3Day = seq_x[3::-1, var].mean()
        min7Day = seq_x[7::-1, var].min()
        
        X = X.append({
            'min' + label : minn,
            'max' + label : maxx,
            'mean' + label : meann,
            'min3Day' + label : min3Day,
            'min7Day' + label : min7Day,
        }, ignore_index = True)
        
        y = y.append({
            'Temperatura' : sequences[end_ix, 7]
        }, ignore_index = True)

    return X, y

# %% [markdown]
# Función para generar el dataset de corte transversal a partir de las series. Se crea para facilitar la reproducción del código en distintas zonas del notebook y buscar la mejor ventana (n_steps) utilizando la optimización bayesiana

# %%
def corteTransversal(n_steps):
    presionAire, Temperatura = split_corte_transversal(df.to_numpy(), n_steps, 1, 'PresionAire')
    presionVapor, _ = split_corte_transversal(df.to_numpy(), n_steps, 2, 'PresionVapor')
    HumedadRelativa, _ = split_corte_transversal(df.to_numpy(), n_steps, 3, 'HumedadRelativa')
    ConcentracionVapor, _ = split_corte_transversal(df.to_numpy(), n_steps, 4, 'ConcentracionVapor')
    DensidadAire, _ = split_corte_transversal(df.to_numpy(), n_steps, 5, 'DensidadAire')
    DireccionViento, _ = split_corte_transversal(df.to_numpy(), n_steps, 6, 'DireccionViento')
    TemperaturaCT, _ = split_corte_transversal(df.to_numpy(), n_steps, 7, 'Temperatura')
    
    data = pd.concat([presionAire.reset_index(drop=True), 
        presionVapor, 
        HumedadRelativa, 
        ConcentracionVapor, 
        DensidadAire,
        DireccionViento,
        TemperaturaCT,
        Temperatura], axis=1)
    return data

# %% [markdown]
# Las tareas de split train/test las realizamos con la siguiente función. Hacemos suffle a la partición que se usa para entrenamiento.

# %%
def splitData(data):
    np.random.seed(1234)

    periodos_test = round(len(data) * 0.2)
    periodos_train = len(data) - periodos_test
    
    train = data.iloc[:periodos_train,:]
    test = data.iloc[periodos_train:,:]
    
    train = shuffle(train)
    
    X_train = train.iloc[:, :-1]
    X_test = test.iloc[:, :-1]
    y_train = train.iloc[:, len(df.columns) - 1]
    y_test = test.iloc[:, len(df.columns) - 1]
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# # SVR

# %% [markdown]
# Estimación y evaluación de los modelos SVR.

# %% [markdown]
# ## Model SVR sin estandarizar las variables

# %% [markdown]
# Estimación de un modelo SVR sin las variables estandarizadas.
#
# Buscamos los mejores hiperparámetros (C, gamma, tol y epsilon) para el SVR y el mejor tamaño de ventana (n_steps).
#
# Tener en cuenta que parte del pretratamiento de los datos lo hacemos dentro de las funciones, esto con el objetivo de simular un pipeline dado que el que provee scikit-learn no está integrado con BayesianOptimization.

# %%
def buildModelSVR1(C, gamma, tol, epsilon, n_steps): 
    np.random.seed(1234)  
    
    n_steps = int(round(n_steps))
    
    # Corte transversal
    data = corteTransversal(n_steps) #muy leeeento
    # Split
    X_train, y_train, X_test, y_test = splitData(data)

    #Estimación del modelo
    model = SVR(C = C, kernel = 'rbf', gamma = gamma, tol = tol, epsilon = epsilon)
    model.fit(X_train, y_train) 
    y_pred = model.predict(X_test)   
    print("Evaluando con C ({}), gamma ({}), tolerancia ({}), epsilon ({}) y una ventana de ({}).".format(C, gamma, tol, epsilon, n_steps))     
    mse = mean_squared_error(y_test, y_pred)
    rmse = math.sqrt(mse)
    return -rmse

# Establecemos los límites donde buscará optimizador
pbounds = {
    'C': (0.001, 100), 
    'gamma' : (0.001, 100),
    'tol' : (0.001, 5),
    'epsilon' : (0.001, 5),
    'n_steps' : (1, 200)
}

optimizer = BayesianOptimization(
    f = buildModelSVR1,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   |     C     |  epsilon  |   gamma   |  n_steps  |    tol    |
# -------------------------------------------------------------------------------------
# Evaluando con C (41.702783448252696), gamma (0.012437367359671318), tolerancia (0.7346326981947481), epsilon (3.601902142717348) y una ventana de (61).
# Evaluando con C (9.23476713828501), gamma (34.556727143577724), tolerancia (2.694544853282781), epsilon (0.9321147966769768) y una ventana de (80).
# Evaluando con C (41.92003224581507), gamma (20.44602052090201), tolerancia (0.1379105783964329), epsilon (3.4264122824834002) y una ventana de (176).
# Evaluando con C (39.91804495602341), gamma (0.4256865922717722), tolerancia (1.4710393186255117), epsilon (2.549472995946248) y una ventana de (58).
# |  4        | -3.853    |  39.92    |  2.549    |  0.4257   |  58.38    |  1.471    |
# Evaluando con C (30.266347422312222), gamma (0.06788944255241798), tolerancia (2.3729829334474966), epsilon (1.7527185253370048) y una ventana de (36).
# |  5        | -3.67     |  30.27    |  1.753    |  0.06789  |  35.88    |  2.373    |
# Evaluando con C (26.197957353846764), gamma (0.001), tolerancia (4.3751729626234255), epsilon (0.001) y una ventana de (11).
# |  6        | -2.355    |  26.2     |  0.001    |  0.001    |  11.14    |  4.375    |
# Evaluando con C (14.639162699147741), gamma (0.001), tolerancia (5.0), epsilon (0.001) y una ventana de (1).
# |  7        | -1.595    |  14.64    |  0.001    |  0.001    |  1.0      |  5.0      |
# Evaluando con C (7.1784623180157405), gamma (40.53209294184375), tolerancia (1.871788159282714), epsilon (3.1702913101006858) y una ventana de (1).
# Evaluando con C (2.5536498914003003), gamma (1.2523428596091006), tolerancia (0.20232014377759963), epsilon (2.717636490267994) y una ventana de (4).
# Evaluando con C (21.376207373408732), gamma (5.291627890918344), tolerancia (5.0), epsilon (0.001) y una ventana de (1).
# Evaluando con C (22.339464328530635), gamma (0.001), tolerancia (4.471349779544812), epsilon (0.001) y una ventana de (10).
# Evaluando con C (11.481094096949954), gamma (3.32142599743223), tolerancia (3.6402482224906723), epsilon (4.294339281351237) y una ventana de (2).
# Evaluando con C (19.12187708797796), gamma (0.12184648605512156), tolerancia (3.633051999915555), epsilon (3.011497558057641) y una ventana de (5).
# =====================================================================================
# Wall time: 8min 31s

# %%
optimizer.max
# Out:
# {'target': -1.5953289179379193,
#  'params': {'C': 14.639162699147741,
#   'epsilon': 0.001,
#   'gamma': 0.001,
#   'n_steps': 1.0,
#   'tol': 5.0}}

# %% [markdown]
# Con este modelo obtenemos un rmse de **1.59**
#
# A continuación, realizamos una búsqueda más local teniendo en cuenta los mejores hiperparámetros encontrados con el método de optimización bayesiana.

# %%
pbounds = {
    'C': (10, 18), 
    'gamma' : (0.0001, 1),
    'tol' : (4, 8),
    'epsilon' : (0.0001, 1),
    'n_steps' : (1, 10)
}
optimizer.set_bounds(pbounds)

# %%
optimizer.maximize(
    n_iter = 10
)
# Out:
# |   iter    |  target   |     C     |  epsilon  |   gamma   |  n_steps  |    tol    |
# -------------------------------------------------------------------------------------
# Evaluando con C (15.363740081427217), gamma (0.558733959462907), tolerancia (4.792405956339515), epsilon (0.41736307188689026) y una ventana de (2).
# Evaluando con C (16.405956549404294), gamma (0.3134928357414269), tolerancia (7.505556609184153), epsilon (0.9682647495618256) y una ventana de (7).
# Evaluando con C (17.15685330803078), gamma (0.039150877754559076), tolerancia (7.512570013717653), epsilon (0.08513570694864094) y una ventana de (3).
# Evaluando con C (10.7867746706644), gamma (0.9578937411974869), tolerancia (6.767508455801893), epsilon (0.42116551424255166) y una ventana de (6).
# Evaluando con C (12.524125048048504), gamma (0.8346422093301832), tolerancia (7.00057725977987), epsilon (0.6865322775888155) y una ventana de (1).
# Evaluando con C (13.07678487554709), gamma (0.030794175524119723), tolerancia (4.247116444112898), epsilon (0.5323458796683548) y una ventana de (2).
# Evaluando con C (12.146080773201607), gamma (0.4539576998765103), tolerancia (5.255942228459199), epsilon (0.5404459656110017) y una ventana de (10).
# Evaluando con C (11.349203169874539), gamma (0.18591563110096318), tolerancia (6.867418349401686), epsilon (0.7501646772997486) y una ventana de (5).
# Evaluando con C (14.756406136178954), gamma (0.3672100070186057), tolerancia (5.1892960163871535), epsilon (0.11630061072020491) y una ventana de (1).
# Evaluando con C (14.244032631988734), gamma (0.8820445785213239), tolerancia (6.922665862098223), epsilon (0.576726714491987) y una ventana de (9).
# Evaluando con C (10.646580467797182), gamma (0.4774309962047287), tolerancia (7.634057524836951), epsilon (0.2666237862591654) y una ventana de (7).
# Evaluando con C (16.873375567356803), gamma (0.4215472602997144), tolerancia (4.496085367153659), epsilon (0.04229136050917378) y una ventana de (10).
# Evaluando con C (11.181888529365423), gamma (0.6715258718523144), tolerancia (5.154272076669594), epsilon (0.5949809307762102) y una ventana de (1).
# Evaluando con C (11.308249194681924), gamma (0.04742475585094792), tolerancia (5.500354042755188), epsilon (0.5980634012063339) y una ventana de (2).
# Evaluando con C (14.452285327445292), gamma (0.010721673279156154), tolerancia (5.236805862906012), epsilon (0.8993613440513046) y una ventana de (10).
# =====================================================================================

# %%
optimizer.max
# Out:
# {'target': -1.5953289179379193,
#  'params': {'C': 14.639162699147741,
#   'epsilon': 0.001,
#   'gamma': 0.001,
#   'n_steps': 1.0,
#   'tol': 5.0}}

# %% [markdown]
# Seguimos obteniendo el mismo rmse (**1.59**). Guardamos esta configuración.

# %%
hiperpSVR1 = optimizer.max
hiperpSVR1
# Out:
# {'target': -1.5953289179379193,
#  'params': {'C': 14.639162699147741,
#   'epsilon': 0.001,
#   'gamma': 0.001,
#   'n_steps': 1.0,
#   'tol': 5.0}}

# %% [markdown]
# Guardamos los mejores hiperparámetros y el rmse obtenido.

# %%
resultsSVR = pd.DataFrame()

# %%
resultsSVR = resultsSVR.append(
    {
        'model': 'Normal',
        'RMSE' : optimizer.max['target'],
        'C' : optimizer.max['params']['C'],
        'epsilon' : optimizer.max['params']['epsilon'],
        'gamma' : optimizer.max['params']['gamma'],
        'tol' : optimizer.max['params']['tol'],
        'n_steps' : optimizer.max['params']['n_steps'],
    }, ignore_index = True)

resultsSVR
# Out:
#            C      RMSE  epsilon  gamma   model  n_steps  tol
# 0  14.639163 -1.595329    0.001  0.001  Normal      1.0  5.0

# %% [markdown]
# ## Model SVR con las variables estandarizadas

# %% [markdown]
# A continuación, estimamos un modelo SVR con las variables estandarizadas.
#
# Buscamos los mejores hiperparámetros (C, gamma, tol y epsilon) para el SVR y el mejor tamaño de ventana (n_steps).
#
# En este caso, estandarizamos los datos de entrenamiento y de test por separado para evitar data leakage.

# %%
def buildModelSVR2(C, gamma, tol, epsilon, n_steps): 
    np.random.seed(1234) 
    
    n_steps = int(round(n_steps))
    
    # Corte transversal
    data = corteTransversal(n_steps)
    # Split
    X_train, y_train, X_test, y_test = splitData(data)
    
    #Pretratamiento de los datos
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.fit_transform(X_test)

    #Estimación del modelo
    model = SVR(C = C, kernel = 'rbf', gamma = gamma, tol = tol, epsilon = epsilon)
    model.fit(X_train_std, y_train)  
    y_pred = model.predict(X_test_std)   
    print("Evaluando con C ({}), gamma ({}), tolerancia ({}), epsilon ({}) y una ventana de ({}).".format(C, gamma, tol, epsilon, n_steps))     
    mse = mean_squared_error(y_test, y_pred)
    rmse = math.sqrt(mse)
    print('RMSE {}'.format(rmse))
    return -rmse

# Establecemos los límites donde buscará optimizador
pbounds = {
    'C': (0.001, 100), 
    'gamma' : (0.001, 100),
    'tol' : (0.001, 5),
    'epsilon' : (0.001, 5),
    'n_steps' : (1, 200)
}

optimizer = BayesianOptimization(
    f = buildModelSVR2,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   |     C     |  epsilon  |   gamma   |  n_steps  |    tol    |
# -------------------------------------------------------------------------------------
# Evaluando con C (41.702783448252696), gamma (0.012437367359671318), tolerancia (0.7346326981947481), epsilon (3.601902142717348) y una ventana de (61).
# RMSE 1.7780550875872527
# Evaluando con C (9.23476713828501), gamma (34.556727143577724), tolerancia (2.694544853282781), epsilon (0.9321147966769768) y una ventana de (80).
# RMSE 3.9399436505700427
# Evaluando con C (41.92003224581507), gamma (20.44602052090201), tolerancia (0.1379105783964329), epsilon (3.4264122824834002) y una ventana de (176).
# RMSE 4.018323880165401
# Evaluando con C (39.91804495602341), gamma (0.4256865922717722), tolerancia (1.4710393186255117), epsilon (2.549472995946248) y una ventana de (58).
# RMSE 3.794225058196921
# Evaluando con C (29.99056338757198), gamma (58.614189330878276), tolerancia (2.371513729097623), epsilon (2.2928551371511277) y una ventana de (149).
# RMSE 4.147317372195071
# Evaluando con C (73.6181441489338), gamma (9.587349234104765), tolerancia (3.2597309508043053), epsilon (3.452611222151067) y una ventana de (135).
# RMSE 4.318566848660619
# Evaluando con C (38.848365546733085), gamma (84.87686925345423), tolerancia (1.0977131794996087), epsilon (4.628835277676865) y una ventana de (118).
# RMSE 4.3031008809578974
# Evaluando con C (8.090870853393499), gamma (80.12833119344472), tolerancia (3.7803145927300412), epsilon (4.249988848382318) y una ventana de (138).
# RMSE 4.2614534310980305
# Evaluando con C (41.3170658915281), gamma (3.376030566250281), tolerancia (4.879837222651127), epsilon (3.854223691750705) y una ventana de (62).
# RMSE 3.8719694918288114
# Evaluando con C (42.923165639000715), gamma (5.501112929933004), tolerancia (0.828498283051958), epsilon (1.8212080800353847) y una ventana de (57).
# RMSE 3.8558736541791347
# Evaluando con C (37.96661979194228), gamma (2.802034455983573), tolerancia (1.5449695087478643), epsilon (4.247372314858076) y una ventana de (69).
# RMSE 3.8908698251943568
# Evaluando con C (44.58954038426174), gamma (1.5184201811836555), tolerancia (1.462770782463388), epsilon (2.642530142079735) y una ventana de (58).
# RMSE 3.855002925342386
# Evaluando con C (40.42574582027159), gamma (1.028685184488653), tolerancia (4.1096769676864815), epsilon (1.3135977243162555) y una ventana de (58).
# RMSE 3.855673013653741
# =====================================================================================
# Wall time: 8min 10s

# %%
optimizer.max
# Out:
# {'target': -1.7780550875872527,
#  'params': {'C': 41.702783448252696,
#   'epsilon': 3.601902142717348,
#   'gamma': 0.012437367359671318,
#   'n_steps': 61.16418195373611,
#   'tol': 0.7346326981947481}}

# %% [markdown]
# El rmse para este modelo es de **1.77**, siendo un poco mayor (1.59) que el del modelo entrenado sin estandarizar las variables. Procedemos a tratar de encontrar mejores hiperparámetros.

# %%
pbounds = {
    'C': (35, 45), 
    'gamma' : (0.01, 1),
    'tol' : (0.1, 1),
    'epsilon' : (2, 5),
    'n_steps' : (50, 70)
}
optimizer.set_bounds(pbounds)

# %%
optimizer.maximize(
    n_iter = 10
)
# Out:
# |   iter    |  target   |     C     |  epsilon  |   gamma   |  n_steps  |    tol    |
# -------------------------------------------------------------------------------------
# Evaluando con C (41.70467510178402), gamma (0.5631029301612941), tolerancia (0.2782913401763909), epsilon (3.251914407101381) y una ventana de (53).
# RMSE 3.771768115676592
# Evaluando con C (43.00744568675537), gamma (0.3202899363776504), tolerancia (0.8887502370664345), epsilon (4.904784727158193) y una ventana de (64).
# RMSE 3.8172968585118237
# Evaluando con C (43.94606663503848), gamma (0.04866423540055354), tolerancia (0.8903282530864718), epsilon (2.2551326341093336) y una ventana de (53).
# RMSE 1.5004997218259997
# |  16       | -1.5      |  43.95    |  2.255    |  0.04866  |  53.4     |  0.8903   |
# Evaluando con C (35.9834683383305), gamma (0.9583106348489969), tolerancia (0.722689402555426), epsilon (3.2633228750151564) y una ventana de (61).
# RMSE 3.8708471492186685
# Evaluando con C (38.15515631006063), gamma (0.8362794151783992), tolerancia (0.7751298834504707), epsilon (4.059502783044751) y una ventana de (50).
# RMSE 3.763350444774944
# Evaluando con C (44.88861088906495), gamma (0.28763955214376113), tolerancia (0.1929034059198778), epsilon (4.244496963139518) y una ventana de (66).
# RMSE 3.7791314162963885
# Evaluando con C (39.47893526175905), gamma (0.30067800688994273), tolerancia (0.2170257149064499), epsilon (4.725786509279287) y una ventana de (56).
# RMSE 3.7092703268716027
# Evaluando con C (35.19366957870297), gamma (0.21951183484005846), tolerancia (0.5424158433523045), epsilon (4.036506598819673) y una ventana de (55).
# RMSE 3.5209144673878954
# Evaluando con C (35.533625451170806), gamma (0.15526128915675205), tolerancia (0.729782524018838), epsilon (3.722352816476039) y una ventana de (62).
# RMSE 3.3372457995371656
# Evaluando con C (36.02334428827826), gamma (0.6974561561504676), tolerancia (0.14495811305147846), epsilon (3.242167963458705) y una ventana de (58).
# RMSE 3.846853220220804
# Evaluando con C (38.84598109443387), gamma (0.040390272796158144), tolerancia (0.1556011999254019), epsilon (3.596897328737938) y una ventana de (53).
# RMSE 1.8625024488922524
# Evaluando con C (37.68260096650201), gamma (0.4593640592836736), tolerancia (0.3825870014033199), epsilon (3.6212000168346887) y una ventana de (70).
# RMSE 3.886645439075026
# Evaluando con C (36.686503962343174), gamma (0.1939758723771913), tolerancia (0.7451691286153793), epsilon (4.2504190738066265) y una ventana de (60).
# RMSE 3.5686532250273943
# Evaluando con C (41.657676269625746), gamma (0.4271267353781117), tolerancia (0.39123837043022547), epsilon (3.5758051903908314) y una ventana de (61).
# RMSE 3.838318066871974
# Evaluando con C (40.30504078998592), gamma (0.8832124539815088), tolerancia (0.7575998189721003), epsilon (3.73005314879084) y una ventana de (67).
# RMSE 3.895793519963601
# Evaluando con C (35.808225584746474), gamma (0.4826049467373551), tolerancia (0.9176629430883141), epsilon (2.7996513239098872) y una ventana de (63).
# RMSE 3.8577495778068527
# Evaluando con C (43.591719459196), gamma (0.4272745151482321), tolerancia (0.21161920760957348), epsilon (2.1265867402015415) y una ventana de (69).
# RMSE 3.8833423567023186
# Evaluando con C (36.477360661706776), gamma (0.6747780909428855), tolerancia (0.3597112172506586), epsilon (3.784821274456076) y una ventana de (51).
# RMSE 3.767137422546132
# Evaluando con C (36.635311493352404), gamma (0.056856193911829625), tolerancia (0.43757965961991707), epsilon (3.7940696105800598) y una ventana de (51).
# RMSE 2.249607356127785
# Evaluando con C (40.565356659306616), gamma (0.020516508197184313), tolerancia (0.37828131915385266), epsilon (4.6980538375376675) y una ventana de (69).
# RMSE 2.25312804943595
# =====================================================================================

# %%
optimizer.max
# Out:
# {'target': -1.5004997218259997,
#  'params': {'C': 43.94606663503848,
#   'epsilon': 2.2551326341093336,
#   'gamma': 0.04866423540055354,
#   'n_steps': 53.39660839129138,
#   'tol': 0.8903282530864718}}

# %% [markdown]
# Después de la búsqueda local, obtenemos un rmse de **1.50**, siendo más bajo que el anterior (antes de la búsqueda local) y que el del modelo sin las variables estandarizadas. Procedemos a guardar la configuración.

# %%
hiperpSVR2 = optimizer.max
hiperpSVR2
# Out:
# {'target': -1.5004997218259997,
#  'params': {'C': 43.94606663503848,
#   'epsilon': 2.2551326341093336,
#   'gamma': 0.04866423540055354,
#   'n_steps': 53.39660839129138,
#   'tol': 0.8903282530864718}}

# %%
resultsSVR = resultsSVR.append(
    {
        'model': 'Estandarizado',
        'RMSE' : optimizer.max['target'],
        'C' : optimizer.max['params']['C'],
        'epsilon' : optimizer.max['params']['epsilon'],
        'gamma' : optimizer.max['params']['gamma'],
        'tol' : optimizer.max['params']['tol'],
        'n_steps' : optimizer.max['params']['n_steps'],
    }, ignore_index = True)
resultsSVR
# Out:
#            C      RMSE   epsilon     gamma          model    n_steps       tol
# 0  14.639163 -1.595329  0.001000  0.001000         Normal   1.000000  5.000000
# 1  43.946067 -1.500500  2.255133  0.048664  Estandarizado  53.396608  0.890328

# %% [markdown]
# ## Model SVR #3 - PCA

# %% [markdown]
# Al ser el número de componentes un hiperparámetro, utilizamos la optimización bayesiana para encontrar el mejor valor para éste.

# %%
def buildModelSVR3(C, gamma, tol, epsilon, n_steps, n_componentes):
    
    np.random.seed(1234)
    
    n_steps = int(round(n_steps))
    n_componentes = int(round(n_componentes))
    
    # Corte transversal
    data = corteTransversal(n_steps)
    # Split
    X_train, y_train, X_test, y_test = splitData(data)
    
    # Pretratamiento de los datos
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.fit_transform(X_test)
    
    # PCA
    pca = PCA(n_componentes)
    pca2 = PCA(n_componentes)
    X_train_PCA = pca.fit_transform(X_train_std)
    X_test_PCA = pca2.fit_transform(X_test_std)
    
    # Estimación del modelo
    model = SVR(C = C, kernel = 'rbf', gamma = gamma, tol = tol, epsilon = epsilon)
    model.fit(X_train_PCA, y_train)  
    y_pred = model.predict(X_test_PCA)   
    print("Evaluando con C ({}), gamma ({}), tolerancia ({}), epsilon ({}) y una ventana de ({}).".format(C, gamma, tol, epsilon, n_steps))     
    mse = mean_squared_error(y_test, y_pred)
    rmse = math.sqrt(mse)
    return -rmse

# Establecemos los límites donde buscará opt
pbounds = {
    'C': (0.001, 100), 
    'gamma' : (0.001, 100),
    'tol' : (0.001, 5),
    'epsilon' : (0.001, 5),
    'n_steps' : (1, 200),
    'n_componentes' : (1, 30)
}

optimizer = BayesianOptimization(
    f = buildModelSVR3,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   |     C     |  epsilon  |   gamma   | n_comp... |  n_steps  |    tol    |
# -------------------------------------------------------------------------------------------------
# Evaluando con C (41.702783448252696), gamma (0.012437367359671318), tolerancia (0.4626006352492202), epsilon (3.601902142717348) y una ventana de (30).
# Evaluando con C (18.626834877555712), gamma (39.67735065559276), tolerancia (3.4264122824834002), epsilon (1.7284580744881954) y una ventana de (84).
# |  2        | -3.911    |  18.63    |  1.728    |  39.68    |  16.63    |  84.42    |  3.426    |
# Evaluando con C (20.44602052090201), gamma (2.739731932199418), tolerancia (2.793890452400312), epsilon (4.390709064518336) y una ventana de (84).
# |  3        | -3.888    |  20.45    |  4.391    |  2.74     |  20.44    |  84.04    |  2.794    |
# Evaluando con C (13.930977831201352), gamma (42.444322186495285), tolerancia (0.5146800628069474), epsilon (1.886709220769921) y una ventana de (85).
# Evaluando con C (17.84535264226609), gamma (13.211294445418945), tolerancia (5.0), epsilon (3.0372120848914412) y una ventana de (142).
# Evaluando con C (60.2095671224054), gamma (85.27906772339114), tolerancia (5.0), epsilon (5.0) y una ventana de (126).
# Evaluando con C (77.6559545018825), gamma (12.656798688017512), tolerancia (0.001), epsilon (5.0) y una ventana de (129).
# Evaluando con C (100.0), gamma (45.49631299745204), tolerancia (3.115110687217511), epsilon (4.95991177691458) y una ventana de (197).
# |  8        | -3.797    |  100.0    |  4.96     |  45.5     |  1.0      |  197.3    |  3.115    |
# Evaluando con C (19.24132224530351), gamma (5.161827668562128), tolerancia (4.9655817360326155), epsilon (2.722250013141581) y una ventana de (89).
# Evaluando con C (83.52876346168837), gamma (0.001), tolerancia (0.001), epsilon (0.001) y una ventana de (200).
# Evaluando con C (100.0), gamma (90.39417547989541), tolerancia (5.0), epsilon (5.0) y una ventana de (183).
# Evaluando con C (6.798617628854036), gamma (69.12650500784216), tolerancia (5.0), epsilon (5.0) y una ventana de (143).
# Evaluando con C (100.0), gamma (56.208314527898985), tolerancia (5.0), epsilon (5.0) y una ventana de (141).
# =================================================================================================
# Wall time: 8min 4s

# %%
optimizer.max
# Out:
# {'target': -3.7970469272180902,
#  'params': {'C': 100.0,
#   'epsilon': 4.95991177691458,
#   'gamma': 45.49631299745204,
#   'n_componentes': 1.0,
#   'n_steps': 197.3355944854622,
#   'tol': 3.115110687217511}}

# %% [markdown]
# El RMSE obtenido con este modelo haciendo uso de la estandarización y PCA (**3.79**) es mayor que el menor obtenido hasta ahora (1.50). Guardamos los parámetros.

# %%
hiperpSVR3 = optimizer.max
hiperpSVR3
# Out:
# {'target': -3.7970469272180902,
#  'params': {'C': 100.0,
#   'epsilon': 4.95991177691458,
#   'gamma': 45.49631299745204,
#   'n_componentes': 1.0,
#   'n_steps': 197.3355944854622,
#   'tol': 3.115110687217511}}

# %%
resultsSVR = resultsSVR.append(
    {
        'model' : 'PCA',
        'RMSE' : optimizer.max['target'],
        'C' : optimizer.max['params']['C'],
        'epsilon' : optimizer.max['params']['epsilon'],
        'gamma' : optimizer.max['params']['gamma'],
        'tol' : optimizer.max['params']['tol'],
        'n_steps' : optimizer.max['params']['n_steps'],
    }, ignore_index = True)

# %%
resultsSVR
# Out:
#             C      RMSE   epsilon      gamma          model     n_steps  \
# 0   14.639163 -1.595329  0.001000   0.001000         Normal    1.000000
# 1   43.946067 -1.500500  2.255133   0.048664  Estandarizado   53.396608
# 2  100.000000 -3.797047  4.959912  45.496313            PCA  197.335594
#
#         tol
# 0  5.000000
# 1  0.890328
# 2  3.115111

# %% [markdown]
# ## Model SVR #4 - Lasso

# %%
from sklearn.linear_model import Ridge, Lasso

# %% [markdown]
# Construimos el modelo SVR aplicando Lasso. Buscamos los mejores hiperparámetros para el modelo SVR al igual que Lasso (max_iter, tol_lasso, alpha_lasso). Internamente seleccionamos las variables que sean distintas de 0.

# %%
def buildModelSVR4(C, gamma, tol, epsilon, n_steps, tol_lasso, alpha_lasso, max_iter):
    
    np.random.seed(1234)
    
    n_steps = int(round(n_steps))
    max_iter = int(round(max_iter))
  
    # Corte transversal
    data = corteTransversal(n_steps)
    
    # Split
    X_train, y_train, X_test, y_test = splitData(data)
    
    # Pretratamiento de los datos
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.fit_transform(X_test)
    
    lasso = Lasso(fit_intercept = True, normalize = False,  max_iter = max_iter, tol = tol_lasso, alpha = alpha_lasso)
    lasso.fit(X_train, y_train)
    
    # Buscamos las diferentes de cero
    significativas = lasso.coef_ != 0
    
    # Descartamos las diferentes de cero
    X_train_lasso = X_train.values[:,significativas]
    X_test_lasso = X_test.values[:,significativas]

    model = SVR(C = C, kernel = 'rbf', gamma = gamma, tol = tol, epsilon = epsilon)
    model.fit(X_train_lasso, y_train)  
    y_pred = model.predict(X_test_lasso)   
    print("Evaluando con C ({}), gamma ({}), tolerancia ({}), epsilon ({}) y una ventana de ({}).".format(C, gamma, tol, epsilon, n_steps))     
    mse = mean_squared_error(y_test, y_pred)
    rmse = math.sqrt(mse)
    return -rmse

# Establecemos los límites donde buscará opt
pbounds = {
    'C': (0.001, 100), 
    'gamma' : (0.001, 100),
    'tol' : (0.001, 5),
    'epsilon' : (0.001, 5),
    'n_steps' : (1, 200),
    'tol_lasso': (0.001, 1), 
    'alpha_lasso' : (-2, 2),
    'max_iter' : (1, 1000), 
}

optimizer = BayesianOptimization(
    f = buildModelSVR4,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   |     C     | alpha_... |  epsilon  |   gamma   | max_iter  |  n_steps  |    tol    | tol_lasso |
# -------------------------------------------------------------------------------------------------------------------------
# |  11       | -3.623    |  45.05    | -0.8575   |  0.9742   |  24.33    |  144.4    |  16.15    |  0.2506   |  0.5144   |
# =========================================================================================================================
# Wall time: 8min 22s

# %%
optimizer.max
# Out:
# {'target': -3.6225590058313877,
#  'params': {'C': 45.05088207712093,
#   'alpha_lasso': -0.8575356523175901,
#   'epsilon': 0.9742437343771132,
#   'gamma': 24.333794470537693,
#   'max_iter': 144.35703998001796,
#   'n_steps': 16.150887554913258,
#   'tol': 0.25057292718571933,
#   'tol_lasso': 0.5143668604694723}}

# %% [markdown]
# El RMSE obtenido es mayor que el menor obtenido hasta ahora. Procedemos a realizar búsquedas locales.

# %%
pbounds = {
    'C': (40, 50), 
    'gamma' : (20, 28),
    'tol' : (0.20, 0.30),
    'epsilon' : (0.8, 1.5),
    'n_steps' : (10, 20),
    'tol_lasso': (0.4, 1), 
    'alpha_lasso' : (-1, 1),
    'max_iter' : (100, 200), 
}
optimizer.set_bounds(pbounds)

# %%
optimizer.maximize(
    n_iter = 10
)
# Out:
# |   iter    |  target   |     C     | alpha_... |  epsilon  |   gamma   | max_iter  |  n_steps  |    tol    | tol_lasso |
# -------------------------------------------------------------------------------------------------------------------------
# |  16       | -3.612    |  49.89    |  0.4963   |  0.9963   |  26.31    |  110.3    |  14.48    |  0.2909   |  0.5762   |
# |  17       | -3.603    |  42.88    | -0.7399   |  0.8136   |  25.43    |  121.2    |  12.66    |  0.2492   |  0.432    |
# |  19       | -3.583    |  50.0     | -1.0      |  0.8      |  20.0     |  200.0    |  10.0     |  0.2      |  1.0      |
# |  23       | -3.583    |  50.0     | -1.0      |  0.8      |  20.0     |  187.0    |  10.0     |  0.3      |  0.4      |
# =========================================================================================================================

# %%
optimizer.max
# Out:
# {'target': -3.5833677009880587,
#  'params': {'C': 50.0,
#   'alpha_lasso': -1.0,
#   'epsilon': 0.8,
#   'gamma': 20.0,
#   'max_iter': 187.02287388638072,
#   'n_steps': 10.0,
#   'tol': 0.3,
#   'tol_lasso': 0.4}}

# %% [markdown]
# El RMSE obtenido con la búsqueda local sigue siendo más alto que el menor obtenido hasta ahora (Modelo solo con estandarización).

# %%
hiperpSVR4 = optimizer.max

# %%
resultsSVR = resultsSVR.append(
    {
        'model' : 'LASSO',
        'RMSE' : optimizer.max['target'],
        'C' : optimizer.max['params']['C'],
        'epsilon' : optimizer.max['params']['epsilon'],
        'gamma' : optimizer.max['params']['gamma'],
        'tol' : optimizer.max['params']['tol'],
        'n_steps' : optimizer.max['params']['n_steps'],
    }, ignore_index = True)

# %%
resultsSVR
# Out:
#             C      RMSE   epsilon      gamma          model     n_steps  \
# 0   14.639163 -1.595329  0.001000   0.001000         Normal    1.000000
# 1   43.946067 -1.500500  2.255133   0.048664  Estandarizado   53.396608
# 2  100.000000 -3.797047  4.959912  45.496313            PCA  197.335594
# 3   50.000000 -3.583368  0.800000  20.000000          LASSO   10.000000
#
#         tol
# 0  5.000000
# 1  0.890328
# 2  3.115111
# 3  0.300000

# %% [markdown]
# # Redes neuronales artificiales tradicionales

# %% [markdown]
# Para crear la red neuronal artificial tradicional vamos a utilizar tensorflow 2x y no scikit-learn para poder aprovechar la potencia de la GPU y obtener menores tiempos de entrenamiento.

# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow.keras as keras
print(keras.__version__)
from tensorflow.keras import models, layers
# Out:
# 2.1.0
# 2.2.4-tf

# %% [markdown]
# Creamos una red neuronal con 2 capas ocultas y buscamos la mejor cantidad de neuronas para cada una. Así mismo, buscamos las épocas, el tamaño del batch y el tamaño de la ventana. En este caso se entrena la red con las variables estandarizadas.

# %%
def buildModelNN(hidden1, hidden2, epochs, batch_size, n_steps):
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)
    np.random.seed(1234) 

    hidden1 = int(round(hidden1))
    hidden2 = int(round(hidden2))
    epochs = int(round(epochs))
    batch_size = int(round(batch_size))
    n_steps = int(round(n_steps))
    
    # Corte transversal
    data = corteTransversal(n_steps)
    # Split
    X_train, y_train, X_test, y_test = splitData(data)
    
    #Pretratamiento de los datos
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.fit_transform(X_test)

    modelNN = models.Sequential()
    modelNN.add(layers.Dense(units = hidden1, activation = 'relu', input_shape = (len(data.columns)-1,)))
    modelNN.add(layers.Dense(units = hidden2, activation = 'relu'))
    modelNN.add(layers.Dense(units = 1, activation = 'linear'))
    
    modelNN.compile(optimizer = 'adam', loss = 'mse', metrics = [tf.keras.metrics.RootMeanSquaredError()])
    
    history = modelNN.fit(X_train, y_train, epochs = epochs, batch_size = batch_size, validation_split=0.1, verbose = 1)    
    y_pred = modelNN.predict(X_test)
    
    #print("RMSE:", sqrt(mean_squared_error(y_test, y_pred)), 
    #  ", MAE:", mean_absolute_error(y_test, y_pred), 
    #  ", R2:", r2_score(y_test, y_pred), "\n")
    
    rmse = sqrt(mean_squared_error(y_test, y_pred))
    #mse = mean_squared_error(y_test, y_pred)
    
    return -rmse

# Establecemos los límites donde buscará opt
pbounds = {
    'hidden1': (2, 1000), 
    'hidden2' : (2, 1000),
    'epochs' : (1, 100),
    'batch_size' : (1, len(df_ori)),
    'n_steps' : (1, 200)
}

optimizer = BayesianOptimization(
    f = buildModelNN,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   | batch_... |  epochs   |  hidden1  |  hidden2  |  n_steps  |
# -------------------------------------------------------------------------------------
# Train on 1557 samples, validate on 173 samples
# Epoch 1/72
# 1557/1557 [==============================] - 2s 1ms/sample - loss: 117.4019 - root_mean_squared_error: 10.8352 - val_loss: 22.1830 - val_root_mean_squared_error: 4.7099
# Epoch 2/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 37.0395 - root_mean_squared_error: 6.0860 - val_loss: 75.8473 - val_root_mean_squared_error: 8.7090
# Epoch 3/72
# 1557/1557 [==============================] - 0s 12us/sample - loss: 65.4136 - root_mean_squared_error: 8.0879 - val_loss: 33.6013 - val_root_mean_squared_error: 5.7967
# Epoch 4/72
# 1557/1557 [==============================] - 0s 12us/sample - loss: 25.7964 - root_mean_squared_error: 5.0790 - val_loss: 15.8634 - val_root_mean_squared_error: 3.9829
# Epoch 5/72
# 1557/1557 [==============================] - 0s 13us/sample - loss: 19.1900 - root_mean_squared_error: 4.3806 - val_loss: 29.9060 - val_root_mean_squared_error: 5.4686
# Epoch 6/72
# 1557/1557 [==============================] - 0s 12us/sample - loss: 33.1552 - root_mean_squared_error: 5.7581 - val_loss: 32.3442 - val_root_mean_squared_error: 5.6872
# Epoch 7/72
# 1557/1557 [==============================] - 0s 12us/sample - loss: 31.8080 - root_mean_squared_error: 5.6399 - val_loss: 21.2731 - val_root_mean_squared_error: 4.6123
# Epoch 8/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 20.2542 - root_mean_squared_error: 4.5005 - val_loss: 15.1078 - val_root_mean_squared_error: 3.8869
# Epoch 9/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 15.4453 - root_mean_squared_error: 3.9300 - val_loss: 19.7270 - val_root_mean_squared_error: 4.4415
# Epoch 10/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 19.7610 - root_mean_squared_error: 4.4453 - val_loss: 23.5295 - val_root_mean_squared_error: 4.8507
# Epoch 11/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 21.7521 - root_mean_squared_error: 4.6639 - val_loss: 19.9187 - val_root_mean_squared_error: 4.4630
# Epoch 12/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 17.8834 - root_mean_squared_error: 4.2289 - val_loss: 15.4902 - val_root_mean_squared_error: 3.9358
# Epoch 13/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.9096 - root_mean_squared_error: 3.8613 - val_loss: 15.2661 - val_root_mean_squared_error: 3.9072
# Epoch 14/72
# 1557/1557 [==============================] - 0s 12us/sample - loss: 15.8383 - root_mean_squared_error: 3.9797 - val_loss: 16.7869 - val_root_mean_squared_error: 4.0972
# Epoch 15/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 17.3703 - root_mean_squared_error: 4.1678 - val_loss: 16.7044 - val_root_mean_squared_error: 4.0871
# Epoch 16/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 16.8073 - root_mean_squared_error: 4.0997 - val_loss: 15.2743 - val_root_mean_squared_error: 3.9082
# Epoch 17/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 15.2236 - root_mean_squared_error: 3.9017 - val_loss: 14.7269 - val_root_mean_squared_error: 3.8376
# Epoch 18/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.5577 - root_mean_squared_error: 3.8154 - val_loss: 15.5711 - val_root_mean_squared_error: 3.9460
# Epoch 19/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 15.2107 - root_mean_squared_error: 3.9001 - val_loss: 16.1644 - val_root_mean_squared_error: 4.0205
# Epoch 20/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 15.4805 - root_mean_squared_error: 3.9345 - val_loss: 15.5465 - val_root_mean_squared_error: 3.9429
# Epoch 21/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.9088 - root_mean_squared_error: 3.8612 - val_loss: 14.6698 - val_root_mean_squared_error: 3.8301
# Epoch 22/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.3854 - root_mean_squared_error: 3.7928 - val_loss: 14.4767 - val_root_mean_squared_error: 3.8048
# Epoch 23/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.4958 - root_mean_squared_error: 3.8073 - val_loss: 14.6011 - val_root_mean_squared_error: 3.8211
# Epoch 24/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.6468 - root_mean_squared_error: 3.8271 - val_loss: 14.5059 - val_root_mean_squared_error: 3.8087
# Epoch 25/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.4892 - root_mean_squared_error: 3.8065 - val_loss: 14.3248 - val_root_mean_squared_error: 3.7848
# Epoch 26/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.1894 - root_mean_squared_error: 3.7669 - val_loss: 14.3412 - val_root_mean_squared_error: 3.7870
# Epoch 27/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.1604 - root_mean_squared_error: 3.7630 - val_loss: 14.5138 - val_root_mean_squared_error: 3.8097
# Epoch 28/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.2059 - root_mean_squared_error: 3.7691 - val_loss: 14.5076 - val_root_mean_squared_error: 3.8089
# Epoch 29/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.1649 - root_mean_squared_error: 3.7636 - val_loss: 14.2934 - val_root_mean_squared_error: 3.7807
# Epoch 30/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 14.0185 - root_mean_squared_error: 3.7441 - val_loss: 14.1115 - val_root_mean_squared_error: 3.7565
# Epoch 31/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.9286 - root_mean_squared_error: 3.7321 - val_loss: 14.0295 - val_root_mean_squared_error: 3.7456
# Epoch 32/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.9397 - root_mean_squared_error: 3.7336 - val_loss: 13.9831 - val_root_mean_squared_error: 3.7394
# Epoch 33/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.8965 - root_mean_squared_error: 3.7278 - val_loss: 13.9302 - val_root_mean_squared_error: 3.7323
# Epoch 34/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 13.8091 - root_mean_squared_error: 3.7161 - val_loss: 13.9069 - val_root_mean_squared_error: 3.7292
# Epoch 35/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.7461 - root_mean_squared_error: 3.7076 - val_loss: 13.9085 - val_root_mean_squared_error: 3.7294
# Epoch 36/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.7045 - root_mean_squared_error: 3.7020 - val_loss: 13.8736 - val_root_mean_squared_error: 3.7247
# Epoch 37/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.6630 - root_mean_squared_error: 3.6963 - val_loss: 13.8035 - val_root_mean_squared_error: 3.7153
# Epoch 38/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 13.6031 - root_mean_squared_error: 3.6882 - val_loss: 13.7124 - val_root_mean_squared_error: 3.7030
# Epoch 39/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.5401 - root_mean_squared_error: 3.6797 - val_loss: 13.6215 - val_root_mean_squared_error: 3.6907
# Epoch 40/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.5014 - root_mean_squared_error: 3.6744 - val_loss: 13.5556 - val_root_mean_squared_error: 3.6818
# Epoch 41/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 13.4570 - root_mean_squared_error: 3.6684 - val_loss: 13.5011 - val_root_mean_squared_error: 3.6744
# Epoch 42/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 13.3908 - root_mean_squared_error: 3.6593 - val_loss: 13.4627 - val_root_mean_squared_error: 3.6692
# Epoch 43/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.3411 - root_mean_squared_error: 3.6525 - val_loss: 13.4433 - val_root_mean_squared_error: 3.6665
# Epoch 44/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.2844 - root_mean_squared_error: 3.6448 - val_loss: 13.3886 - val_root_mean_squared_error: 3.6590
# Epoch 45/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.2251 - root_mean_squared_error: 3.6366 - val_loss: 13.2974 - val_root_mean_squared_error: 3.6466
# Epoch 46/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.1582 - root_mean_squared_error: 3.6274 - val_loss: 13.2152 - val_root_mean_squared_error: 3.6353
# Epoch 47/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.1008 - root_mean_squared_error: 3.6195 - val_loss: 13.1412 - val_root_mean_squared_error: 3.6251
# Epoch 48/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 13.0452 - root_mean_squared_error: 3.6118 - val_loss: 13.0774 - val_root_mean_squared_error: 3.6163
# Epoch 49/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.9810 - root_mean_squared_error: 3.6029 - val_loss: 13.0159 - val_root_mean_squared_error: 3.6078
# Epoch 50/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.9176 - root_mean_squared_error: 3.5941 - val_loss: 12.9518 - val_root_mean_squared_error: 3.5989
# Epoch 51/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.8513 - root_mean_squared_error: 3.5849 - val_loss: 12.8954 - val_root_mean_squared_error: 3.5910
# Epoch 52/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.7883 - root_mean_squared_error: 3.5761 - val_loss: 12.8335 - val_root_mean_squared_error: 3.5824
# Epoch 53/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.7233 - root_mean_squared_error: 3.5670 - val_loss: 12.7580 - val_root_mean_squared_error: 3.5718
# Epoch 54/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.6567 - root_mean_squared_error: 3.5576 - val_loss: 12.6700 - val_root_mean_squared_error: 3.5595
# Epoch 55/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.5828 - root_mean_squared_error: 3.5472 - val_loss: 12.5894 - val_root_mean_squared_error: 3.5482
# Epoch 56/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.5126 - root_mean_squared_error: 3.5373 - val_loss: 12.5081 - val_root_mean_squared_error: 3.5367
# Epoch 57/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.4402 - root_mean_squared_error: 3.5271 - val_loss: 12.4282 - val_root_mean_squared_error: 3.5254
# Epoch 58/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.3681 - root_mean_squared_error: 3.5168 - val_loss: 12.3461 - val_root_mean_squared_error: 3.5137
# Epoch 59/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.2919 - root_mean_squared_error: 3.5060 - val_loss: 12.2598 - val_root_mean_squared_error: 3.5014
# Epoch 60/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.2160 - root_mean_squared_error: 3.4951 - val_loss: 12.1757 - val_root_mean_squared_error: 3.4894
# Epoch 61/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 12.1362 - root_mean_squared_error: 3.4837 - val_loss: 12.0964 - val_root_mean_squared_error: 3.4780
# Epoch 62/72
# 1557/1557 [==============================] - 0s 9us/sample - loss: 12.0553 - root_mean_squared_error: 3.4721 - val_loss: 12.0123 - val_root_mean_squared_error: 3.4659
# Epoch 63/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.9729 - root_mean_squared_error: 3.4602 - val_loss: 11.9195 - val_root_mean_squared_error: 3.4525
# Epoch 64/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.8908 - root_mean_squared_error: 3.4483 - val_loss: 11.8223 - val_root_mean_squared_error: 3.4384
# Epoch 65/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.8065 - root_mean_squared_error: 3.4361 - val_loss: 11.7233 - val_root_mean_squared_error: 3.4239
# Epoch 66/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.7172 - root_mean_squared_error: 3.4230 - val_loss: 11.6211 - val_root_mean_squared_error: 3.4090
# Epoch 67/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 11.6395 - root_mean_squared_error: 3.4117 - val_loss: 11.5200 - val_root_mean_squared_error: 3.3941
# Epoch 68/72
# 1557/1557 [==============================] - 0s 11us/sample - loss: 11.5434 - root_mean_squared_error: 3.3976 - val_loss: 11.4290 - val_root_mean_squared_error: 3.3807
# Epoch 69/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.4456 - root_mean_squared_error: 3.3831 - val_loss: 11.3376 - val_root_mean_squared_error: 3.3671
# Epoch 70/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.3516 - root_mean_squared_error: 3.3692 - val_loss: 11.2398 - val_root_mean_squared_error: 3.3526
# Epoch 71/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.2595 - root_mean_squared_error: 3.3555 - val_loss: 11.1305 - val_root_mean_squared_error: 3.3362
# Epoch 72/72
# 1557/1557 [==============================] - 0s 10us/sample - loss: 11.1593 - root_mean_squared_error: 3.3406 - val_loss: 11.0116 - val_root_mean_squared_error: 3.3184
# Train on 1501 samples, validate on 167 samples
# Epoch 1/19
# 1501/1501 [==============================] - 1s 334us/sample - loss: 48295.0511 - root_mean_squared_error: 219.7614 - val_loss: 17559.8145 - val_root_mean_squared_error: 132.5134
# Epoch 2/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 13910.8141 - root_mean_squared_error: 117.9441 - val_loss: 9535.6621 - val_root_mean_squared_error: 97.6507
# Epoch 3/19
# 1501/1501 [==============================] - 0s 26us/sample - loss: 4668.5701 - root_mean_squared_error: 68.3269 - val_loss: 19.4988 - val_root_mean_squared_error: 4.4157
# Epoch 4/19
# 1501/1501 [==============================] - 0s 25us/sample - loss: 1669.6761 - root_mean_squared_error: 40.8617 - val_loss: 1983.2085 - val_root_mean_squared_error: 44.5332
# Epoch 5/19
# 1501/1501 [==============================] - 0s 26us/sample - loss: 1060.3613 - root_mean_squared_error: 32.5632 - val_loss: 559.9109 - val_root_mean_squared_error: 23.6624
# Epoch 6/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 346.4699 - root_mean_squared_error: 18.6137 - val_loss: 103.9368 - val_root_mean_squared_error: 10.1949
# Epoch 7/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 177.4958 - root_mean_squared_error: 13.3228 - val_loss: 191.3587 - val_root_mean_squared_error: 13.8332
# Epoch 8/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 84.9822 - root_mean_squared_error: 9.2186 - val_loss: 13.8984 - val_root_mean_squared_error: 3.7281
# Epoch 9/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 34.8511 - root_mean_squared_error: 5.9035 - val_loss: 31.9358 - val_root_mean_squared_error: 5.6512
# Epoch 10/19
# 1501/1501 [==============================] - 0s 26us/sample - loss: 17.9765 - root_mean_squared_error: 4.2399 - val_loss: 15.0016 - val_root_mean_squared_error: 3.8732
# Epoch 11/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 12.5696 - root_mean_squared_error: 3.5454 - val_loss: 6.0134 - val_root_mean_squared_error: 2.4522
# Epoch 12/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 7.1280 - root_mean_squared_error: 2.6698 - val_loss: 7.6721 - val_root_mean_squared_error: 2.7699
# Epoch 13/19
# 1501/1501 [==============================] - 0s 28us/sample - loss: 5.9970 - root_mean_squared_error: 2.4489 - val_loss: 5.4081 - val_root_mean_squared_error: 2.3255
# Epoch 14/19
# 1501/1501 [==============================] - 0s 28us/sample - loss: 5.2466 - root_mean_squared_error: 2.2906 - val_loss: 4.5792 - val_root_mean_squared_error: 2.1399
# Epoch 15/19
# 1501/1501 [==============================] - 0s 28us/sample - loss: 4.7574 - root_mean_squared_error: 2.1812 - val_loss: 4.4014 - val_root_mean_squared_error: 2.0979
# Epoch 16/19
# 1501/1501 [==============================] - 0s 28us/sample - loss: 4.3572 - root_mean_squared_error: 2.0874 - val_loss: 4.3970 - val_root_mean_squared_error: 2.0969
# Epoch 17/19
# 1501/1501 [==============================] - 0s 28us/sample - loss: 4.3433 - root_mean_squared_error: 2.0840 - val_loss: 4.3241 - val_root_mean_squared_error: 2.0795
# Epoch 18/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 4.2891 - root_mean_squared_error: 2.0710 - val_loss: 4.0569 - val_root_mean_squared_error: 2.0142
# Epoch 19/19
# 1501/1501 [==============================] - 0s 27us/sample - loss: 3.9920 - root_mean_squared_error: 1.9980 - val_loss: 3.7062 - val_root_mean_squared_error: 1.9252
# |  2        | -2.279    |  203.4    |  19.44    |  346.9    |  398.0    |  108.2    |
# Train on 1575 samples, validate on 175 samples
# Epoch 1/69
# 1575/1575 [==============================] - 0s 263us/sample - loss: 99176.9231 - root_mean_squared_error: 314.9237 - val_loss: 17350.0234 - val_root_mean_squared_error: 131.7195
# Epoch 2/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 26903.3121 - root_mean_squared_error: 164.0223 - val_loss: 110622.9609 - val_root_mean_squared_error: 332.6003
# Epoch 3/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 100423.9656 - root_mean_squared_error: 316.8974 - val_loss: 29594.4238 - val_root_mean_squared_error: 172.0303
# Epoch 4/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 17536.0802 - root_mean_squared_error: 132.4239 - val_loss: 11242.6855 - val_root_mean_squared_error: 106.0315
# Epoch 5/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 21181.0932 - root_mean_squared_error: 145.5373 - val_loss: 45215.2109 - val_root_mean_squared_error: 212.6387
# Epoch 6/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 40555.8168 - root_mean_squared_error: 201.3848 - val_loss: 15512.1357 - val_root_mean_squared_error: 124.5477
# Epoch 7/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 9848.0291 - root_mean_squared_error: 99.2372 - val_loss: 1033.1311 - val_root_mean_squared_error: 32.1424
# Epoch 8/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 4257.2341 - root_mean_squared_error: 65.2475 - val_loss: 16712.4492 - val_root_mean_squared_error: 129.2766
# Epoch 9/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 17513.2296 - root_mean_squared_error: 132.3376 - val_loss: 13837.8184 - val_root_mean_squared_error: 117.6343
# Epoch 10/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 10700.1640 - root_mean_squared_error: 103.4416 - val_loss: 939.5723 - val_root_mean_squared_error: 30.6524
# Epoch 11/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 702.5533 - root_mean_squared_error: 26.5057 - val_loss: 3569.0017 - val_root_mean_squared_error: 59.7411
# Epoch 12/69
# 1575/1575 [==============================] - ETA: 0s - loss: 3524.8750 - root_mean_squared_error: 59.370 - 0s 14us/sample - loss: 5044.4598 - root_mean_squared_error: 71.0244 - val_loss: 8534.8242 - val_root_mean_squared_error: 92.3841
# Epoch 13/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 7724.9709 - root_mean_squared_error: 87.8918 - val_loss: 3430.5356 - val_root_mean_squared_error: 58.5708
# Epoch 14/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 2280.7650 - root_mean_squared_error: 47.7574 - val_loss: 65.3637 - val_root_mean_squared_error: 8.0848
# Epoch 15/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 573.4372 - root_mean_squared_error: 23.9465 - val_loss: 3036.4404 - val_root_mean_squared_error: 55.1039
# Epoch 16/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 3417.0619 - root_mean_squared_error: 58.4556 - val_loss: 3376.9875 - val_root_mean_squared_error: 58.1119
# Epoch 17/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 2774.9087 - root_mean_squared_error: 52.6774 - val_loss: 521.1930 - val_root_mean_squared_error: 22.8297
# Epoch 18/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 315.3769 - root_mean_squared_error: 17.7589 - val_loss: 481.2564 - val_root_mean_squared_error: 21.9376
# Epoch 19/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 826.8964 - root_mean_squared_error: 28.7558 - val_loss: 1889.7620 - val_root_mean_squared_error: 43.4714
# Epoch 20/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 1797.0575 - root_mean_squared_error: 42.3917 - val_loss: 1039.1110 - val_root_mean_squared_error: 32.2352
# Epoch 21/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 726.8020 - root_mean_squared_error: 26.9593 - val_loss: 19.6804 - val_root_mean_squared_error: 4.4363
# Epoch 22/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 102.4509 - root_mean_squared_error: 10.1218 - val_loss: 610.2431 - val_root_mean_squared_error: 24.7031
# Epoch 23/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 712.8609 - root_mean_squared_error: 26.6995 - val_loss: 733.5134 - val_root_mean_squared_error: 27.0835
# Epoch 24/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 600.5183 - root_mean_squared_error: 24.5055 - val_loss: 97.2221 - val_root_mean_squared_error: 9.8601
# Epoch 25/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 69.2153 - root_mean_squared_error: 8.3196 - val_loss: 177.9159 - val_root_mean_squared_error: 13.3385
# Epoch 26/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 253.8737 - root_mean_squared_error: 15.9334 - val_loss: 439.9942 - val_root_mean_squared_error: 20.9760
# Epoch 27/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 384.5475 - root_mean_squared_error: 19.6099 - val_loss: 141.2199 - val_root_mean_squared_error: 11.8836
# Epoch 28/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 90.9638 - root_mean_squared_error: 9.5375 - val_loss: 43.4104 - val_root_mean_squared_error: 6.5887
# Epoch 29/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 86.0748 - root_mean_squared_error: 9.2777 - val_loss: 219.0296 - val_root_mean_squared_error: 14.7996
# Epoch 30/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 218.4486 - root_mean_squared_error: 14.7800 - val_loss: 122.4671 - val_root_mean_squared_error: 11.0665
# Epoch 31/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 90.1935 - root_mean_squared_error: 9.4970 - val_loss: 18.4108 - val_root_mean_squared_error: 4.2908
# Epoch 32/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 33.5584 - root_mean_squared_error: 5.7930 - val_loss: 111.6635 - val_root_mean_squared_error: 10.5671
# Epoch 33/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 108.5522 - root_mean_squared_error: 10.4188 - val_loss: 67.3154 - val_root_mean_squared_error: 8.2046
# Epoch 34/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 47.7052 - root_mean_squared_error: 6.9069 - val_loss: 21.9963 - val_root_mean_squared_error: 4.6900
# Epoch 35/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 34.8514 - root_mean_squared_error: 5.9035 - val_loss: 65.5704 - val_root_mean_squared_error: 8.0976
# Epoch 36/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 61.6345 - root_mean_squared_error: 7.8508 - val_loss: 25.1745 - val_root_mean_squared_error: 5.0174
# Epoch 37/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 22.1850 - root_mean_squared_error: 4.7101 - val_loss: 29.4247 - val_root_mean_squared_error: 5.4245
# Epoch 38/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 34.5397 - root_mean_squared_error: 5.8770 - val_loss: 44.4512 - val_root_mean_squared_error: 6.6672
# Epoch 39/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 36.8748 - root_mean_squared_error: 6.0725 - val_loss: 17.0361 - val_root_mean_squared_error: 4.1275
# Epoch 40/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 17.0135 - root_mean_squared_error: 4.1247 - val_loss: 25.7148 - val_root_mean_squared_error: 5.0710
# Epoch 41/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 29.2531 - root_mean_squared_error: 5.4086 - val_loss: 25.5851 - val_root_mean_squared_error: 5.0582
# Epoch 42/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 23.2480 - root_mean_squared_error: 4.8216 - val_loss: 14.7164 - val_root_mean_squared_error: 3.8362
# Epoch 43/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 16.4366 - root_mean_squared_error: 4.0542 - val_loss: 24.2399 - val_root_mean_squared_error: 4.9234
# Epoch 44/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 23.2324 - root_mean_squared_error: 4.8200 - val_loss: 18.2721 - val_root_mean_squared_error: 4.2746
# Epoch 45/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 16.1303 - root_mean_squared_error: 4.0163 - val_loss: 14.4623 - val_root_mean_squared_error: 3.8029
# Epoch 46/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 16.4049 - root_mean_squared_error: 4.0503 - val_loss: 18.3944 - val_root_mean_squared_error: 4.2889
# Epoch 47/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 18.3788 - root_mean_squared_error: 4.2871 - val_loss: 13.5117 - val_root_mean_squared_error: 3.6758
# Epoch 48/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 13.7774 - root_mean_squared_error: 3.7118 - val_loss: 15.3624 - val_root_mean_squared_error: 3.9195
# Epoch 49/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 15.7788 - root_mean_squared_error: 3.9722 - val_loss: 15.7297 - val_root_mean_squared_error: 3.9661
# Epoch 50/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 14.8333 - root_mean_squared_error: 3.8514 - val_loss: 12.3662 - val_root_mean_squared_error: 3.5166
# Epoch 51/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 12.9909 - root_mean_squared_error: 3.6043 - val_loss: 13.6142 - val_root_mean_squared_error: 3.6897
# Epoch 52/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 14.2732 - root_mean_squared_error: 3.7780 - val_loss: 12.3742 - val_root_mean_squared_error: 3.5177
# Epoch 53/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 12.6444 - root_mean_squared_error: 3.5559 - val_loss: 12.2867 - val_root_mean_squared_error: 3.5052
# Epoch 54/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 12.6914 - root_mean_squared_error: 3.5625 - val_loss: 12.8869 - val_root_mean_squared_error: 3.5898
# Epoch 55/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 12.7216 - root_mean_squared_error: 3.5667 - val_loss: 11.3581 - val_root_mean_squared_error: 3.3702
# Epoch 56/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 11.6963 - root_mean_squared_error: 3.4200 - val_loss: 11.4777 - val_root_mean_squared_error: 3.3879
# Epoch 57/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 12.1395 - root_mean_squared_error: 3.4842 - val_loss: 11.1268 - val_root_mean_squared_error: 3.3357
# Epoch 58/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 11.6076 - root_mean_squared_error: 3.4070 - val_loss: 10.8849 - val_root_mean_squared_error: 3.2992
# Epoch 59/69
# 1575/1575 [==============================] - 0s 13us/sample - loss: 11.3239 - root_mean_squared_error: 3.3651 - val_loss: 11.0463 - val_root_mean_squared_error: 3.3236
# Epoch 60/69
# 1575/1575 [==============================] - 0s 14us/sample - loss: 11.2428 - root_mean_squared_error: 3.3530 - val_loss: 10.3681 - val_root_mean_squared_error: 3.2200
# Epoch 61/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.7908 - root_mean_squared_error: 3.2849 - val_loss: 10.2609 - val_root_mean_squared_error: 3.2033
# Epoch 62/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.7964 - root_mean_squared_error: 3.2858 - val_loss: 10.0305 - val_root_mean_squared_error: 3.1671
# Epoch 63/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.4928 - root_mean_squared_error: 3.2393 - val_loss: 9.9299 - val_root_mean_squared_error: 3.1512
# Epoch 64/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.3878 - root_mean_squared_error: 3.2230 - val_loss: 9.8924 - val_root_mean_squared_error: 3.1452
# Epoch 65/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.2387 - root_mean_squared_error: 3.1998 - val_loss: 9.5343 - val_root_mean_squared_error: 3.0878
# Epoch 66/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 10.0655 - root_mean_squared_error: 3.1726 - val_loss: 9.4198 - val_root_mean_squared_error: 3.0692
# Epoch 67/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 9.9388 - root_mean_squared_error: 3.1526 - val_loss: 9.2326 - val_root_mean_squared_error: 3.0385
# Epoch 68/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 9.7292 - root_mean_squared_error: 3.1192 - val_loss: 9.1725 - val_root_mean_squared_error: 3.0286
# Epoch 69/69
# 1575/1575 [==============================] - 0s 15us/sample - loss: 9.6431 - root_mean_squared_error: 3.1053 - val_loss: 9.0222 - val_root_mean_squared_error: 3.0037
# Train on 1541 samples, validate on 172 samples
# Epoch 1/95
# 1541/1541 [==============================] - 0s 233us/sample - loss: 154.7318 - root_mean_squared_error: 12.4391 - val_loss: 397673.6875 - val_root_mean_squared_error: 630.6137
# Epoch 2/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 396067.4375 - root_mean_squared_error: 629.3389 - val_loss: 30837.0117 - val_root_mean_squared_error: 175.6047
# Epoch 3/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 30713.9980 - root_mean_squared_error: 175.2541 - val_loss: 63682.9609 - val_root_mean_squared_error: 252.3548
# Epoch 4/95
# 1541/1541 [==============================] - 0s 11us/sample - loss: 63405.6914 - root_mean_squared_error: 251.8049 - val_loss: 183048.5000 - val_root_mean_squared_error: 427.8417
# Epoch 5/95
# 1541/1541 [==============================] - 0s 11us/sample - loss: 182240.6406 - root_mean_squared_error: 426.8965 - val_loss: 151676.1875 - val_root_mean_squared_error: 389.4563
# Epoch 6/95
# 1541/1541 [==============================] - 0s 11us/sample - loss: 150986.9531 - root_mean_squared_error: 388.5704 - val_loss: 60169.5273 - val_root_mean_squared_error: 245.2948
# Epoch 7/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 59888.5312 - root_mean_squared_error: 244.7213 - val_loss: 4743.3701 - val_root_mean_squared_error: 68.8721
# Epoch 8/95
# 1541/1541 [==============================] - 0s 11us/sample - loss: 4714.3477 - root_mean_squared_error: 68.6611 - val_loss: 8951.3623 - val_root_mean_squared_error: 94.6116
# Epoch 9/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 8928.6611 - root_mean_squared_error: 94.4916 - val_loss: 43869.4141 - val_root_mean_squared_error: 209.4503
# Epoch 10/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 43725.1328 - root_mean_squared_error: 209.1056 - val_loss: 68044.8047 - val_root_mean_squared_error: 260.8540
# Epoch 11/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 67816.1484 - root_mean_squared_error: 260.4153 - val_loss: 63263.3789 - val_root_mean_squared_error: 251.5221
# Epoch 12/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 63059.2227 - root_mean_squared_error: 251.1160 - val_loss: 38428.5508 - val_root_mean_squared_error: 196.0320
# Epoch 13/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 38325.7227 - root_mean_squared_error: 195.7696 - val_loss: 12828.5176 - val_root_mean_squared_error: 113.2630
# Epoch 14/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 12811.1016 - root_mean_squared_error: 113.1861 - val_loss: 449.4608 - val_root_mean_squared_error: 21.2005
# Epoch 15/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 455.6364 - root_mean_squared_error: 21.3456 - val_loss: 4185.7061 - val_root_mean_squared_error: 64.6970
# Epoch 16/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 4142.2637 - root_mean_squared_error: 64.3604 - val_loss: 16374.4277 - val_root_mean_squared_error: 127.9626
# Epoch 17/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 16251.5117 - root_mean_squared_error: 127.4814 - val_loss: 26372.8516 - val_root_mean_squared_error: 162.3972
# Epoch 18/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 26190.7168 - root_mean_squared_error: 161.8355 - val_loss: 27639.0430 - val_root_mean_squared_error: 166.2499
# Epoch 19/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 27450.9824 - root_mean_squared_error: 165.6834 - val_loss: 20416.4180 - val_root_mean_squared_error: 142.8860
# Epoch 20/95
# 1541/1541 [==============================] - 0s 14us/sample - loss: 20270.3809 - root_mean_squared_error: 142.3741 - val_loss: 9931.2783 - val_root_mean_squared_error: 99.6558
# Epoch 21/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 9849.8477 - root_mean_squared_error: 99.2464 - val_loss: 2078.5427 - val_root_mean_squared_error: 45.5910
# Epoch 22/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 2052.5110 - root_mean_squared_error: 45.3046 - val_loss: 112.3307 - val_root_mean_squared_error: 10.5986
# Epoch 23/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 116.3237 - root_mean_squared_error: 10.7853 - val_loss: 3216.7959 - val_root_mean_squared_error: 56.7168
# Epoch 24/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 3224.3008 - root_mean_squared_error: 56.7829 - val_loss: 7905.7495 - val_root_mean_squared_error: 88.9143
# Epoch 25/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 7903.1309 - root_mean_squared_error: 88.8996 - val_loss: 10727.7949 - val_root_mean_squared_error: 103.5751
# Epoch 26/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 10716.3311 - root_mean_squared_error: 103.5197 - val_loss: 10071.7109 - val_root_mean_squared_error: 100.3579
# Epoch 27/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 10062.4873 - root_mean_squared_error: 100.3120 - val_loss: 6591.6636 - val_root_mean_squared_error: 81.1891
# Epoch 28/95
# 1541/1541 [==============================] - 0s 14us/sample - loss: 6589.6196 - root_mean_squared_error: 81.1765 - val_loss: 2530.8467 - val_root_mean_squared_error: 50.3075
# Epoch 29/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 2537.3621 - root_mean_squared_error: 50.3722 - val_loss: 221.7158 - val_root_mean_squared_error: 14.8901
# Epoch 30/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 226.4502 - root_mean_squared_error: 15.0483 - val_loss: 429.2070 - val_root_mean_squared_error: 20.7173
# Epoch 31/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 420.0869 - root_mean_squared_error: 20.4960 - val_loss: 2323.3682 - val_root_mean_squared_error: 48.2013
# Epoch 32/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 2294.8577 - root_mean_squared_error: 47.9047 - val_loss: 4101.1050 - val_root_mean_squared_error: 64.0399
# Epoch 33/95
# 1541/1541 [==============================] - 0s 13us/sample - loss: 4058.4126 - root_mean_squared_error: 63.7057 - val_loss: 4488.9907 - val_root_mean_squared_error: 66.9999
# Epoch 34/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 4443.1191 - root_mean_squared_error: 66.6567 - val_loss: 3405.7830 - val_root_mean_squared_error: 58.3591
# Epoch 35/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 3368.3440 - root_mean_squared_error: 58.0374 - val_loss: 1681.1766 - val_root_mean_squared_error: 41.0022
# Epoch 36/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 1658.5024 - root_mean_squared_error: 40.7247 - val_loss: 348.6489 - val_root_mean_squared_error: 18.6721
# Epoch 37/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 340.9016 - root_mean_squared_error: 18.4635 - val_loss: 37.4285 - val_root_mean_squared_error: 6.1179
# Epoch 38/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 39.3468 - root_mean_squared_error: 6.2727 - val_loss: 604.2485 - val_root_mean_squared_error: 24.5815
# Epoch 39/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 610.2168 - root_mean_squared_error: 24.7026 - val_loss: 1371.7220 - val_root_mean_squared_error: 37.0368
# Epoch 40/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 1378.7712 - root_mean_squared_error: 37.1318 - val_loss: 1772.8817 - val_root_mean_squared_error: 42.1056
# Epoch 41/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 1779.8274 - root_mean_squared_error: 42.1880 - val_loss: 1629.5347 - val_root_mean_squared_error: 40.3675
# Epoch 42/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 1636.9260 - root_mean_squared_error: 40.4589 - val_loss: 1067.2761 - val_root_mean_squared_error: 32.6692
# Epoch 43/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 1074.3715 - root_mean_squared_error: 32.7776 - val_loss: 426.3873 - val_root_mean_squared_error: 20.6491
# Epoch 44/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 432.0928 - root_mean_squared_error: 20.7868 - val_loss: 50.0459 - val_root_mean_squared_error: 7.0743
# Epoch 45/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 52.4416 - root_mean_squared_error: 7.2417 - val_loss: 74.2313 - val_root_mean_squared_error: 8.6158
# Epoch 46/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 71.5966 - root_mean_squared_error: 8.4615 - val_loss: 381.7842 - val_root_mean_squared_error: 19.5393
# Epoch 47/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 373.7196 - root_mean_squared_error: 19.3318 - val_loss: 711.1581 - val_root_mean_squared_error: 26.6675
# Epoch 48/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 699.0643 - root_mean_squared_error: 26.4398 - val_loss: 834.6970 - val_root_mean_squared_error: 28.8911
# Epoch 49/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 821.3319 - root_mean_squared_error: 28.6589 - val_loss: 654.9514 - val_root_mean_squared_error: 25.5920
# Epoch 50/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 644.1444 - root_mean_squared_error: 25.3800 - val_loss: 324.9478 - val_root_mean_squared_error: 18.0263
# Epoch 51/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 318.1812 - root_mean_squared_error: 17.8376 - val_loss: 66.4598 - val_root_mean_squared_error: 8.1523
# Epoch 52/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 64.1563 - root_mean_squared_error: 8.0098 - val_loss: 24.8224 - val_root_mean_squared_error: 4.9822
# Epoch 53/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 26.0279 - root_mean_squared_error: 5.1018 - val_loss: 170.0400 - val_root_mean_squared_error: 13.0399
# Epoch 54/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 173.2480 - root_mean_squared_error: 13.1624 - val_loss: 337.1888 - val_root_mean_squared_error: 18.3627
# Epoch 55/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 341.1647 - root_mean_squared_error: 18.4706 - val_loss: 382.0875 - val_root_mean_squared_error: 19.5471
# Epoch 56/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 386.1649 - root_mean_squared_error: 19.6511 - val_loss: 283.7935 - val_root_mean_squared_error: 16.8462
# Epoch 57/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 287.5093 - root_mean_squared_error: 16.9561 - val_loss: 127.7348 - val_root_mean_squared_error: 11.3020
# Epoch 58/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 130.5052 - root_mean_squared_error: 11.4239 - val_loss: 24.1547 - val_root_mean_squared_error: 4.9147
# Epoch 59/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 25.2791 - root_mean_squared_error: 5.0278 - val_loss: 27.4294 - val_root_mean_squared_error: 5.2373
# Epoch 60/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 26.4010 - root_mean_squared_error: 5.1382 - val_loss: 107.1913 - val_root_mean_squared_error: 10.3533
# Epoch 61/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 104.0735 - root_mean_squared_error: 10.2016 - val_loss: 184.1057 - val_root_mean_squared_error: 13.5686
# Epoch 62/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 179.6434 - root_mean_squared_error: 13.4031 - val_loss: 195.7795 - val_root_mean_squared_error: 13.9921
# Epoch 63/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 191.1492 - root_mean_squared_error: 13.8257 - val_loss: 138.8470 - val_root_mean_squared_error: 11.7833
# Epoch 64/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 135.1738 - root_mean_squared_error: 11.6264 - val_loss: 60.3967 - val_root_mean_squared_error: 7.7715
# Epoch 65/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 58.3543 - root_mean_squared_error: 7.6390 - val_loss: 14.9174 - val_root_mean_squared_error: 3.8623
# Epoch 66/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 14.5940 - root_mean_squared_error: 3.8202 - val_loss: 23.7017 - val_root_mean_squared_error: 4.8684
# Epoch 67/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 24.7550 - root_mean_squared_error: 4.9754 - val_loss: 65.1002 - val_root_mean_squared_error: 8.0685
# Epoch 68/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 67.0233 - root_mean_squared_error: 8.1868 - val_loss: 97.8440 - val_root_mean_squared_error: 9.8916
# Epoch 69/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 100.1502 - root_mean_squared_error: 10.0075 - val_loss: 95.0806 - val_root_mean_squared_error: 9.7509
# Epoch 70/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 97.3514 - root_mean_squared_error: 9.8667 - val_loss: 61.8376 - val_root_mean_squared_error: 7.8637
# Epoch 71/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 63.6982 - root_mean_squared_error: 7.9811 - val_loss: 25.6143 - val_root_mean_squared_error: 5.0611
# Epoch 72/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 26.7267 - root_mean_squared_error: 5.1698 - val_loss: 11.7867 - val_root_mean_squared_error: 3.4332
# Epoch 73/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 11.9143 - root_mean_squared_error: 3.4517 - val_loss: 24.7355 - val_root_mean_squared_error: 4.9735
# Epoch 74/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 23.8521 - root_mean_squared_error: 4.8839 - val_loss: 47.9318 - val_root_mean_squared_error: 6.9233
# Epoch 75/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 46.2831 - root_mean_squared_error: 6.8032 - val_loss: 59.9622 - val_root_mean_squared_error: 7.7435
# Epoch 76/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 58.0091 - root_mean_squared_error: 7.6164 - val_loss: 51.7123 - val_root_mean_squared_error: 7.1911
# Epoch 77/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 49.9730 - root_mean_squared_error: 7.0692 - val_loss: 31.2601 - val_root_mean_squared_error: 5.5911
# Epoch 78/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 30.1353 - root_mean_squared_error: 5.4896 - val_loss: 14.7010 - val_root_mean_squared_error: 3.8342
# Epoch 79/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 14.3705 - root_mean_squared_error: 3.7908 - val_loss: 12.3406 - val_root_mean_squared_error: 3.5129
# Epoch 80/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 12.7574 - root_mean_squared_error: 3.5717 - val_loss: 21.7073 - val_root_mean_squared_error: 4.6591
# Epoch 81/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 22.6748 - root_mean_squared_error: 4.7618 - val_loss: 31.7496 - val_root_mean_squared_error: 5.6347
# Epoch 82/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 33.0088 - root_mean_squared_error: 5.7453 - val_loss: 33.0904 - val_root_mean_squared_error: 5.7524
# Epoch 83/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 34.3773 - root_mean_squared_error: 5.8632 - val_loss: 25.2036 - val_root_mean_squared_error: 5.0203
# Epoch 84/95
# 1541/1541 [==============================] - 0s 11us/sample - loss: 26.2794 - root_mean_squared_error: 5.1263 - val_loss: 15.2927 - val_root_mean_squared_error: 3.9106
# Epoch 85/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 15.9657 - root_mean_squared_error: 3.9957 - val_loss: 11.1241 - val_root_mean_squared_error: 3.3353
# Epoch 86/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 11.2851 - root_mean_squared_error: 3.3593 - val_loss: 14.5833 - val_root_mean_squared_error: 3.8188
# Epoch 87/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 14.2420 - root_mean_squared_error: 3.7739 - val_loss: 21.0651 - val_root_mean_squared_error: 4.5897
# Epoch 88/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 20.3581 - root_mean_squared_error: 4.5120 - val_loss: 24.2663 - val_root_mean_squared_error: 4.9261
# Epoch 89/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 23.4234 - root_mean_squared_error: 4.8398 - val_loss: 21.6093 - val_root_mean_squared_error: 4.6486
# Epoch 90/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 20.8803 - root_mean_squared_error: 4.5695 - val_loss: 15.7247 - val_root_mean_squared_error: 3.9654
# Epoch 91/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 15.3007 - root_mean_squared_error: 3.9116 - val_loss: 11.4056 - val_root_mean_squared_error: 3.3772
# Epoch 92/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 11.3711 - root_mean_squared_error: 3.3721 - val_loss: 11.2923 - val_root_mean_squared_error: 3.3604
# Epoch 93/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 11.6242 - root_mean_squared_error: 3.4094 - val_loss: 14.0881 - val_root_mean_squared_error: 3.7534
# Epoch 94/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 14.6851 - root_mean_squared_error: 3.8321 - val_loss: 16.3736 - val_root_mean_squared_error: 4.0464
# Epoch 95/95
# 1541/1541 [==============================] - 0s 12us/sample - loss: 17.0938 - root_mean_squared_error: 4.1345 - val_loss: 15.8881 - val_root_mean_squared_error: 3.9860
# Train on 1510 samples, validate on 168 samples
# Epoch 1/46
# 1510/1510 [==============================] - 0s 239us/sample - loss: 266345.5527 - root_mean_squared_error: 516.0867 - val_loss: 80822.1172 - val_root_mean_squared_error: 284.2923
# Epoch 2/46
# 1510/1510 [==============================] - 0s 18us/sample - loss: 155649.4593 - root_mean_squared_error: 394.5244 - val_loss: 75855.2891 - val_root_mean_squared_error: 275.4184
# Epoch 3/46
# 1510/1510 [==============================] - 0s 18us/sample - loss: 37222.3029 - root_mean_squared_error: 192.9308 - val_loss: 51920.7734 - val_root_mean_squared_error: 227.8613
# Epoch 4/46
# 1510/1510 [==============================] - 0s 18us/sample - loss: 66117.7713 - root_mean_squared_error: 257.1338 - val_loss: 42642.7656 - val_root_mean_squared_error: 206.5013
# Epoch 5/46
# 1510/1510 [==============================] - 0s 17us/sample - loss: 24285.6069 - root_mean_squared_error: 155.8384 - val_loss: 5406.5811 - val_root_mean_squared_error: 73.5295
# Epoch 6/46
# ...
# Epoch 14/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 1169.7103 - root_mean_squared_error: 34.2010 - val_loss: 1434.4709 - val_root_mean_squared_error: 37.8744
# Epoch 15/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 1029.9156 - root_mean_squared_error: 32.0923 - val_loss: 132.8607 - val_root_mean_squared_error: 11.5265
# Epoch 16/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 90.0941 - root_mean_squared_error: 9.4918 - val_loss: 345.9949 - val_root_mean_squared_error: 18.6009
# Epoch 17/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 454.0084 - root_mean_squared_error: 21.3075 - val_loss: 432.1674 - val_root_mean_squared_error: 20.7886
# Epoch 18/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 264.2643 - root_mean_squared_error: 16.2562 - val_loss: 13.1655 - val_root_mean_squared_error: 3.6284
# Epoch 19/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 72.0117 - root_mean_squared_error: 8.4860 - val_loss: 226.6599 - val_root_mean_squared_error: 15.0552
# Epoch 20/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 205.3576 - root_mean_squared_error: 14.3303 - val_loss: 64.5915 - val_root_mean_squared_error: 8.0369
# Epoch 21/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 35.2786 - root_mean_squared_error: 5.9396 - val_loss: 55.7528 - val_root_mean_squared_error: 7.4668
# Epoch 22/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 85.9123 - root_mean_squared_error: 9.2689 - val_loss: 100.8315 - val_root_mean_squared_error: 10.0415
# Epoch 23/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 67.7469 - root_mean_squared_error: 8.2308 - val_loss: 12.9356 - val_root_mean_squared_error: 3.5966
# Epoch 24/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 22.0685 - root_mean_squared_error: 4.6977 - val_loss: 51.3149 - val_root_mean_squared_error: 7.1634
# Epoch 25/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 53.3502 - root_mean_squared_error: 7.3041 - val_loss: 27.2259 - val_root_mean_squared_error: 5.2178
# Epoch 26/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 20.5503 - root_mean_squared_error: 4.5332 - val_loss: 18.8714 - val_root_mean_squared_error: 4.3441
# Epoch 27/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 25.6618 - root_mean_squared_error: 5.0658 - val_loss: 30.8653 - val_root_mean_squared_error: 5.5557
# Epoch 28/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 24.1717 - root_mean_squared_error: 4.9165 - val_loss: 11.5078 - val_root_mean_squared_error: 3.3923
# Epoch 29/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 13.8592 - root_mean_squared_error: 3.7228 - val_loss: 18.9196 - val_root_mean_squared_error: 4.3497
# Epoch 30/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 20.0293 - root_mean_squared_error: 4.4754 - val_loss: 13.3254 - val_root_mean_squared_error: 3.6504
# Epoch 31/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 12.7510 - root_mean_squared_error: 3.5709 - val_loss: 12.8763 - val_root_mean_squared_error: 3.5884
# Epoch 32/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 14.7377 - root_mean_squared_error: 3.8390 - val_loss: 14.6414 - val_root_mean_squared_error: 3.8264
# Epoch 33/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 13.4733 - root_mean_squared_error: 3.6706 - val_loss: 10.4210 - val_root_mean_squared_error: 3.2282
# Epoch 34/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 11.7278 - root_mean_squared_error: 3.4246 - val_loss: 11.9150 - val_root_mean_squared_error: 3.4518
# Epoch 35/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 12.6189 - root_mean_squared_error: 3.5523 - val_loss: 10.2312 - val_root_mean_squared_error: 3.1986
# Epoch 36/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 11.0141 - root_mean_squared_error: 3.3187 - val_loss: 10.8543 - val_root_mean_squared_error: 3.2946
# Epoch 37/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 11.4321 - root_mean_squared_error: 3.3811 - val_loss: 10.3411 - val_root_mean_squared_error: 3.2158
# Epoch 38/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 10.5919 - root_mean_squared_error: 3.2545 - val_loss: 9.6917 - val_root_mean_squared_error: 3.1132
# Epoch 39/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 10.6323 - root_mean_squared_error: 3.2607 - val_loss: 9.7689 - val_root_mean_squared_error: 3.1255
# Epoch 40/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 10.3733 - root_mean_squared_error: 3.2208 - val_loss: 9.3671 - val_root_mean_squared_error: 3.0606
# Epoch 41/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 10.0960 - root_mean_squared_error: 3.1774 - val_loss: 9.5850 - val_root_mean_squared_error: 3.0960
# Epoch 42/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 10.0193 - root_mean_squared_error: 3.1653 - val_loss: 9.0910 - val_root_mean_squared_error: 3.0151
# Epoch 43/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 9.6776 - root_mean_squared_error: 3.1109 - val_loss: 8.9760 - val_root_mean_squared_error: 2.9960
# Epoch 44/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 9.6428 - root_mean_squared_error: 3.1053 - val_loss: 8.7469 - val_root_mean_squared_error: 2.9575
# Epoch 45/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 9.3507 - root_mean_squared_error: 3.0579 - val_loss: 8.6797 - val_root_mean_squared_error: 2.9461
# Epoch 46/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 9.2048 - root_mean_squared_error: 3.0339 - val_loss: 8.5110 - val_root_mean_squared_error: 2.9174
# Epoch 47/100
# 1578/1578 [==============================] - 0s 26us/sample - loss: 9.0321 - root_mean_squared_error: 3.0053 - val_loss: 8.3047 - val_root_mean_squared_error: 2.8818
# Epoch 48/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 8.8742 - root_mean_squared_error: 2.9790 - val_loss: 8.1596 - val_root_mean_squared_error: 2.8565
# Epoch 49/100
# 1578/1578 [==============================] - 0s 26us/sample - loss: 8.6978 - root_mean_squared_error: 2.9492 - val_loss: 8.0427 - val_root_mean_squared_error: 2.8360
# Epoch 50/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 8.5495 - root_mean_squared_error: 2.9239 - val_loss: 7.9033 - val_root_mean_squared_error: 2.8113
# Epoch 51/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 8.3910 - root_mean_squared_error: 2.8967 - val_loss: 7.7405 - val_root_mean_squared_error: 2.7822
# Epoch 52/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 8.2413 - root_mean_squared_error: 2.8708 - val_loss: 7.5928 - val_root_mean_squared_error: 2.7555
# Epoch 53/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 8.0874 - root_mean_squared_error: 2.8438 - val_loss: 7.4628 - val_root_mean_squared_error: 2.7318
# Epoch 54/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 7.9437 - root_mean_squared_error: 2.8185 - val_loss: 7.3544 - val_root_mean_squared_error: 2.7119
# Epoch 55/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 7.7933 - root_mean_squared_error: 2.7917 - val_loss: 7.1841 - val_root_mean_squared_error: 2.6803
# Epoch 56/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 7.6381 - root_mean_squared_error: 2.7637 - val_loss: 7.0463 - val_root_mean_squared_error: 2.6545
# Epoch 57/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 7.4926 - root_mean_squared_error: 2.7373 - val_loss: 6.9141 - val_root_mean_squared_error: 2.6295
# Epoch 58/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 7.3496 - root_mean_squared_error: 2.7110 - val_loss: 6.8006 - val_root_mean_squared_error: 2.6078
# Epoch 59/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 7.2035 - root_mean_squared_error: 2.6839 - val_loss: 6.6485 - val_root_mean_squared_error: 2.5785
# Epoch 60/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 7.0607 - root_mean_squared_error: 2.6572 - val_loss: 6.5141 - val_root_mean_squared_error: 2.5523
# Epoch 61/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 6.9201 - root_mean_squared_error: 2.6306 - val_loss: 6.3917 - val_root_mean_squared_error: 2.5282
# Epoch 62/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 6.7795 - root_mean_squared_error: 2.6038 - val_loss: 6.2625 - val_root_mean_squared_error: 2.5025
# Epoch 63/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 6.6382 - root_mean_squared_error: 2.5765 - val_loss: 6.1258 - val_root_mean_squared_error: 2.4750
# Epoch 64/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 6.5078 - root_mean_squared_error: 2.5510 - val_loss: 6.0009 - val_root_mean_squared_error: 2.4497
# Epoch 65/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 6.3741 - root_mean_squared_error: 2.5247 - val_loss: 5.8735 - val_root_mean_squared_error: 2.4235
# Epoch 66/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 6.2281 - root_mean_squared_error: 2.4956 - val_loss: 5.7634 - val_root_mean_squared_error: 2.4007
# Epoch 67/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 6.1084 - root_mean_squared_error: 2.4715 - val_loss: 5.6403 - val_root_mean_squared_error: 2.3749
# Epoch 68/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 5.9687 - root_mean_squared_error: 2.4431 - val_loss: 5.5059 - val_root_mean_squared_error: 2.3465
# Epoch 69/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 5.8431 - root_mean_squared_error: 2.4173 - val_loss: 5.3864 - val_root_mean_squared_error: 2.3209
# Epoch 70/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 5.7166 - root_mean_squared_error: 2.3909 - val_loss: 5.2712 - val_root_mean_squared_error: 2.2959
# Epoch 71/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 5.6010 - root_mean_squared_error: 2.3666 - val_loss: 5.1666 - val_root_mean_squared_error: 2.2730
# Epoch 72/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 5.4719 - root_mean_squared_error: 2.3392 - val_loss: 5.0443 - val_root_mean_squared_error: 2.2459
# Epoch 73/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 5.3609 - root_mean_squared_error: 2.3154 - val_loss: 4.9350 - val_root_mean_squared_error: 2.2215
# Epoch 74/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 5.2372 - root_mean_squared_error: 2.2885 - val_loss: 4.8410 - val_root_mean_squared_error: 2.2002
# Epoch 75/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 5.1362 - root_mean_squared_error: 2.2663 - val_loss: 4.7389 - val_root_mean_squared_error: 2.1769
# Epoch 76/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 5.0302 - root_mean_squared_error: 2.2428 - val_loss: 4.6226 - val_root_mean_squared_error: 2.1500
# Epoch 77/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.9129 - root_mean_squared_error: 2.2165 - val_loss: 4.5269 - val_root_mean_squared_error: 2.1277
# Epoch 78/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.8077 - root_mean_squared_error: 2.1926 - val_loss: 4.4387 - val_root_mean_squared_error: 2.1068
# Epoch 79/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.7110 - root_mean_squared_error: 2.1705 - val_loss: 4.3370 - val_root_mean_squared_error: 2.0825
# Epoch 80/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 4.6088 - root_mean_squared_error: 2.1468 - val_loss: 4.2452 - val_root_mean_squared_error: 2.0604
# Epoch 81/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.5155 - root_mean_squared_error: 2.1250 - val_loss: 4.1582 - val_root_mean_squared_error: 2.0392
# Epoch 82/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.4247 - root_mean_squared_error: 2.1035 - val_loss: 4.0766 - val_root_mean_squared_error: 2.0191
# Epoch 83/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 4.3259 - root_mean_squared_error: 2.0799 - val_loss: 3.9870 - val_root_mean_squared_error: 1.9968
# Epoch 84/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.2479 - root_mean_squared_error: 2.0610 - val_loss: 3.9051 - val_root_mean_squared_error: 1.9761
# Epoch 85/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.1564 - root_mean_squared_error: 2.0387 - val_loss: 3.8413 - val_root_mean_squared_error: 1.9599
# Epoch 86/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 4.0747 - root_mean_squared_error: 2.0186 - val_loss: 3.7481 - val_root_mean_squared_error: 1.9360
# Epoch 87/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 3.9856 - root_mean_squared_error: 1.9964 - val_loss: 3.6766 - val_root_mean_squared_error: 1.9175
# Epoch 88/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 3.9102 - root_mean_squared_error: 1.9774 - val_loss: 3.5988 - val_root_mean_squared_error: 1.8970
# Epoch 89/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 3.8231 - root_mean_squared_error: 1.9553 - val_loss: 3.5314 - val_root_mean_squared_error: 1.8792
# Epoch 90/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 3.7528 - root_mean_squared_error: 1.9372 - val_loss: 3.4586 - val_root_mean_squared_error: 1.8597
# Epoch 91/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 3.6736 - root_mean_squared_error: 1.9167 - val_loss: 3.3891 - val_root_mean_squared_error: 1.8410
# Epoch 92/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 3.6028 - root_mean_squared_error: 1.8981 - val_loss: 3.3206 - val_root_mean_squared_error: 1.8223
# Epoch 93/100
# 1578/1578 [==============================] - 0s 24us/sample - loss: 3.5293 - root_mean_squared_error: 1.8786 - val_loss: 3.2606 - val_root_mean_squared_error: 1.8057
# Epoch 94/100
# 1578/1578 [==============================] - 0s 26us/sample - loss: 3.4622 - root_mean_squared_error: 1.8607 - val_loss: 3.1926 - val_root_mean_squared_error: 1.7868
# Epoch 95/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 3.3940 - root_mean_squared_error: 1.8423 - val_loss: 3.1318 - val_root_mean_squared_error: 1.7697
# Epoch 96/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 3.3297 - root_mean_squared_error: 1.8247 - val_loss: 3.0718 - val_root_mean_squared_error: 1.7526
# Epoch 97/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 3.2627 - root_mean_squared_error: 1.8063 - val_loss: 3.0125 - val_root_mean_squared_error: 1.7356
# Epoch 98/100
# 1578/1578 [==============================] - 0s 25us/sample - loss: 3.2005 - root_mean_squared_error: 1.7890 - val_loss: 2.9559 - val_root_mean_squared_error: 1.7193
# Epoch 99/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 3.1396 - root_mean_squared_error: 1.7719 - val_loss: 2.9014 - val_root_mean_squared_error: 1.7033
# Epoch 100/100
# 1578/1578 [==============================] - 0s 23us/sample - loss: 3.0837 - root_mean_squared_error: 1.7560 - val_loss: 2.8487 - val_root_mean_squared_error: 1.6878
# |  13       | -1.651    |  573.7    |  100.0    |  1e+03    |  857.6    |  1.0      |
# =====================================================================================
# Wall time: 8min 53s

# %%
optimizer.max
# Out:
# {'target': -1.6510967745738543,
#  'params': {'batch_size': 573.7001888996526,
#   'epochs': 100.0,
#   'hidden1': 1000.0,
#   'hidden2': 857.5630678591813,
#   'n_steps': 1.0}}

# %% [markdown]
# El RMSE obtenido con este modelo está muy cerca al menor obtenido hasta ahora. Notamos que la búsqueda tomó valores muy altos en los hiperparámetros relacionados con la cantidad de neuronas y las épocas. Procedemos a modelar una red con 3 capas ocultas y buscar sus hiperparámetros para analizar el comportamiento.

# %%
def buildModelNN2(hidden1, hidden2, hidden3, epochs, batch_size, n_steps):
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)
    np.random.seed(1234) 

    hidden1 = int(round(hidden1))
    hidden2 = int(round(hidden2))
    hidden3 = int(round(hidden3))
    
    epochs = int(round(epochs))
    batch_size = int(round(batch_size))
    n_steps = int(round(n_steps))
    
    # Corte transversal
    data = corteTransversal(n_steps)
    # Split
    X_train, y_train, X_test, y_test = splitData(data)
    
    #Pretratamiento de los datos
    scaler = StandardScaler()
    X_train_std = scaler.fit_transform(X_train)
    X_test_std = scaler.fit_transform(X_test)

    modelNN = models.Sequential()
    modelNN.add(layers.Dense(units = hidden1, activation = 'relu', input_shape = (len(data.columns)-1,)))
    modelNN.add(layers.Dense(units = hidden2, activation = 'relu'))
    modelNN.add(layers.Dense(units = hidden3, activation = 'relu'))
    modelNN.add(layers.Dense(units = 1, activation = 'linear'))
    
    modelNN.compile(optimizer = 'adam', loss = 'mse', metrics = [tf.keras.metrics.RootMeanSquaredError()])
    
    history = modelNN.fit(X_train, y_train, epochs = epochs, batch_size = batch_size, validation_split=0.1, verbose = 1)    
    y_pred = modelNN.predict(X_test)
    
    #print("RMSE:", sqrt(mean_squared_error(y_test, y_pred)), 
    #  ", MAE:", mean_absolute_error(y_test, y_pred), 
    #  ", R2:", r2_score(y_test, y_pred), "\n")
    
    rmse = sqrt(mean_squared_error(y_test, y_pred))
    #mse = mean_squared_error(y_test, y_pred)
    
    return -rmse

# Establecemos los límites donde buscará opt
pbounds = {
    'hidden1': (2, 1000), 
    'hidden2' : (2, 1000),
    'hidden3' : (2, 1000),
    'epochs' : (1, 100),
    'batch_size' : (1, len(df_ori)),
    'n_steps' : (1, 200)
}

optimizer = BayesianOptimization(
    f = buildModelNN2,
    pbounds = pbounds,
    random_state = 1,
    verbose = 1
)

# %%
# %%time 
optimizer.maximize(
    init_points=3,
    n_iter=10,
)
# Out:
# |   iter    |  target   | batch_... |  epochs   |  hidden1  |  hidden2  |  hidden3  |  n_steps  |
# -------------------------------------------------------------------------------------------------
# Train on 1565 samples, validate on 174 samples
# Epoch 1/72
# 1565/1565 [==============================] - 0s 262us/sample - loss: 417.1226 - root_mean_squared_error: 20.4236 - val_loss: 95.5319 - val_root_mean_squared_error: 9.7740
# Epoch 2/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 119.6654 - root_mean_squared_error: 10.9392 - val_loss: 455.1397 - val_root_mean_squared_error: 21.3340
# Epoch 3/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 430.5499 - root_mean_squared_error: 20.7497 - val_loss: 126.3601 - val_root_mean_squared_error: 11.2410
# Epoch 4/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 85.5549 - root_mean_squared_error: 9.2496 - val_loss: 77.9714 - val_root_mean_squared_error: 8.8301
# Epoch 5/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 118.7338 - root_mean_squared_error: 10.8965 - val_loss: 216.5541 - val_root_mean_squared_error: 14.7158
# Epoch 6/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 184.6242 - root_mean_squared_error: 13.5876 - val_loss: 66.4010 - val_root_mean_squared_error: 8.1487
# Epoch 7/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 43.5023 - root_mean_squared_error: 6.5956 - val_loss: 23.7885 - val_root_mean_squared_error: 4.8773
# Epoch 8/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 41.3475 - root_mean_squared_error: 6.4302 - val_loss: 88.4715 - val_root_mean_squared_error: 9.4059
# Epoch 9/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 95.3537 - root_mean_squared_error: 9.7649 - val_loss: 69.7774 - val_root_mean_squared_error: 8.3533
# Epoch 10/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 61.5177 - root_mean_squared_error: 7.8433 - val_loss: 18.9224 - val_root_mean_squared_error: 4.3500
# Epoch 11/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 18.0896 - root_mean_squared_error: 4.2532 - val_loss: 26.2597 - val_root_mean_squared_error: 5.1244
# Epoch 12/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 30.9718 - root_mean_squared_error: 5.5652 - val_loss: 50.7731 - val_root_mean_squared_error: 7.1255
# Epoch 13/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 47.4336 - root_mean_squared_error: 6.8872 - val_loss: 38.1571 - val_root_mean_squared_error: 6.1771
# Epoch 14/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 31.2100 - root_mean_squared_error: 5.5866 - val_loss: 16.7288 - val_root_mean_squared_error: 4.0901
# Epoch 15/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 15.7498 - root_mean_squared_error: 3.9686 - val_loss: 17.4835 - val_root_mean_squared_error: 4.1813
# Epoch 16/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 21.1886 - root_mean_squared_error: 4.6031 - val_loss: 25.7553 - val_root_mean_squared_error: 5.0750
# Epoch 17/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 27.9566 - root_mean_squared_error: 5.2874 - val_loss: 22.8745 - val_root_mean_squared_error: 4.7827
# Epoch 18/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 22.9062 - root_mean_squared_error: 4.7860 - val_loss: 15.4290 - val_root_mean_squared_error: 3.9280
# Epoch 19/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 15.8378 - root_mean_squared_error: 3.9797 - val_loss: 15.5291 - val_root_mean_squared_error: 3.9407
# Epoch 20/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 15.9959 - root_mean_squared_error: 3.9995 - val_loss: 20.0512 - val_root_mean_squared_error: 4.4779
# Epoch 21/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 19.4913 - root_mean_squared_error: 4.4149 - val_loss: 20.0337 - val_root_mean_squared_error: 4.4759
# Epoch 22/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 18.4829 - root_mean_squared_error: 4.2992 - val_loss: 16.0259 - val_root_mean_squared_error: 4.0032
# Epoch 23/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 15.2969 - root_mean_squared_error: 3.9111 - val_loss: 14.2401 - val_root_mean_squared_error: 3.7736
# Epoch 24/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.9126 - root_mean_squared_error: 3.8617 - val_loss: 15.2686 - val_root_mean_squared_error: 3.9075
# Epoch 25/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 16.3076 - root_mean_squared_error: 4.0383 - val_loss: 15.5887 - val_root_mean_squared_error: 3.9483
# Epoch 26/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 16.2482 - root_mean_squared_error: 4.0309 - val_loss: 14.5483 - val_root_mean_squared_error: 3.8142
# Epoch 27/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 14.9216 - root_mean_squared_error: 3.8629 - val_loss: 14.2588 - val_root_mean_squared_error: 3.7761
# Epoch 28/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.4640 - root_mean_squared_error: 3.8032 - val_loss: 15.1634 - val_root_mean_squared_error: 3.8940
# Epoch 29/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 15.1031 - root_mean_squared_error: 3.8863 - val_loss: 15.5857 - val_root_mean_squared_error: 3.9479
# Epoch 30/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 15.1975 - root_mean_squared_error: 3.8984 - val_loss: 14.8549 - val_root_mean_squared_error: 3.8542
# Epoch 31/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.6291 - root_mean_squared_error: 3.8248 - val_loss: 14.1668 - val_root_mean_squared_error: 3.7639
# Epoch 32/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.4149 - root_mean_squared_error: 3.7967 - val_loss: 14.1556 - val_root_mean_squared_error: 3.7624
# Epoch 33/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.6509 - root_mean_squared_error: 3.8277 - val_loss: 14.2176 - val_root_mean_squared_error: 3.7706
# Epoch 34/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.6457 - root_mean_squared_error: 3.8270 - val_loss: 14.0752 - val_root_mean_squared_error: 3.7517
# Epoch 35/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.3884 - root_mean_squared_error: 3.7932 - val_loss: 14.1319 - val_root_mean_squared_error: 3.7592
# Epoch 36/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.2898 - root_mean_squared_error: 3.7802 - val_loss: 14.3751 - val_root_mean_squared_error: 3.7914
# Epoch 37/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.3809 - root_mean_squared_error: 3.7922 - val_loss: 14.4149 - val_root_mean_squared_error: 3.7967
# Epoch 38/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.3796 - root_mean_squared_error: 3.7920 - val_loss: 14.2150 - val_root_mean_squared_error: 3.7703
# Epoch 39/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.2552 - root_mean_squared_error: 3.7756 - val_loss: 14.0346 - val_root_mean_squared_error: 3.7463
# Epoch 40/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.2171 - root_mean_squared_error: 3.7706 - val_loss: 13.9691 - val_root_mean_squared_error: 3.7375
# Epoch 41/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.2399 - root_mean_squared_error: 3.7736 - val_loss: 13.9516 - val_root_mean_squared_error: 3.7352
# Epoch 42/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.2286 - root_mean_squared_error: 3.7721 - val_loss: 13.9518 - val_root_mean_squared_error: 3.7352
# Epoch 43/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.1667 - root_mean_squared_error: 3.7639 - val_loss: 13.9903 - val_root_mean_squared_error: 3.7404
# Epoch 44/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.1396 - root_mean_squared_error: 3.7603 - val_loss: 14.0325 - val_root_mean_squared_error: 3.7460
# Epoch 45/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.1449 - root_mean_squared_error: 3.7610 - val_loss: 14.0319 - val_root_mean_squared_error: 3.7459
# Epoch 46/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.1250 - root_mean_squared_error: 3.7583 - val_loss: 13.9596 - val_root_mean_squared_error: 3.7363
# Epoch 47/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.1164 - root_mean_squared_error: 3.7572 - val_loss: 13.8870 - val_root_mean_squared_error: 3.7265
# Epoch 48/72
# 1565/1565 [==============================] - 0s 14us/sample - loss: 14.0778 - root_mean_squared_error: 3.7520 - val_loss: 13.8646 - val_root_mean_squared_error: 3.7235
# Epoch 49/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.0620 - root_mean_squared_error: 3.7499 - val_loss: 13.8619 - val_root_mean_squared_error: 3.7232
# Epoch 50/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.0411 - root_mean_squared_error: 3.7471 - val_loss: 13.8548 - val_root_mean_squared_error: 3.7222
# Epoch 51/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 14.0317 - root_mean_squared_error: 3.7459 - val_loss: 13.8683 - val_root_mean_squared_error: 3.7240
# Epoch 52/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 14.0064 - root_mean_squared_error: 3.7425 - val_loss: 13.8383 - val_root_mean_squared_error: 3.7200
# Epoch 53/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.9908 - root_mean_squared_error: 3.7404 - val_loss: 13.8006 - val_root_mean_squared_error: 3.7149
# Epoch 54/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.9683 - root_mean_squared_error: 3.7374 - val_loss: 13.7833 - val_root_mean_squared_error: 3.7126
# Epoch 55/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 13.9508 - root_mean_squared_error: 3.7351 - val_loss: 13.7554 - val_root_mean_squared_error: 3.7088
# Epoch 56/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 13.9305 - root_mean_squared_error: 3.7324 - val_loss: 13.7426 - val_root_mean_squared_error: 3.7071
# Epoch 57/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.9111 - root_mean_squared_error: 3.7298 - val_loss: 13.7318 - val_root_mean_squared_error: 3.7056
# Epoch 58/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.8934 - root_mean_squared_error: 3.7274 - val_loss: 13.7190 - val_root_mean_squared_error: 3.7039
# Epoch 59/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.8733 - root_mean_squared_error: 3.7247 - val_loss: 13.6919 - val_root_mean_squared_error: 3.7003
# Epoch 60/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 13.8581 - root_mean_squared_error: 3.7227 - val_loss: 13.6664 - val_root_mean_squared_error: 3.6968
# Epoch 61/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.8336 - root_mean_squared_error: 3.7194 - val_loss: 13.6279 - val_root_mean_squared_error: 3.6916
# Epoch 62/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.8213 - root_mean_squared_error: 3.7177 - val_loss: 13.6020 - val_root_mean_squared_error: 3.6881
# Epoch 63/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.8088 - root_mean_squared_error: 3.7160 - val_loss: 13.6070 - val_root_mean_squared_error: 3.6888
# Epoch 64/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 13.7757 - root_mean_squared_error: 3.7116 - val_loss: 13.5889 - val_root_mean_squared_error: 3.6863
# Epoch 65/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.7538 - root_mean_squared_error: 3.7086 - val_loss: 13.5801 - val_root_mean_squared_error: 3.6851
# Epoch 66/72
# 1565/1565 [==============================] - 0s 13us/sample - loss: 13.7350 - root_mean_squared_error: 3.7061 - val_loss: 13.5589 - val_root_mean_squared_error: 3.6822
# Epoch 67/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 13.7143 - root_mean_squared_error: 3.7033 - val_loss: 13.5413 - val_root_mean_squared_error: 3.6798
# Epoch 68/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.6921 - root_mean_squared_error: 3.7003 - val_loss: 13.5065 - val_root_mean_squared_error: 3.6751
# Epoch 69/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.6720 - root_mean_squared_error: 3.6976 - val_loss: 13.4741 - val_root_mean_squared_error: 3.6707
# Epoch 70/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 13.6534 - root_mean_squared_error: 3.6950 - val_loss: 13.4353 - val_root_mean_squared_error: 3.6654
# Epoch 71/72
# 1565/1565 [==============================] - 0s 12us/sample - loss: 13.6306 - root_mean_squared_error: 3.6920 - val_loss: 13.4222 - val_root_mean_squared_error: 3.6636
# Epoch 72/72
# 1565/1565 [==============================] - 0s 11us/sample - loss: 13.6058 - root_mean_squared_error: 3.6886 - val_loss: 13.4192 - val_root_mean_squared_error: 3.6632
# Train on 1480 samples, validate on 165 samples
# Epoch 1/35
# 1480/1480 [==============================] - 0s 318us/sample - loss: 176510.7634 - root_mean_squared_error: 420.1318 - val_loss: 124799.2344 - val_root_mean_squared_error: 353.2693
# Epoch 2/35
# 1480/1480 [==============================] - 0s 22us/sample - loss: 81773.5484 - root_mean_squared_error: 285.9608 - val_loss: 53.5422 - val_root_mean_squared_error: 7.3173
# Epoch 3/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 8985.9400 - root_mean_squared_error: 94.7942 - val_loss: 12829.3701 - val_root_mean_squared_error: 113.2668
# Epoch 4/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 5373.1126 - root_mean_squared_error: 73.3015 - val_loss: 1717.8600 - val_root_mean_squared_error: 41.4471
# Epoch 5/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 2983.8289 - root_mean_squared_error: 54.6244 - val_loss: 1447.5940 - val_root_mean_squared_error: 38.0473
# Epoch 6/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 582.5336 - root_mean_squared_error: 24.1357 - val_loss: 959.0531 - val_root_mean_squared_error: 30.9686
# Epoch 7/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 909.3067 - root_mean_squared_error: 30.1547 - val_loss: 33.4342 - val_root_mean_squared_error: 5.7822
# Epoch 8/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 277.6029 - root_mean_squared_error: 16.6614 - val_loss: 252.3919 - val_root_mean_squared_error: 15.8868
# Epoch 9/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 124.7722 - root_mean_squared_error: 11.1701 - val_loss: 270.9573 - val_root_mean_squared_error: 16.4608
# Epoch 10/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 168.9233 - root_mean_squared_error: 12.9971 - val_loss: 22.3393 - val_root_mean_squared_error: 4.7264
# Epoch 11/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 74.9662 - root_mean_squared_error: 8.6583 - val_loss: 63.8888 - val_root_mean_squared_error: 7.9930
# Epoch 12/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 38.8651 - root_mean_squared_error: 6.2342 - val_loss: 66.3605 - val_root_mean_squared_error: 8.1462
# Epoch 13/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 55.7087 - root_mean_squared_error: 7.4638 - val_loss: 17.7231 - val_root_mean_squared_error: 4.2099
# Epoch 14/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 28.4030 - root_mean_squared_error: 5.3295 - val_loss: 34.0130 - val_root_mean_squared_error: 5.8321
# Epoch 15/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 25.9269 - root_mean_squared_error: 5.0918 - val_loss: 27.8395 - val_root_mean_squared_error: 5.2763
# Epoch 16/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 28.1828 - root_mean_squared_error: 5.3088 - val_loss: 16.9373 - val_root_mean_squared_error: 4.1155
# Epoch 17/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 20.2942 - root_mean_squared_error: 4.5049 - val_loss: 20.4639 - val_root_mean_squared_error: 4.5237
# Epoch 18/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 18.8716 - root_mean_squared_error: 4.3441 - val_loss: 20.2024 - val_root_mean_squared_error: 4.4947
# Epoch 19/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 20.0234 - root_mean_squared_error: 4.4748 - val_loss: 15.0933 - val_root_mean_squared_error: 3.8850
# Epoch 20/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 17.3234 - root_mean_squared_error: 4.1621 - val_loss: 15.7070 - val_root_mean_squared_error: 3.9632
# Epoch 21/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 16.1694 - root_mean_squared_error: 4.0211 - val_loss: 16.7080 - val_root_mean_squared_error: 4.0875
# Epoch 22/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 15.9697 - root_mean_squared_error: 3.9962 - val_loss: 13.4877 - val_root_mean_squared_error: 3.6726
# Epoch 23/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 15.4276 - root_mean_squared_error: 3.9278 - val_loss: 13.3323 - val_root_mean_squared_error: 3.6513
# Epoch 24/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 14.6787 - root_mean_squared_error: 3.8313 - val_loss: 14.7803 - val_root_mean_squared_error: 3.8445
# Epoch 25/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 14.2640 - root_mean_squared_error: 3.7768 - val_loss: 13.0172 - val_root_mean_squared_error: 3.6079
# Epoch 26/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 14.4990 - root_mean_squared_error: 3.8078 - val_loss: 12.8338 - val_root_mean_squared_error: 3.5824
# Epoch 27/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 13.8429 - root_mean_squared_error: 3.7206 - val_loss: 12.9439 - val_root_mean_squared_error: 3.5978
# Epoch 28/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 13.3247 - root_mean_squared_error: 3.6503 - val_loss: 12.1668 - val_root_mean_squared_error: 3.4881
# Epoch 29/35
# 1480/1480 [==============================] - 0s 23us/sample - loss: 13.0950 - root_mean_squared_error: 3.6187 - val_loss: 12.3569 - val_root_mean_squared_error: 3.5152
# Epoch 30/35
# 1480/1480 [==============================] - 0s 25us/sample - loss: 12.8724 - root_mean_squared_error: 3.5878 - val_loss: 11.4900 - val_root_mean_squared_error: 3.3897
# Epoch 31/35
# 1480/1480 [==============================] - 0s 26us/sample - loss: 12.2426 - root_mean_squared_error: 3.4989 - val_loss: 10.9542 - val_root_mean_squared_error: 3.3097
# Epoch 32/35
# 1480/1480 [==============================] - 0s 26us/sample - loss: 11.8727 - root_mean_squared_error: 3.4457 - val_loss: 10.8667 - val_root_mean_squared_error: 3.2965
# Epoch 33/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 11.4134 - root_mean_squared_error: 3.3784 - val_loss: 10.0803 - val_root_mean_squared_error: 3.1749
# Epoch 34/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 10.9995 - root_mean_squared_error: 3.3165 - val_loss: 10.0401 - val_root_mean_squared_error: 3.1686
# Epoch 35/35
# 1480/1480 [==============================] - 0s 24us/sample - loss: 10.6548 - root_mean_squared_error: 3.2642 - val_loss: 9.4405 - val_root_mean_squared_error: 3.0725
# Train on 1498 samples, validate on 167 samples
# Epoch 1/88
# 1498/1498 [==============================] - 0s 325us/sample - loss: 95787.6030 - root_mean_squared_error: 309.4957 - val_loss: 137622.7500 - val_root_mean_squared_error: 370.9754
# Epoch 2/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 80775.9390 - root_mean_squared_error: 284.2111 - val_loss: 11079.7451 - val_root_mean_squared_error: 105.2604
# Epoch 3/88
# 1498/1498 [==============================] - 0s 19us/sample - loss: 33240.1747 - root_mean_squared_error: 182.3189 - val_loss: 22534.8086 - val_root_mean_squared_error: 150.1160
# Epoch 4/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 9012.4142 - root_mean_squared_error: 94.9337 - val_loss: 11298.9102 - val_root_mean_squared_error: 106.2963
# Epoch 5/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14774.0929 - root_mean_squared_error: 121.5487 - val_loss: 6935.1514 - val_root_mean_squared_error: 83.2776
# Epoch 6/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 2752.2253 - root_mean_squared_error: 52.4617 - val_loss: 4058.0613 - val_root_mean_squared_error: 63.7029
# Epoch 7/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 5480.2656 - root_mean_squared_error: 74.0288 - val_loss: 2804.6750 - val_root_mean_squared_error: 52.9592
# Epoch 8/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 1167.7745 - root_mean_squared_error: 34.1727 - val_loss: 983.2345 - val_root_mean_squared_error: 31.3566
# Epoch 9/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 1712.8277 - root_mean_squared_error: 41.3863 - val_loss: 1508.8330 - val_root_mean_squared_error: 38.8437
# Epoch 10/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 728.1434 - root_mean_squared_error: 26.9841 - val_loss: 184.6700 - val_root_mean_squared_error: 13.5893
# Epoch 11/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 558.2720 - root_mean_squared_error: 23.6278 - val_loss: 763.0508 - val_root_mean_squared_error: 27.6234
# Epoch 12/88
# 1498/1498 [==============================] - 0s 19us/sample - loss: 443.8061 - root_mean_squared_error: 21.0667 - val_loss: 38.9515 - val_root_mean_squared_error: 6.2411
# Epoch 13/88
# 1498/1498 [==============================] - 0s 19us/sample - loss: 185.8486 - root_mean_squared_error: 13.6326 - val_loss: 387.5937 - val_root_mean_squared_error: 19.6874
# Epoch 14/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 241.9891 - root_mean_squared_error: 15.5560 - val_loss: 18.2805 - val_root_mean_squared_error: 4.2756
# Epoch 15/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 79.7219 - root_mean_squared_error: 8.9287 - val_loss: 176.1368 - val_root_mean_squared_error: 13.2717
# Epoch 16/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 124.9305 - root_mean_squared_error: 11.1772 - val_loss: 17.9729 - val_root_mean_squared_error: 4.2394
# Epoch 17/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 43.7818 - root_mean_squared_error: 6.6168 - val_loss: 94.4657 - val_root_mean_squared_error: 9.7193
# Epoch 18/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 63.3623 - root_mean_squared_error: 7.9600 - val_loss: 17.5306 - val_root_mean_squared_error: 4.1870
# Epoch 19/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 31.9510 - root_mean_squared_error: 5.6525 - val_loss: 47.0098 - val_root_mean_squared_error: 6.8564
# Epoch 20/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 36.3931 - root_mean_squared_error: 6.0327 - val_loss: 18.7326 - val_root_mean_squared_error: 4.3281
# Epoch 21/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 26.2682 - root_mean_squared_error: 5.1252 - val_loss: 31.8900 - val_root_mean_squared_error: 5.6471
# Epoch 22/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 23.4255 - root_mean_squared_error: 4.8400 - val_loss: 18.6091 - val_root_mean_squared_error: 4.3138
# Epoch 23/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 22.2158 - root_mean_squared_error: 4.7134 - val_loss: 20.0770 - val_root_mean_squared_error: 4.4807
# Epoch 24/88
# 1498/1498 [==============================] - 0s 24us/sample - loss: 18.6941 - root_mean_squared_error: 4.3237 - val_loss: 19.2545 - val_root_mean_squared_error: 4.3880
# Epoch 25/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 19.6464 - root_mean_squared_error: 4.4324 - val_loss: 18.2043 - val_root_mean_squared_error: 4.2667
# Epoch 26/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 17.0091 - root_mean_squared_error: 4.1242 - val_loss: 16.9775 - val_root_mean_squared_error: 4.1204
# Epoch 27/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 17.6726 - root_mean_squared_error: 4.2039 - val_loss: 16.2858 - val_root_mean_squared_error: 4.0356
# Epoch 28/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 16.6863 - root_mean_squared_error: 4.0849 - val_loss: 17.2927 - val_root_mean_squared_error: 4.1584
# Epoch 29/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 16.8361 - root_mean_squared_error: 4.1032 - val_loss: 16.0068 - val_root_mean_squared_error: 4.0008
# Epoch 30/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 16.6542 - root_mean_squared_error: 4.0810 - val_loss: 15.9563 - val_root_mean_squared_error: 3.9945
# Epoch 31/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 16.2718 - root_mean_squared_error: 4.0338 - val_loss: 16.2125 - val_root_mean_squared_error: 4.0265
# Epoch 32/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 16.1767 - root_mean_squared_error: 4.0220 - val_loss: 15.6805 - val_root_mean_squared_error: 3.9599
# Epoch 33/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 15.9270 - root_mean_squared_error: 3.9909 - val_loss: 15.5040 - val_root_mean_squared_error: 3.9375
# Epoch 34/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 15.8513 - root_mean_squared_error: 3.9814 - val_loss: 15.5674 - val_root_mean_squared_error: 3.9456
# Epoch 35/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 15.6941 - root_mean_squared_error: 3.9616 - val_loss: 15.2996 - val_root_mean_squared_error: 3.9115
# Epoch 36/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 15.5669 - root_mean_squared_error: 3.9455 - val_loss: 15.1440 - val_root_mean_squared_error: 3.8915
# Epoch 37/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 15.4388 - root_mean_squared_error: 3.9292 - val_loss: 15.0877 - val_root_mean_squared_error: 3.8843
# Epoch 38/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 15.3183 - root_mean_squared_error: 3.9139 - val_loss: 14.9442 - val_root_mean_squared_error: 3.8658
# Epoch 39/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 15.2064 - root_mean_squared_error: 3.8995 - val_loss: 14.8375 - val_root_mean_squared_error: 3.8519
# Epoch 40/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 15.1097 - root_mean_squared_error: 3.8871 - val_loss: 14.7081 - val_root_mean_squared_error: 3.8351
# Epoch 41/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 14.9937 - root_mean_squared_error: 3.8722 - val_loss: 14.5810 - val_root_mean_squared_error: 3.8185
# Epoch 42/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.8980 - root_mean_squared_error: 3.8598 - val_loss: 14.5284 - val_root_mean_squared_error: 3.8116
# Epoch 43/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.8014 - root_mean_squared_error: 3.8473 - val_loss: 14.4415 - val_root_mean_squared_error: 3.8002
# Epoch 44/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.6788 - root_mean_squared_error: 3.8313 - val_loss: 14.2762 - val_root_mean_squared_error: 3.7784
# Epoch 45/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.5693 - root_mean_squared_error: 3.8170 - val_loss: 14.1803 - val_root_mean_squared_error: 3.7657
# Epoch 46/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.5038 - root_mean_squared_error: 3.8084 - val_loss: 14.1097 - val_root_mean_squared_error: 3.7563
# Epoch 47/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.3877 - root_mean_squared_error: 3.7931 - val_loss: 13.9799 - val_root_mean_squared_error: 3.7390
# Epoch 48/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.3152 - root_mean_squared_error: 3.7835 - val_loss: 13.8512 - val_root_mean_squared_error: 3.7217
# Epoch 49/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 14.2099 - root_mean_squared_error: 3.7696 - val_loss: 13.8156 - val_root_mean_squared_error: 3.7169
# Epoch 50/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.0705 - root_mean_squared_error: 3.7511 - val_loss: 13.6048 - val_root_mean_squared_error: 3.6885
# Epoch 51/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 14.0407 - root_mean_squared_error: 3.7471 - val_loss: 13.6000 - val_root_mean_squared_error: 3.6878
# Epoch 52/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.9537 - root_mean_squared_error: 3.7355 - val_loss: 13.6599 - val_root_mean_squared_error: 3.6959
# Epoch 53/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.8312 - root_mean_squared_error: 3.7190 - val_loss: 13.3093 - val_root_mean_squared_error: 3.6482
# Epoch 54/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.7630 - root_mean_squared_error: 3.7098 - val_loss: 13.2846 - val_root_mean_squared_error: 3.6448
# Epoch 55/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.6700 - root_mean_squared_error: 3.6973 - val_loss: 13.1858 - val_root_mean_squared_error: 3.6312
# Epoch 56/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 13.6217 - root_mean_squared_error: 3.6908 - val_loss: 13.0244 - val_root_mean_squared_error: 3.6089
# Epoch 57/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.4437 - root_mean_squared_error: 3.6666 - val_loss: 13.1879 - val_root_mean_squared_error: 3.6315
# Epoch 58/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 13.4318 - root_mean_squared_error: 3.6649 - val_loss: 12.8499 - val_root_mean_squared_error: 3.5847
# Epoch 59/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.3071 - root_mean_squared_error: 3.6479 - val_loss: 12.7615 - val_root_mean_squared_error: 3.5723
# Epoch 60/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.2057 - root_mean_squared_error: 3.6340 - val_loss: 12.7822 - val_root_mean_squared_error: 3.5752
# Epoch 61/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 13.1408 - root_mean_squared_error: 3.6250 - val_loss: 12.5854 - val_root_mean_squared_error: 3.5476
# Epoch 62/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 13.0715 - root_mean_squared_error: 3.6154 - val_loss: 12.5140 - val_root_mean_squared_error: 3.5375
# Epoch 63/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 12.9818 - root_mean_squared_error: 3.6030 - val_loss: 12.3983 - val_root_mean_squared_error: 3.5211
# Epoch 64/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 12.9984 - root_mean_squared_error: 3.6053 - val_loss: 12.4910 - val_root_mean_squared_error: 3.5343
# Epoch 65/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 12.8286 - root_mean_squared_error: 3.5817 - val_loss: 12.2233 - val_root_mean_squared_error: 3.4962
# Epoch 66/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 12.7360 - root_mean_squared_error: 3.5688 - val_loss: 12.2424 - val_root_mean_squared_error: 3.4989
# Epoch 67/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 12.7027 - root_mean_squared_error: 3.5641 - val_loss: 12.1223 - val_root_mean_squared_error: 3.4817
# Epoch 68/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 12.5753 - root_mean_squared_error: 3.5462 - val_loss: 11.9697 - val_root_mean_squared_error: 3.4597
# Epoch 69/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 12.5011 - root_mean_squared_error: 3.5357 - val_loss: 12.0969 - val_root_mean_squared_error: 3.4781
# Epoch 70/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 12.4856 - root_mean_squared_error: 3.5335 - val_loss: 11.8059 - val_root_mean_squared_error: 3.4360
# Epoch 71/88
# 1498/1498 [==============================] - 0s 22us/sample - loss: 12.4169 - root_mean_squared_error: 3.5238 - val_loss: 11.7207 - val_root_mean_squared_error: 3.4235
# Epoch 72/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 12.3018 - root_mean_squared_error: 3.5074 - val_loss: 11.7700 - val_root_mean_squared_error: 3.4307
# Epoch 73/88
# 1498/1498 [==============================] - 0s 23us/sample - loss: 12.2463 - root_mean_squared_error: 3.4995 - val_loss: 11.5731 - val_root_mean_squared_error: 3.4019
# Epoch 74/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 12.1206 - root_mean_squared_error: 3.4815 - val_loss: 11.4740 - val_root_mean_squared_error: 3.3873
# Epoch 75/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 12.0835 - root_mean_squared_error: 3.4761 - val_loss: 11.4533 - val_root_mean_squared_error: 3.3843
# Epoch 76/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.9477 - root_mean_squared_error: 3.4565 - val_loss: 11.3165 - val_root_mean_squared_error: 3.3640
# Epoch 77/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.9822 - root_mean_squared_error: 3.4615 - val_loss: 11.2968 - val_root_mean_squared_error: 3.3611
# Epoch 78/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.8046 - root_mean_squared_error: 3.4358 - val_loss: 11.1485 - val_root_mean_squared_error: 3.3389
# Epoch 79/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.7393 - root_mean_squared_error: 3.4263 - val_loss: 11.2243 - val_root_mean_squared_error: 3.3503
# Epoch 80/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.8000 - root_mean_squared_error: 3.4351 - val_loss: 11.0085 - val_root_mean_squared_error: 3.3179
# Epoch 81/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.6499 - root_mean_squared_error: 3.4132 - val_loss: 10.9128 - val_root_mean_squared_error: 3.3035
# Epoch 82/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.4832 - root_mean_squared_error: 3.3887 - val_loss: 11.1650 - val_root_mean_squared_error: 3.3414
# Epoch 83/88
# 1498/1498 [==============================] - 0s 20us/sample - loss: 11.5923 - root_mean_squared_error: 3.4048 - val_loss: 10.7599 - val_root_mean_squared_error: 3.2802
# Epoch 84/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.4513 - root_mean_squared_error: 3.3840 - val_loss: 10.6798 - val_root_mean_squared_error: 3.2680
# Epoch 85/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.3637 - root_mean_squared_error: 3.3710 - val_loss: 10.8207 - val_root_mean_squared_error: 3.2895
# Epoch 86/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.2675 - root_mean_squared_error: 3.3567 - val_loss: 10.5331 - val_root_mean_squared_error: 3.2455
# Epoch 87/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.1536 - root_mean_squared_error: 3.3397 - val_loss: 10.6699 - val_root_mean_squared_error: 3.2665
# Epoch 88/88
# 1498/1498 [==============================] - 0s 21us/sample - loss: 11.1540 - root_mean_squared_error: 3.3398 - val_loss: 10.3672 - val_root_mean_squared_error: 3.2198
# Train on 1485 samples, validate on 166 samples
# Epoch 1/38
# 1485/1485 [==============================] - 0s 270us/sample - loss: 97185.8389 - root_mean_squared_error: 311.7464 - val_loss: 40677.9805 - val_root_mean_squared_error: 201.6878
# Epoch 2/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 34289.0568 - root_mean_squared_error: 185.1730 - val_loss: 42215.9102 - val_root_mean_squared_error: 205.4651
# Epoch 3/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 40284.1885 - root_mean_squared_error: 200.7092 - val_loss: 4037.1033 - val_root_mean_squared_error: 63.5382
# Epoch 4/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 3933.7291 - root_mean_squared_error: 62.7194 - val_loss: 15879.2031 - val_root_mean_squared_error: 126.0127
# Epoch 5/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 15874.5939 - root_mean_squared_error: 125.9944 - val_loss: 6703.5625 - val_root_mean_squared_error: 81.8753
# Epoch 6/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 5527.4569 - root_mean_squared_error: 74.3469 - val_loss: 3127.1760 - val_root_mean_squared_error: 55.9212
# Epoch 7/38
# 1485/1485 [==============================] - 0s 16us/sample - loss: 3956.5774 - root_mean_squared_error: 62.9013 - val_loss: 6871.0210 - val_root_mean_squared_error: 82.8916
# Epoch 8/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 6111.7993 - root_mean_squared_error: 78.1780 - val_loss: 14.3614 - val_root_mean_squared_error: 3.7896
# Epoch 9/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 340.3647 - root_mean_squared_error: 18.4490 - val_loss: 4285.4097 - val_root_mean_squared_error: 65.4630
# Epoch 10/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 4112.6041 - root_mean_squared_error: 64.1296 - val_loss: 1036.6219 - val_root_mean_squared_error: 32.1966
# Epoch 11/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 850.7272 - root_mean_squared_error: 29.1672 - val_loss: 1284.7987 - val_root_mean_squared_error: 35.8441
# Epoch 12/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 1506.1176 - root_mean_squared_error: 38.8087 - val_loss: 1894.3757 - val_root_mean_squared_error: 43.5244
# Epoch 13/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 1665.7602 - root_mean_squared_error: 40.8137 - val_loss: 58.7654 - val_root_mean_squared_error: 7.6659
# Epoch 14/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 190.0430 - root_mean_squared_error: 13.7856 - val_loss: 1417.3213 - val_root_mean_squared_error: 37.6473
# Epoch 15/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 1309.0372 - root_mean_squared_error: 36.1806 - val_loss: 139.9813 - val_root_mean_squared_error: 11.8314
# Epoch 16/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 132.7900 - root_mean_squared_error: 11.5235 - val_loss: 640.3637 - val_root_mean_squared_error: 25.3054
# Epoch 17/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 675.6675 - root_mean_squared_error: 25.9936 - val_loss: 344.8065 - val_root_mean_squared_error: 18.5690
# Epoch 18/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 298.7982 - root_mean_squared_error: 17.2858 - val_loss: 180.6824 - val_root_mean_squared_error: 13.4418
# Epoch 19/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 225.2218 - root_mean_squared_error: 15.0074 - val_loss: 434.2639 - val_root_mean_squared_error: 20.8390
# Epoch 20/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 373.7285 - root_mean_squared_error: 19.3321 - val_loss: 13.2316 - val_root_mean_squared_error: 3.6375
# Epoch 21/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 42.2747 - root_mean_squared_error: 6.5019 - val_loss: 307.1334 - val_root_mean_squared_error: 17.5252
# Epoch 22/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 298.6219 - root_mean_squared_error: 17.2807 - val_loss: 34.3538 - val_root_mean_squared_error: 5.8612
# Epoch 23/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 37.9331 - root_mean_squared_error: 6.1590 - val_loss: 167.8381 - val_root_mean_squared_error: 12.9552
# Epoch 24/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 166.4061 - root_mean_squared_error: 12.8998 - val_loss: 91.4606 - val_root_mean_squared_error: 9.5635
# Epoch 25/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 74.0839 - root_mean_squared_error: 8.6072 - val_loss: 54.3044 - val_root_mean_squared_error: 7.3692
# Epoch 26/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 70.6240 - root_mean_squared_error: 8.4038 - val_loss: 93.6611 - val_root_mean_squared_error: 9.6779
# Epoch 27/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 87.2606 - root_mean_squared_error: 9.3413 - val_loss: 18.7826 - val_root_mean_squared_error: 4.3339
# Epoch 28/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 25.9559 - root_mean_squared_error: 5.0947 - val_loss: 86.1404 - val_root_mean_squared_error: 9.2812
# Epoch 29/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 75.0037 - root_mean_squared_error: 8.6605 - val_loss: 9.7103 - val_root_mean_squared_error: 3.1161
# Epoch 30/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 14.2463 - root_mean_squared_error: 3.7744 - val_loss: 53.4549 - val_root_mean_squared_error: 7.3113
# Epoch 31/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 54.9244 - root_mean_squared_error: 7.4111 - val_loss: 11.3673 - val_root_mean_squared_error: 3.3715
# Epoch 32/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 13.7445 - root_mean_squared_error: 3.7074 - val_loss: 40.5267 - val_root_mean_squared_error: 6.3661
# Epoch 33/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 38.0374 - root_mean_squared_error: 6.1674 - val_loss: 16.6998 - val_root_mean_squared_error: 4.0865
# Epoch 34/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 15.4995 - root_mean_squared_error: 3.9369 - val_loss: 21.5048 - val_root_mean_squared_error: 4.6373
# Epoch 35/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 24.8326 - root_mean_squared_error: 4.9832 - val_loss: 14.1617 - val_root_mean_squared_error: 3.7632
# Epoch 36/38
# 1485/1485 [==============================] - 0s 17us/sample - loss: 15.1704 - root_mean_squared_error: 3.8949 - val_loss: 17.8825 - val_root_mean_squared_error: 4.2288
# Epoch 37/38
# 1485/1485 [==============================] - 0s 18us/sample - loss: 18.0231 - root_mean_squared_error: 4.2454 - val_loss: 15.3969 - val_root_mean_squared_error: 3.9239
# Epoch 38/38
# 1485/1485 [==============================] - 0s 19us/sample - loss: 14.2716 - root_mean_squared_error: 3.7778 - val_loss: 11.5513 - val_root_mean_squared_error: 3.3987
# Train on 1476 samples, validate on 165 samples
# Epoch 1/9
# 1476/1476 [==============================] - 0s 283us/sample - loss: 134141.8193 - root_mean_squared_error: 366.2538 - val_loss: 51073.4805 - val_root_mean_squared_error: 225.9944
# Epoch 2/9
# 1476/1476 [==============================] - 0s 23us/sample - loss: 38414.9830 - root_mean_squared_error: 195.9974 - val_loss: 6913.7559 - val_root_mean_squared_error: 83.1490
# Epoch 3/9
# 1476/1476 [==============================] - 0s 24us/sample - loss: 14108.9926 - root_mean_squared_error: 118.7813 - val_loss: 1530.4337 - val_root_mean_squared_error: 39.1208
# Epoch 4/9
# 1476/1476 [==============================] - 0s 24us/sample - loss: 2438.6258 - root_mean_squared_error: 49.3824 - val_loss: 6928.5298 - val_root_mean_squared_error: 83.2378
# Epoch 5/9
# 1476/1476 [==============================] - 0s 24us/sample - loss: 3505.6488 - root_mean_squared_error: 59.2085 - val_loss: 1831.5323 - val_root_mean_squared_error: 42.7964
# Epoch 6/9
# 1476/1476 [==============================] - 0s 23us/sample - loss: 2295.6669 - root_mean_squared_error: 47.9131 - val_loss: 70.7193 - val_root_mean_squared_error: 8.4095
# Epoch 7/9
# 1476/1476 [==============================] - 0s 24us/sample - loss: 547.5969 - root_mean_squared_error: 23.4008 - val_loss: 889.0551 - val_root_mean_squared_error: 29.8170
# Epoch 8/9
# 1476/1476 [==============================] - 0s 24us/sample - loss: 377.9672 - root_mean_squared_error: 19.4414 - val_loss: 739.5061 - val_root_mean_squared_error: 27.1939
# Epoch 9/9
# 1476/1476 [==============================] - 0s 25us/sample - loss: 519.8576 - root_mean_squared_error: 22.8004 - val_loss: 63.7802 - val_root_mean_squared_error: 7.9862
# Train on 1551 samples, validate on 173 samples
# Epoch 1/53
# 1551/1551 [==============================] - 0s 314us/sample - loss: 394.2159 - root_mean_squared_error: 19.8549 - val_loss: 457935.8125 - val_root_mean_squared_error: 676.7095
# Epoch 2/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 456584.6250 - root_mean_squared_error: 675.7104 - val_loss: 39675.5117 - val_root_mean_squared_error: 199.1871
# Epoch 3/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 39610.7656 - root_mean_squared_error: 199.0245 - val_loss: 43949.0586 - val_root_mean_squared_error: 209.6403
# Epoch 4/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 43661.6289 - root_mean_squared_error: 208.9537 - val_loss: 122205.5938 - val_root_mean_squared_error: 349.5792
# Epoch 5/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 121620.2891 - root_mean_squared_error: 348.7410 - val_loss: 114746.9922 - val_root_mean_squared_error: 338.7433
# Epoch 6/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 114209.6953 - root_mean_squared_error: 337.9492 - val_loss: 60730.6719 - val_root_mean_squared_error: 246.4359
# Epoch 7/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 60428.2656 - root_mean_squared_error: 245.8216 - val_loss: 14367.5430 - val_root_mean_squared_error: 119.8647
# Epoch 8/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 14274.9336 - root_mean_squared_error: 119.4778 - val_loss: 130.3770 - val_root_mean_squared_error: 11.4183
# Epoch 9/53
# 1551/1551 [==============================] - 0s 11us/sample - loss: 133.9161 - root_mean_squared_error: 11.5722 - val_loss: 13573.9785 - val_root_mean_squared_error: 116.5074
# Epoch 10/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 13561.4092 - root_mean_squared_error: 116.4535 - val_loss: 32666.0117 - val_root_mean_squared_error: 180.7374
# Epoch 11/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 32601.6758 - root_mean_squared_error: 180.5593 - val_loss: 39808.6992 - val_root_mean_squared_error: 199.5212
# Epoch 12/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 39726.4648 - root_mean_squared_error: 199.3150 - val_loss: 31909.6426 - val_root_mean_squared_error: 178.6327
# Epoch 13/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 31840.0234 - root_mean_squared_error: 178.4377 - val_loss: 16655.3027 - val_root_mean_squared_error: 129.0554
# Epoch 14/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 16633.2090 - root_mean_squared_error: 128.9698 - val_loss: 4002.6738 - val_root_mean_squared_error: 63.2667
# Epoch 15/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 4007.9497 - root_mean_squared_error: 63.3084 - val_loss: 45.9118 - val_root_mean_squared_error: 6.7758
# Epoch 16/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 44.7408 - root_mean_squared_error: 6.6889 - val_loss: 4277.3213 - val_root_mean_squared_error: 65.4012
# Epoch 17/53
# 1551/1551 [==============================] - 0s 12us/sample - loss: 4241.3564 - root_mean_squared_error: 65.1257 - val_loss: 10903.4482 - val_root_mean_squared_error: 104.4196
# Epoch 18/53
# 1551/1551 [==============================] - 0s 13us/sample - loss: 10830.0156 - root_mean_squared_error: 104.0674 - val_loss: 14284.1787 - val_root_mean_squared_error: 119.5164
# Epoch 19/53
# 1551/1551 [==============================] - 0s 13us/sample - loss: 14193.0059 - root_mean_squared_error: 119.1344 - val_loss: 12668.9062 - val_root_mean_squared_error: 112.5562
# Epoch 20/53
# ...
# Epoch 78/82
# 1442/1442 [==============================] - 1s 411us/sample - loss: 0.2481 - root_mean_squared_error: 0.4981 - val_loss: 0.6425 - val_root_mean_squared_error: 0.8016
# Epoch 79/82
# 1442/1442 [==============================] - 1s 379us/sample - loss: 0.3238 - root_mean_squared_error: 0.5690 - val_loss: 0.7162 - val_root_mean_squared_error: 0.8463
# Epoch 80/82
# 1442/1442 [==============================] - 1s 368us/sample - loss: 0.3915 - root_mean_squared_error: 0.6257 - val_loss: 0.4073 - val_root_mean_squared_error: 0.6382
# Epoch 81/82
# 1442/1442 [==============================] - 1s 407us/sample - loss: 0.3149 - root_mean_squared_error: 0.5611 - val_loss: 0.0971 - val_root_mean_squared_error: 0.3116
# Epoch 82/82
# 1442/1442 [==============================] - 1s 378us/sample - loss: 0.2038 - root_mean_squared_error: 0.4515 - val_loss: 0.2902 - val_root_mean_squared_error: 0.5387
# |  11       | -0.651    |  11.12    |  82.28    |  513.4    |  537.6    |  738.9    |  189.1    |
# Train on 1517 samples, validate on 169 samples
# Epoch 1/72
# 1517/1517 [==============================] - 1s 458us/sample - loss: 23157.4285 - root_mean_squared_error: 152.1756 - val_loss: 25.9935 - val_root_mean_squared_error: 5.0984
# Epoch 2/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 46.6433 - root_mean_squared_error: 6.8296 - val_loss: 23.0676 - val_root_mean_squared_error: 4.8029
# Epoch 3/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 16.2986 - root_mean_squared_error: 4.0371 - val_loss: 12.4818 - val_root_mean_squared_error: 3.5330
# Epoch 4/72
# 1517/1517 [==============================] - 0s 80us/sample - loss: 13.4235 - root_mean_squared_error: 3.6638 - val_loss: 11.7572 - val_root_mean_squared_error: 3.4289
# Epoch 5/72
# 1517/1517 [==============================] - 0s 76us/sample - loss: 11.2956 - root_mean_squared_error: 3.3609 - val_loss: 9.5636 - val_root_mean_squared_error: 3.0925
# Epoch 6/72
# 1517/1517 [==============================] - 0s 99us/sample - loss: 9.2953 - root_mean_squared_error: 3.0488 - val_loss: 7.8979 - val_root_mean_squared_error: 2.8103
# Epoch 7/72
# 1517/1517 [==============================] - 0s 81us/sample - loss: 8.5465 - root_mean_squared_error: 2.9234 - val_loss: 7.6334 - val_root_mean_squared_error: 2.7629
# Epoch 8/72
# 1517/1517 [==============================] - 0s 78us/sample - loss: 6.6208 - root_mean_squared_error: 2.5731 - val_loss: 5.6664 - val_root_mean_squared_error: 2.3804
# Epoch 9/72
# 1517/1517 [==============================] - 0s 73us/sample - loss: 7.2033 - root_mean_squared_error: 2.6839 - val_loss: 4.5699 - val_root_mean_squared_error: 2.1377
# Epoch 10/72
# 1517/1517 [==============================] - 0s 73us/sample - loss: 5.6030 - root_mean_squared_error: 2.3671 - val_loss: 3.4872 - val_root_mean_squared_error: 1.8674
# Epoch 11/72
# 1517/1517 [==============================] - 0s 70us/sample - loss: 4.0668 - root_mean_squared_error: 2.0166 - val_loss: 3.5972 - val_root_mean_squared_error: 1.8966
# Epoch 12/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 3.8411 - root_mean_squared_error: 1.9599 - val_loss: 2.7105 - val_root_mean_squared_error: 1.6464
# Epoch 13/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 3.4326 - root_mean_squared_error: 1.8527 - val_loss: 2.4656 - val_root_mean_squared_error: 1.5702
# Epoch 14/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 3.1123 - root_mean_squared_error: 1.7642 - val_loss: 6.4421 - val_root_mean_squared_error: 2.5381
# Epoch 15/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 3.4979 - root_mean_squared_error: 1.8703 - val_loss: 2.5914 - val_root_mean_squared_error: 1.6098
# Epoch 16/72
# 1517/1517 [==============================] - 0s 65us/sample - loss: 2.8212 - root_mean_squared_error: 1.6796 - val_loss: 2.7497 - val_root_mean_squared_error: 1.6582
# Epoch 17/72
# 1517/1517 [==============================] - 0s 65us/sample - loss: 2.3778 - root_mean_squared_error: 1.5420 - val_loss: 2.4048 - val_root_mean_squared_error: 1.5507
# Epoch 18/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 3.1909 - root_mean_squared_error: 1.7863 - val_loss: 2.8934 - val_root_mean_squared_error: 1.7010
# Epoch 19/72
# 1517/1517 [==============================] - 0s 64us/sample - loss: 2.5485 - root_mean_squared_error: 1.5964 - val_loss: 1.6785 - val_root_mean_squared_error: 1.2956
# Epoch 20/72
# 1517/1517 [==============================] - 0s 64us/sample - loss: 2.9377 - root_mean_squared_error: 1.7140 - val_loss: 3.2415 - val_root_mean_squared_error: 1.8004
# Epoch 21/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 2.3905 - root_mean_squared_error: 1.5461 - val_loss: 1.5001 - val_root_mean_squared_error: 1.2248
# Epoch 22/72
# 1517/1517 [==============================] - 0s 65us/sample - loss: 2.3672 - root_mean_squared_error: 1.5386 - val_loss: 5.6751 - val_root_mean_squared_error: 2.3822
# Epoch 23/72
# 1517/1517 [==============================] - 0s 77us/sample - loss: 3.7880 - root_mean_squared_error: 1.9463 - val_loss: 2.8230 - val_root_mean_squared_error: 1.6802
# Epoch 24/72
# 1517/1517 [==============================] - 0s 77us/sample - loss: 2.7823 - root_mean_squared_error: 1.6680 - val_loss: 1.4992 - val_root_mean_squared_error: 1.2244
# Epoch 25/72
# 1517/1517 [==============================] - 0s 68us/sample - loss: 2.9245 - root_mean_squared_error: 1.7101 - val_loss: 4.1387 - val_root_mean_squared_error: 2.0344
# Epoch 26/72
# 1517/1517 [==============================] - 0s 73us/sample - loss: 3.1363 - root_mean_squared_error: 1.7710 - val_loss: 1.5062 - val_root_mean_squared_error: 1.2273
# Epoch 27/72
# 1517/1517 [==============================] - 0s 74us/sample - loss: 2.3156 - root_mean_squared_error: 1.5217 - val_loss: 1.7683 - val_root_mean_squared_error: 1.3298
# Epoch 28/72
# 1517/1517 [==============================] - 0s 73us/sample - loss: 2.0175 - root_mean_squared_error: 1.4204 - val_loss: 1.2012 - val_root_mean_squared_error: 1.0960
# Epoch 29/72
# 1517/1517 [==============================] - 0s 72us/sample - loss: 1.3125 - root_mean_squared_error: 1.1456 - val_loss: 1.3466 - val_root_mean_squared_error: 1.1604
# Epoch 30/72
# 1517/1517 [==============================] - 0s 68us/sample - loss: 2.0707 - root_mean_squared_error: 1.4390 - val_loss: 1.3142 - val_root_mean_squared_error: 1.1464
# Epoch 31/72
# 1517/1517 [==============================] - 0s 96us/sample - loss: 2.1434 - root_mean_squared_error: 1.4640 - val_loss: 1.0100 - val_root_mean_squared_error: 1.0050
# Epoch 32/72
# 1517/1517 [==============================] - 0s 69us/sample - loss: 1.4156 - root_mean_squared_error: 1.1898 - val_loss: 0.9875 - val_root_mean_squared_error: 0.9937
# Epoch 33/72
# 1517/1517 [==============================] - 0s 69us/sample - loss: 1.1727 - root_mean_squared_error: 1.0829 - val_loss: 2.0404 - val_root_mean_squared_error: 1.4284
# Epoch 34/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 2.2388 - root_mean_squared_error: 1.4963 - val_loss: 2.0724 - val_root_mean_squared_error: 1.4396
# Epoch 35/72
# 1517/1517 [==============================] - 0s 70us/sample - loss: 1.6268 - root_mean_squared_error: 1.2755 - val_loss: 1.3690 - val_root_mean_squared_error: 1.1701
# Epoch 36/72
# 1517/1517 [==============================] - 0s 70us/sample - loss: 1.7105 - root_mean_squared_error: 1.3078 - val_loss: 3.0210 - val_root_mean_squared_error: 1.7381
# Epoch 37/72
# 1517/1517 [==============================] - 0s 72us/sample - loss: 1.7530 - root_mean_squared_error: 1.3240 - val_loss: 0.8646 - val_root_mean_squared_error: 0.9299
# Epoch 38/72
# 1517/1517 [==============================] - 0s 70us/sample - loss: 1.0848 - root_mean_squared_error: 1.0415 - val_loss: 1.3463 - val_root_mean_squared_error: 1.1603
# Epoch 39/72
# 1517/1517 [==============================] - 0s 70us/sample - loss: 1.3614 - root_mean_squared_error: 1.1668 - val_loss: 1.3808 - val_root_mean_squared_error: 1.1751
# Epoch 40/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 1.5824 - root_mean_squared_error: 1.2579 - val_loss: 0.9510 - val_root_mean_squared_error: 0.9752
# Epoch 41/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 1.5177 - root_mean_squared_error: 1.2320 - val_loss: 2.5633 - val_root_mean_squared_error: 1.6010
# Epoch 42/72
# 1517/1517 [==============================] - 0s 61us/sample - loss: 1.3998 - root_mean_squared_error: 1.1831 - val_loss: 0.7941 - val_root_mean_squared_error: 0.8911
# Epoch 43/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 1.8946 - root_mean_squared_error: 1.3765 - val_loss: 1.1011 - val_root_mean_squared_error: 1.0493
# Epoch 44/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 1.1994 - root_mean_squared_error: 1.0952 - val_loss: 0.7146 - val_root_mean_squared_error: 0.8453
# Epoch 45/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 2.4657 - root_mean_squared_error: 1.5703 - val_loss: 2.5808 - val_root_mean_squared_error: 1.6065
# Epoch 46/72
# 1517/1517 [==============================] - 0s 61us/sample - loss: 1.1088 - root_mean_squared_error: 1.0530 - val_loss: 0.7773 - val_root_mean_squared_error: 0.8817
# Epoch 47/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 1.6774 - root_mean_squared_error: 1.2951 - val_loss: 0.7412 - val_root_mean_squared_error: 0.8609
# Epoch 48/72
# 1517/1517 [==============================] - 0s 63us/sample - loss: 2.5384 - root_mean_squared_error: 1.5932 - val_loss: 1.0058 - val_root_mean_squared_error: 1.0029
# Epoch 49/72
# 1517/1517 [==============================] - 0s 61us/sample - loss: 4.5002 - root_mean_squared_error: 2.1214 - val_loss: 0.9225 - val_root_mean_squared_error: 0.9605
# Epoch 50/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 1.4206 - root_mean_squared_error: 1.1919 - val_loss: 3.1636 - val_root_mean_squared_error: 1.7787
# Epoch 51/72
# 1517/1517 [==============================] - 0s 59us/sample - loss: 1.0481 - root_mean_squared_error: 1.0238 - val_loss: 2.0834 - val_root_mean_squared_error: 1.4434
# Epoch 52/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 2.3069 - root_mean_squared_error: 1.5188 - val_loss: 1.9031 - val_root_mean_squared_error: 1.3795
# Epoch 53/72
# 1517/1517 [==============================] - 0s 59us/sample - loss: 1.4545 - root_mean_squared_error: 1.2060 - val_loss: 1.7564 - val_root_mean_squared_error: 1.3253
# Epoch 54/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 1.2987 - root_mean_squared_error: 1.1396 - val_loss: 0.6722 - val_root_mean_squared_error: 0.8199
# Epoch 55/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 2.3461 - root_mean_squared_error: 1.5317 - val_loss: 2.5837 - val_root_mean_squared_error: 1.6074
# Epoch 56/72
# 1517/1517 [==============================] - 0s 60us/sample - loss: 2.5660 - root_mean_squared_error: 1.6019 - val_loss: 6.1971 - val_root_mean_squared_error: 2.4894
# Epoch 57/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 3.2616 - root_mean_squared_error: 1.8060 - val_loss: 3.1785 - val_root_mean_squared_error: 1.7828
# Epoch 58/72
# 1517/1517 [==============================] - 0s 68us/sample - loss: 1.4508 - root_mean_squared_error: 1.2045 - val_loss: 0.6681 - val_root_mean_squared_error: 0.8174
# Epoch 59/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 1.4171 - root_mean_squared_error: 1.1904 - val_loss: 1.5756 - val_root_mean_squared_error: 1.2552
# Epoch 60/72
# 1517/1517 [==============================] - 0s 68us/sample - loss: 1.2394 - root_mean_squared_error: 1.1133 - val_loss: 0.9559 - val_root_mean_squared_error: 0.9777
# Epoch 61/72
# 1517/1517 [==============================] - 0s 64us/sample - loss: 1.2099 - root_mean_squared_error: 1.0999 - val_loss: 1.0199 - val_root_mean_squared_error: 1.0099
# Epoch 62/72
# 1517/1517 [==============================] - 0s 64us/sample - loss: 1.0862 - root_mean_squared_error: 1.0422 - val_loss: 1.0301 - val_root_mean_squared_error: 1.0149
# Epoch 63/72
# 1517/1517 [==============================] - 0s 66us/sample - loss: 2.5097 - root_mean_squared_error: 1.5842 - val_loss: 4.8487 - val_root_mean_squared_error: 2.2020
# Epoch 64/72
# 1517/1517 [==============================] - 0s 68us/sample - loss: 3.0061 - root_mean_squared_error: 1.7338 - val_loss: 0.7423 - val_root_mean_squared_error: 0.8616
# Epoch 65/72
# 1517/1517 [==============================] - 0s 64us/sample - loss: 2.3904 - root_mean_squared_error: 1.5461 - val_loss: 0.7714 - val_root_mean_squared_error: 0.8783
# Epoch 66/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 1.1590 - root_mean_squared_error: 1.0766 - val_loss: 0.7779 - val_root_mean_squared_error: 0.8820
# Epoch 67/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 0.9495 - root_mean_squared_error: 0.9744 - val_loss: 0.6066 - val_root_mean_squared_error: 0.7788
# Epoch 68/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 0.6105 - root_mean_squared_error: 0.7813 - val_loss: 1.9980 - val_root_mean_squared_error: 1.4135
# Epoch 69/72
# 1517/1517 [==============================] - 0s 61us/sample - loss: 0.9898 - root_mean_squared_error: 0.9949 - val_loss: 1.1637 - val_root_mean_squared_error: 1.0787
# Epoch 70/72
# 1517/1517 [==============================] - 0s 62us/sample - loss: 0.8388 - root_mean_squared_error: 0.9158 - val_loss: 0.7677 - val_root_mean_squared_error: 0.8762
# Epoch 71/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 2.6461 - root_mean_squared_error: 1.6267 - val_loss: 2.6282 - val_root_mean_squared_error: 1.6212
# Epoch 72/72
# 1517/1517 [==============================] - 0s 67us/sample - loss: 61.3249 - root_mean_squared_error: 7.8310 - val_loss: 9.0779 - val_root_mean_squared_error: 3.0130
# Train on 1544 samples, validate on 172 samples
# Epoch 1/10
# 1544/1544 [==============================] - 0s 250us/sample - loss: 21.4536 - root_mean_squared_error: 4.6318 - val_loss: 231707.8594 - val_root_mean_squared_error: 481.3604
# Epoch 2/10
# 1544/1544 [==============================] - 0s 13us/sample - loss: 231016.5000 - root_mean_squared_error: 480.6418 - val_loss: 15588.4873 - val_root_mean_squared_error: 124.8539
# Epoch 3/10
# 1544/1544 [==============================] - 0s 12us/sample - loss: 15556.8652 - root_mean_squared_error: 124.7272 - val_loss: 29177.8223 - val_root_mean_squared_error: 170.8152
# Epoch 4/10
# 1544/1544 [==============================] - 0s 13us/sample - loss: 29066.7207 - root_mean_squared_error: 170.4897 - val_loss: 55619.6992 - val_root_mean_squared_error: 235.8383
# Epoch 5/10
# 1544/1544 [==============================] - 0s 14us/sample - loss: 55391.8867 - root_mean_squared_error: 235.3548 - val_loss: 32528.5234 - val_root_mean_squared_error: 180.3567
# Epoch 6/10
# 1544/1544 [==============================] - 0s 14us/sample - loss: 32379.5898 - root_mean_squared_error: 179.9433 - val_loss: 8804.4473 - val_root_mean_squared_error: 93.8320
# Epoch 7/10
# 1544/1544 [==============================] - 0s 13us/sample - loss: 8753.4541 - root_mean_squared_error: 93.5599 - val_loss: 283.6414 - val_root_mean_squared_error: 16.8417
# Epoch 8/10
# 1544/1544 [==============================] - 0s 13us/sample - loss: 277.3220 - root_mean_squared_error: 16.6530 - val_loss: 2271.3538 - val_root_mean_squared_error: 47.6587
# Epoch 9/10
# 1544/1544 [==============================] - 0s 14us/sample - loss: 2280.0469 - root_mean_squared_error: 47.7498 - val_loss: 5871.6719 - val_root_mean_squared_error: 76.6268
# Epoch 10/10
# 1544/1544 [==============================] - 0s 14us/sample - loss: 5873.0859 - root_mean_squared_error: 76.6361 - val_loss: 6978.4878 - val_root_mean_squared_error: 83.5373
# =================================================================================================
# Wall time: 9min 40s

# %%
optimizer.max
# Out:
# {'target': -0.6510487424307048,
#  'params': {'batch_size': 11.120889293230427,
#   'epochs': 82.28030685972415,
#   'hidden1': 513.4274516344879,
#   'hidden2': 537.6029775003996,
#   'hidden3': 738.9203833936791,
#   'n_steps': 189.10609475756982}}

# %% [markdown]
# El RMSE obtenido con este modelo nos da la menor métrica hasta ahora (**0.65**). Procedemos a realizar una búsqueda local al rededor de estos hiperparámetros.

# %%
pbounds = {
    'hidden1': (450, 600), 
    'hidden2' : (450, 600),
    'hidden3' : (650, 800),
    'epochs' : (70, 90),
    'batch_size' : (1, 20),
    'n_steps' : (170, 220)
}
optimizer.set_bounds(pbounds)

# %%
# %%time 
optimizer.maximize(
    n_iter = 10
)
# Out:
# |   iter    |  target   | batch_... |  epochs   |  hidden1  |  hidden2  |  hidden3  |  n_steps  |
# -------------------------------------------------------------------------------------------------
# Train on 1431 samples, validate on 159 samples
# Epoch 1/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 2414.6512 - root_mean_squared_error: 49.1391 - val_loss: 3.9620 - val_root_mean_squared_error: 1.9905
# Epoch 2/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 5.3818 - root_mean_squared_error: 2.3199 - val_loss: 4.8621 - val_root_mean_squared_error: 2.2050
# Epoch 3/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 4.2347 - root_mean_squared_error: 2.0578 - val_loss: 1.5831 - val_root_mean_squared_error: 1.2582
# Epoch 4/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 3.9901 - root_mean_squared_error: 1.9975 - val_loss: 3.1636 - val_root_mean_squared_error: 1.7787
# Epoch 5/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 3.4023 - root_mean_squared_error: 1.8445 - val_loss: 1.0339 - val_root_mean_squared_error: 1.0168
# Epoch 6/74
# 1431/1431 [==============================] - 1s 954us/sample - loss: 3.6758 - root_mean_squared_error: 1.9172 - val_loss: 0.8847 - val_root_mean_squared_error: 0.9406
# Epoch 7/74
# 1431/1431 [==============================] - 1s 956us/sample - loss: 3.0079 - root_mean_squared_error: 1.7343 - val_loss: 0.9600 - val_root_mean_squared_error: 0.9798
# Epoch 8/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 1.9800 - root_mean_squared_error: 1.4071 - val_loss: 0.7223 - val_root_mean_squared_error: 0.8499
# Epoch 9/74
# 1431/1431 [==============================] - 1s 953us/sample - loss: 2.3443 - root_mean_squared_error: 1.5311 - val_loss: 3.9285 - val_root_mean_squared_error: 1.9820
# Epoch 10/74
# 1431/1431 [==============================] - 1s 967us/sample - loss: 2.2137 - root_mean_squared_error: 1.4879 - val_loss: 2.3381 - val_root_mean_squared_error: 1.5291
# Epoch 11/74
# 1431/1431 [==============================] - 1s 969us/sample - loss: 2.3097 - root_mean_squared_error: 1.5198 - val_loss: 0.5751 - val_root_mean_squared_error: 0.7583
# Epoch 12/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 1.2092 - root_mean_squared_error: 1.0996 - val_loss: 0.7319 - val_root_mean_squared_error: 0.8555
# Epoch 13/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 1.6473 - root_mean_squared_error: 1.2835 - val_loss: 4.8988 - val_root_mean_squared_error: 2.2133
# Epoch 14/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 1.2189 - root_mean_squared_error: 1.1041 - val_loss: 0.7300 - val_root_mean_squared_error: 0.8544
# Epoch 15/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 1.5954 - root_mean_squared_error: 1.2631 - val_loss: 0.3813 - val_root_mean_squared_error: 0.6175
# Epoch 16/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 1.0256 - root_mean_squared_error: 1.0127 - val_loss: 0.5319 - val_root_mean_squared_error: 0.7293
# Epoch 17/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 3.4076 - root_mean_squared_error: 1.8460 - val_loss: 6.5145 - val_root_mean_squared_error: 2.5523
# Epoch 18/74
# 1431/1431 [==============================] - 1s 965us/sample - loss: 1.6437 - root_mean_squared_error: 1.2821 - val_loss: 1.0772 - val_root_mean_squared_error: 1.0379
# Epoch 19/74
# 1431/1431 [==============================] - 1s 992us/sample - loss: 1.5321 - root_mean_squared_error: 1.2378 - val_loss: 1.0575 - val_root_mean_squared_error: 1.0283
# Epoch 20/74
# 1431/1431 [==============================] - 1s 989us/sample - loss: 1.3315 - root_mean_squared_error: 1.1539 - val_loss: 1.4416 - val_root_mean_squared_error: 1.2006
# Epoch 21/74
# 1431/1431 [==============================] - 1s 992us/sample - loss: 1.2165 - root_mean_squared_error: 1.1029 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5874
# Epoch 22/74
# 1431/1431 [==============================] - 1s 965us/sample - loss: 0.9474 - root_mean_squared_error: 0.9734 - val_loss: 0.4532 - val_root_mean_squared_error: 0.6732
# Epoch 23/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.9920 - root_mean_squared_error: 0.9960 - val_loss: 1.5118 - val_root_mean_squared_error: 1.2296
# Epoch 24/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 1.6458 - root_mean_squared_error: 1.2829 - val_loss: 1.2315 - val_root_mean_squared_error: 1.1097
# Epoch 25/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.9164 - root_mean_squared_error: 0.9573 - val_loss: 1.0821 - val_root_mean_squared_error: 1.0403
# Epoch 26/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 1.3877 - root_mean_squared_error: 1.1780 - val_loss: 74.0483 - val_root_mean_squared_error: 8.6051
# Epoch 27/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 55.6083 - root_mean_squared_error: 7.4571 - val_loss: 1.2523 - val_root_mean_squared_error: 1.1191
# Epoch 28/74
# 1431/1431 [==============================] - 1s 962us/sample - loss: 1.3650 - root_mean_squared_error: 1.1683 - val_loss: 4.7161 - val_root_mean_squared_error: 2.1717
# Epoch 29/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 1.1743 - root_mean_squared_error: 1.0837 - val_loss: 0.2969 - val_root_mean_squared_error: 0.5449
# Epoch 30/74
# 1431/1431 [==============================] - 1s 995us/sample - loss: 0.7310 - root_mean_squared_error: 0.8550 - val_loss: 0.5375 - val_root_mean_squared_error: 0.7332
# Epoch 31/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.6688 - root_mean_squared_error: 0.8178 - val_loss: 0.5576 - val_root_mean_squared_error: 0.7467
# Epoch 32/74
# 1431/1431 [==============================] - 1s 978us/sample - loss: 0.7549 - root_mean_squared_error: 0.8688 - val_loss: 0.3928 - val_root_mean_squared_error: 0.6267
# Epoch 33/74
# 1431/1431 [==============================] - 1s 998us/sample - loss: 0.5601 - root_mean_squared_error: 0.7484 - val_loss: 0.8229 - val_root_mean_squared_error: 0.9071
# Epoch 34/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.4251 - root_mean_squared_error: 0.6520 - val_loss: 0.2948 - val_root_mean_squared_error: 0.5429
# Epoch 35/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.6666 - root_mean_squared_error: 0.8164 - val_loss: 0.4962 - val_root_mean_squared_error: 0.7044
# Epoch 36/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2762 - root_mean_squared_error: 0.5255 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3827
# Epoch 37/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.7733 - root_mean_squared_error: 0.8794 - val_loss: 0.8888 - val_root_mean_squared_error: 0.9427
# Epoch 38/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.5971 - root_mean_squared_error: 0.7727 - val_loss: 0.1221 - val_root_mean_squared_error: 0.3494
# Epoch 39/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.3777 - root_mean_squared_error: 0.6146 - val_loss: 0.1186 - val_root_mean_squared_error: 0.3444
# Epoch 40/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.2974 - root_mean_squared_error: 0.5454 - val_loss: 0.3969 - val_root_mean_squared_error: 0.6300
# Epoch 41/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.5540 - root_mean_squared_error: 0.7443 - val_loss: 0.2220 - val_root_mean_squared_error: 0.4711
# Epoch 42/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2686 - root_mean_squared_error: 0.5183 - val_loss: 0.6832 - val_root_mean_squared_error: 0.8265
# Epoch 43/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2570 - root_mean_squared_error: 0.5070 - val_loss: 0.5420 - val_root_mean_squared_error: 0.7362
# Epoch 44/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2181 - root_mean_squared_error: 0.4670 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3955
# Epoch 45/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.2879 - root_mean_squared_error: 0.5366 - val_loss: 0.2598 - val_root_mean_squared_error: 0.5097
# Epoch 46/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.2947 - root_mean_squared_error: 0.5429 - val_loss: 0.0865 - val_root_mean_squared_error: 0.2942
# Epoch 47/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2246 - root_mean_squared_error: 0.4739 - val_loss: 0.1432 - val_root_mean_squared_error: 0.3784
# Epoch 48/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.2582 - root_mean_squared_error: 0.5082 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2387
# Epoch 49/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1282 - root_mean_squared_error: 0.3581 - val_loss: 0.4406 - val_root_mean_squared_error: 0.6638
# Epoch 50/74
# 1431/1431 [==============================] - 1s 995us/sample - loss: 0.3069 - root_mean_squared_error: 0.5540 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3709
# Epoch 51/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1512 - root_mean_squared_error: 0.3889 - val_loss: 0.8007 - val_root_mean_squared_error: 0.8948
# Epoch 52/74
# 1431/1431 [==============================] - 1s 986us/sample - loss: 0.1748 - root_mean_squared_error: 0.4181 - val_loss: 0.2999 - val_root_mean_squared_error: 0.5476
# Epoch 53/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1849 - root_mean_squared_error: 0.4300 - val_loss: 0.1239 - val_root_mean_squared_error: 0.3519
# Epoch 54/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1117 - root_mean_squared_error: 0.3342 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2169
# Epoch 55/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1137 - root_mean_squared_error: 0.3372 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1756
# Epoch 56/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1838 - root_mean_squared_error: 0.4287 - val_loss: 0.2762 - val_root_mean_squared_error: 0.5256
# Epoch 57/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1440 - root_mean_squared_error: 0.3794 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
# Epoch 58/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1325 - root_mean_squared_error: 0.3639 - val_loss: 0.0897 - val_root_mean_squared_error: 0.2995
# Epoch 59/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1293 - root_mean_squared_error: 0.3596 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2186
# Epoch 60/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1580 - root_mean_squared_error: 0.3976 - val_loss: 0.3625 - val_root_mean_squared_error: 0.6021
# Epoch 61/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0910 - root_mean_squared_error: 0.3016 - val_loss: 0.0824 - val_root_mean_squared_error: 0.2870
# Epoch 62/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.1015 - root_mean_squared_error: 0.3186 - val_loss: 0.3753 - val_root_mean_squared_error: 0.6126
# Epoch 63/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0934 - root_mean_squared_error: 0.3056 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 64/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0721 - root_mean_squared_error: 0.2685 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 65/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.4441 - val_root_mean_squared_error: 0.6664
# Epoch 66/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0733 - root_mean_squared_error: 0.2708 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 67/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1573 - root_mean_squared_error: 0.3966 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1599
# Epoch 68/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0709 - root_mean_squared_error: 0.2664 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 69/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0930 - root_mean_squared_error: 0.3049 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
# Epoch 70/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.0782 - root_mean_squared_error: 0.2796 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3898
# Epoch 71/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0807 - root_mean_squared_error: 0.2841 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 72/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.0779 - root_mean_squared_error: 0.2790 - val_loss: 0.2320 - val_root_mean_squared_error: 0.4816
# Epoch 73/74
# 1431/1431 [==============================] - 2s 1ms/sample - loss: 0.0747 - root_mean_squared_error: 0.2732 - val_loss: 0.1951 - val_root_mean_squared_error: 0.4417
# Epoch 74/74
# 1431/1431 [==============================] - 1s 1ms/sample - loss: 0.1206 - root_mean_squared_error: 0.3473 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1775
# |  14       | -0.1562   |  3.667    |  73.96    |  570.1    |  595.2    |  697.0    |  204.6    |
# Train on 1424 samples, validate on 159 samples
# Epoch 1/88
# 1424/1424 [==============================] - 1s 584us/sample - loss: 6452.8798 - root_mean_squared_error: 80.3298 - val_loss: 8.3725 - val_root_mean_squared_error: 2.8935
# Epoch 2/88
# 1424/1424 [==============================] - 0s 222us/sample - loss: 8.5612 - root_mean_squared_error: 2.9260 - val_loss: 9.2023 - val_root_mean_squared_error: 3.0335
# Epoch 3/88
# 1424/1424 [==============================] - 0s 223us/sample - loss: 5.8949 - root_mean_squared_error: 2.4279 - val_loss: 3.4768 - val_root_mean_squared_error: 1.8646
# Epoch 4/88
# 1424/1424 [==============================] - 0s 219us/sample - loss: 3.8183 - root_mean_squared_error: 1.9541 - val_loss: 4.8955 - val_root_mean_squared_error: 2.2126
# Epoch 5/88
# 1424/1424 [==============================] - 0s 224us/sample - loss: 3.0372 - root_mean_squared_error: 1.7428 - val_loss: 2.3209 - val_root_mean_squared_error: 1.5235
# Epoch 6/88
# 1424/1424 [==============================] - 0s 237us/sample - loss: 2.2204 - root_mean_squared_error: 1.4901 - val_loss: 6.2763 - val_root_mean_squared_error: 2.5052
# Epoch 7/88
# 1424/1424 [==============================] - 0s 237us/sample - loss: 2.4807 - root_mean_squared_error: 1.5750 - val_loss: 7.2380 - val_root_mean_squared_error: 2.6904
# Epoch 8/88
# 1424/1424 [==============================] - 0s 229us/sample - loss: 1.8969 - root_mean_squared_error: 1.3773 - val_loss: 2.7329 - val_root_mean_squared_error: 1.6531
# Epoch 9/88
# 1424/1424 [==============================] - 0s 219us/sample - loss: 2.0988 - root_mean_squared_error: 1.4487 - val_loss: 2.5886 - val_root_mean_squared_error: 1.6089
# Epoch 10/88
# 1424/1424 [==============================] - 0s 218us/sample - loss: 2.0840 - root_mean_squared_error: 1.4436 - val_loss: 0.9478 - val_root_mean_squared_error: 0.9735
# Epoch 11/88
# 1424/1424 [==============================] - 0s 244us/sample - loss: 1.9807 - root_mean_squared_error: 1.4074 - val_loss: 4.6814 - val_root_mean_squared_error: 2.1636
# Epoch 12/88
# 1424/1424 [==============================] - 0s 236us/sample - loss: 2.1972 - root_mean_squared_error: 1.4823 - val_loss: 1.0453 - val_root_mean_squared_error: 1.0224
# Epoch 13/88
# 1424/1424 [==============================] - 0s 249us/sample - loss: 1.5307 - root_mean_squared_error: 1.2372 - val_loss: 3.1262 - val_root_mean_squared_error: 1.7681
# Epoch 14/88
# 1424/1424 [==============================] - 0s 227us/sample - loss: 3.4051 - root_mean_squared_error: 1.8453 - val_loss: 4.3948 - val_root_mean_squared_error: 2.0964
# Epoch 15/88
# 1424/1424 [==============================] - 0s 230us/sample - loss: 1.7209 - root_mean_squared_error: 1.3118 - val_loss: 0.8710 - val_root_mean_squared_error: 0.9333
# Epoch 16/88
# 1424/1424 [==============================] - 0s 217us/sample - loss: 1.9150 - root_mean_squared_error: 1.3838 - val_loss: 1.6661 - val_root_mean_squared_error: 1.2908
# Epoch 17/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.9938 - root_mean_squared_error: 1.4120 - val_loss: 1.0233 - val_root_mean_squared_error: 1.0116
# Epoch 18/88
# 1424/1424 [==============================] - 0s 207us/sample - loss: 2.2031 - root_mean_squared_error: 1.4843 - val_loss: 0.7254 - val_root_mean_squared_error: 0.8517
# Epoch 19/88
# 1424/1424 [==============================] - 0s 207us/sample - loss: 1.4907 - root_mean_squared_error: 1.2209 - val_loss: 3.3493 - val_root_mean_squared_error: 1.8301
# Epoch 20/88
# 1424/1424 [==============================] - 0s 210us/sample - loss: 1.5733 - root_mean_squared_error: 1.2543 - val_loss: 8.4087 - val_root_mean_squared_error: 2.8998
# Epoch 21/88
# 1424/1424 [==============================] - 0s 209us/sample - loss: 1.8732 - root_mean_squared_error: 1.3686 - val_loss: 0.6682 - val_root_mean_squared_error: 0.8174
# Epoch 22/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 1.7341 - root_mean_squared_error: 1.3168 - val_loss: 0.6347 - val_root_mean_squared_error: 0.7967
# Epoch 23/88
# 1424/1424 [==============================] - 0s 241us/sample - loss: 1.6173 - root_mean_squared_error: 1.2717 - val_loss: 1.1649 - val_root_mean_squared_error: 1.0793
# Epoch 24/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 2.8567 - root_mean_squared_error: 1.6902 - val_loss: 0.9508 - val_root_mean_squared_error: 0.9751
# Epoch 25/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 1.6640 - root_mean_squared_error: 1.2899 - val_loss: 0.8692 - val_root_mean_squared_error: 0.9323
# Epoch 26/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 1.9390 - root_mean_squared_error: 1.3925 - val_loss: 0.6464 - val_root_mean_squared_error: 0.8040
# Epoch 27/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.2034 - root_mean_squared_error: 1.0970 - val_loss: 0.5327 - val_root_mean_squared_error: 0.7298
# Epoch 28/88
# 1424/1424 [==============================] - 0s 216us/sample - loss: 1.2860 - root_mean_squared_error: 1.1340 - val_loss: 6.4837 - val_root_mean_squared_error: 2.5463
# Epoch 29/88
# 1424/1424 [==============================] - 0s 239us/sample - loss: 2.5825 - root_mean_squared_error: 1.6070 - val_loss: 0.4719 - val_root_mean_squared_error: 0.6870
# Epoch 30/88
# 1424/1424 [==============================] - 0s 219us/sample - loss: 3.7498 - root_mean_squared_error: 1.9364 - val_loss: 3.8917 - val_root_mean_squared_error: 1.9727
# Epoch 31/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 2.2535 - root_mean_squared_error: 1.5012 - val_loss: 0.6644 - val_root_mean_squared_error: 0.8151
# Epoch 32/88
# 1424/1424 [==============================] - 0s 224us/sample - loss: 1.2309 - root_mean_squared_error: 1.1095 - val_loss: 5.5578 - val_root_mean_squared_error: 2.3575
# Epoch 33/88
# 1424/1424 [==============================] - 0s 228us/sample - loss: 1.7992 - root_mean_squared_error: 1.3414 - val_loss: 0.4330 - val_root_mean_squared_error: 0.6580
# Epoch 34/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 2.0894 - root_mean_squared_error: 1.4455 - val_loss: 3.4502 - val_root_mean_squared_error: 1.8575
# Epoch 35/88
# 1424/1424 [==============================] - 0s 213us/sample - loss: 1.2331 - root_mean_squared_error: 1.1105 - val_loss: 0.7545 - val_root_mean_squared_error: 0.8686
# Epoch 36/88
# 1424/1424 [==============================] - 0s 208us/sample - loss: 1.2353 - root_mean_squared_error: 1.1114 - val_loss: 7.0607 - val_root_mean_squared_error: 2.6572
# Epoch 37/88
# 1424/1424 [==============================] - 0s 209us/sample - loss: 1.0094 - root_mean_squared_error: 1.0047 - val_loss: 1.6200 - val_root_mean_squared_error: 1.2728
# Epoch 38/88
# 1424/1424 [==============================] - 0s 210us/sample - loss: 1.5095 - root_mean_squared_error: 1.2286 - val_loss: 0.3483 - val_root_mean_squared_error: 0.5901
# Epoch 39/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 0.8820 - root_mean_squared_error: 0.9392 - val_loss: 3.2632 - val_root_mean_squared_error: 1.8064
# Epoch 40/88
# 1424/1424 [==============================] - 0s 232us/sample - loss: 2.1978 - root_mean_squared_error: 1.4825 - val_loss: 0.4203 - val_root_mean_squared_error: 0.6483
# Epoch 41/88
# 1424/1424 [==============================] - 0s 233us/sample - loss: 1.8414 - root_mean_squared_error: 1.3570 - val_loss: 0.4365 - val_root_mean_squared_error: 0.6607
# Epoch 42/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.8915 - root_mean_squared_error: 1.3753 - val_loss: 2.1396 - val_root_mean_squared_error: 1.4627
# Epoch 43/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.3160 - root_mean_squared_error: 1.1472 - val_loss: 1.2577 - val_root_mean_squared_error: 1.1215
# Epoch 44/88
# 1424/1424 [==============================] - 0s 209us/sample - loss: 1.1313 - root_mean_squared_error: 1.0636 - val_loss: 0.2897 - val_root_mean_squared_error: 0.5382
# Epoch 45/88
# 1424/1424 [==============================] - 0s 206us/sample - loss: 1.1644 - root_mean_squared_error: 1.0791 - val_loss: 75.8208 - val_root_mean_squared_error: 8.7075
# Epoch 46/88
# 1424/1424 [==============================] - 0s 232us/sample - loss: 6.7608 - root_mean_squared_error: 2.6001 - val_loss: 2.2188 - val_root_mean_squared_error: 1.4896
# Epoch 47/88
# 1424/1424 [==============================] - 0s 226us/sample - loss: 0.7122 - root_mean_squared_error: 0.8439 - val_loss: 5.7899 - val_root_mean_squared_error: 2.4062
# Epoch 48/88
# 1424/1424 [==============================] - 0s 210us/sample - loss: 1.1764 - root_mean_squared_error: 1.0846 - val_loss: 0.3322 - val_root_mean_squared_error: 0.5764
# Epoch 49/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 0.9681 - root_mean_squared_error: 0.9839 - val_loss: 1.7250 - val_root_mean_squared_error: 1.3134
# Epoch 50/88
# 1424/1424 [==============================] - 0s 247us/sample - loss: 1.0668 - root_mean_squared_error: 1.0329 - val_loss: 1.1284 - val_root_mean_squared_error: 1.0622
# Epoch 51/88
# 1424/1424 [==============================] - 0s 242us/sample - loss: 0.8001 - root_mean_squared_error: 0.8945 - val_loss: 3.2088 - val_root_mean_squared_error: 1.7913
# Epoch 52/88
# 1424/1424 [==============================] - 0s 232us/sample - loss: 1.0989 - root_mean_squared_error: 1.0483 - val_loss: 1.7304 - val_root_mean_squared_error: 1.3154
# Epoch 53/88
# 1424/1424 [==============================] - 0s 235us/sample - loss: 0.7134 - root_mean_squared_error: 0.8446 - val_loss: 0.8503 - val_root_mean_squared_error: 0.9221
# Epoch 54/88
# 1424/1424 [==============================] - 0s 238us/sample - loss: 0.5748 - root_mean_squared_error: 0.7582 - val_loss: 0.9349 - val_root_mean_squared_error: 0.9669
# Epoch 55/88
# 1424/1424 [==============================] - 0s 229us/sample - loss: 0.5739 - root_mean_squared_error: 0.7576 - val_loss: 1.0693 - val_root_mean_squared_error: 1.0340
# Epoch 56/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.3598 - root_mean_squared_error: 1.1661 - val_loss: 0.4919 - val_root_mean_squared_error: 0.7013
# Epoch 57/88
# 1424/1424 [==============================] - 0s 228us/sample - loss: 0.6391 - root_mean_squared_error: 0.7994 - val_loss: 0.1991 - val_root_mean_squared_error: 0.4462
# Epoch 58/88
# 1424/1424 [==============================] - 0s 233us/sample - loss: 0.5654 - root_mean_squared_error: 0.7519 - val_loss: 1.0251 - val_root_mean_squared_error: 1.0125
# Epoch 59/88
# 1424/1424 [==============================] - 0s 215us/sample - loss: 0.5067 - root_mean_squared_error: 0.7118 - val_loss: 2.0838 - val_root_mean_squared_error: 1.4435
# Epoch 60/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 0.4032 - root_mean_squared_error: 0.6350 - val_loss: 0.2367 - val_root_mean_squared_error: 0.4865
# Epoch 61/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 0.5028 - root_mean_squared_error: 0.7091 - val_loss: 4.5096 - val_root_mean_squared_error: 2.1236
# Epoch 62/88
# 1424/1424 [==============================] - 0s 213us/sample - loss: 0.4969 - root_mean_squared_error: 0.7049 - val_loss: 1.1033 - val_root_mean_squared_error: 1.0504
# Epoch 63/88
# 1424/1424 [==============================] - 0s 231us/sample - loss: 0.8104 - root_mean_squared_error: 0.9002 - val_loss: 1.8242 - val_root_mean_squared_error: 1.3506
# Epoch 64/88
# 1424/1424 [==============================] - 0s 228us/sample - loss: 1.2186 - root_mean_squared_error: 1.1039 - val_loss: 1.4368 - val_root_mean_squared_error: 1.1987
# Epoch 65/88
# 1424/1424 [==============================] - 0s 213us/sample - loss: 1.0777 - root_mean_squared_error: 1.0381 - val_loss: 0.4021 - val_root_mean_squared_error: 0.6341
# Epoch 66/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 0.5347 - root_mean_squared_error: 0.7312 - val_loss: 0.1996 - val_root_mean_squared_error: 0.4467
# Epoch 67/88
# 1424/1424 [==============================] - 0s 228us/sample - loss: 0.3735 - root_mean_squared_error: 0.6112 - val_loss: 0.4357 - val_root_mean_squared_error: 0.6601
# Epoch 68/88
# 1424/1424 [==============================] - 0s 231us/sample - loss: 0.6473 - root_mean_squared_error: 0.8046 - val_loss: 0.5049 - val_root_mean_squared_error: 0.7106
# Epoch 69/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 0.3020 - root_mean_squared_error: 0.5496 - val_loss: 0.1414 - val_root_mean_squared_error: 0.3760
# Epoch 70/88
# 1424/1424 [==============================] - 0s 208us/sample - loss: 0.3986 - root_mean_squared_error: 0.6314 - val_loss: 2.1593 - val_root_mean_squared_error: 1.4695
# Epoch 71/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 1.0379 - root_mean_squared_error: 1.0188 - val_loss: 0.4566 - val_root_mean_squared_error: 0.6757
# Epoch 72/88
# 1424/1424 [==============================] - 0s 212us/sample - loss: 0.4397 - root_mean_squared_error: 0.6631 - val_loss: 0.1077 - val_root_mean_squared_error: 0.3282
# Epoch 73/88
# 1424/1424 [==============================] - 0s 208us/sample - loss: 3.9375 - root_mean_squared_error: 1.9843 - val_loss: 337.8840 - val_root_mean_squared_error: 18.3816
# Epoch 74/88
# 1424/1424 [==============================] - 0s 220us/sample - loss: 40.5602 - root_mean_squared_error: 6.3687 - val_loss: 0.8833 - val_root_mean_squared_error: 0.9399
# Epoch 75/88
# 1424/1424 [==============================] - 0s 237us/sample - loss: 2.7254 - root_mean_squared_error: 1.6509 - val_loss: 1.8533 - val_root_mean_squared_error: 1.3614
# Epoch 76/88
# 1424/1424 [==============================] - 0s 221us/sample - loss: 1.5562 - root_mean_squared_error: 1.2475 - val_loss: 1.4204 - val_root_mean_squared_error: 1.1918
# Epoch 77/88
# 1424/1424 [==============================] - 0s 209us/sample - loss: 0.8438 - root_mean_squared_error: 0.9186 - val_loss: 2.1537 - val_root_mean_squared_error: 1.4676
# Epoch 78/88
# 1424/1424 [==============================] - 0s 209us/sample - loss: 0.8520 - root_mean_squared_error: 0.9230 - val_loss: 1.6809 - val_root_mean_squared_error: 1.2965
# Epoch 79/88
# 1424/1424 [==============================] - 0s 211us/sample - loss: 0.8236 - root_mean_squared_error: 0.9075 - val_loss: 0.5871 - val_root_mean_squared_error: 0.7662
# Epoch 80/88
# 1424/1424 [==============================] - 0s 221us/sample - loss: 0.5068 - root_mean_squared_error: 0.7119 - val_loss: 0.4229 - val_root_mean_squared_error: 0.6503
# Epoch 81/88
# 1424/1424 [==============================] - 0s 244us/sample - loss: 0.7068 - root_mean_squared_error: 0.8407 - val_loss: 0.9356 - val_root_mean_squared_error: 0.9672
# Epoch 82/88
# 1424/1424 [==============================] - 0s 221us/sample - loss: 0.8044 - root_mean_squared_error: 0.8969 - val_loss: 0.2484 - val_root_mean_squared_error: 0.4984
# Epoch 83/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 0.5901 - root_mean_squared_error: 0.7682 - val_loss: 1.1290 - val_root_mean_squared_error: 1.0625
# Epoch 84/88
# 1424/1424 [==============================] - 0s 228us/sample - loss: 0.5928 - root_mean_squared_error: 0.7699 - val_loss: 0.2372 - val_root_mean_squared_error: 0.4870
# Epoch 85/88
# 1424/1424 [==============================] - 0s 242us/sample - loss: 0.6253 - root_mean_squared_error: 0.7907 - val_loss: 0.6803 - val_root_mean_squared_error: 0.8248
# Epoch 86/88
# 1424/1424 [==============================] - 0s 219us/sample - loss: 0.6088 - root_mean_squared_error: 0.7802 - val_loss: 0.6132 - val_root_mean_squared_error: 0.7831
# Epoch 87/88
# 1424/1424 [==============================] - 0s 214us/sample - loss: 0.4136 - root_mean_squared_error: 0.6431 - val_loss: 0.1870 - val_root_mean_squared_error: 0.4324
# Epoch 88/88
# 1424/1424 [==============================] - 0s 216us/sample - loss: 0.4902 - root_mean_squared_error: 0.7002 - val_loss: 0.2450 - val_root_mean_squared_error: 0.4950
# Train on 1445 samples, validate on 161 samples
# Epoch 1/78
# 1445/1445 [==============================] - 2s 2ms/sample - loss: 1468.5383 - root_mean_squared_error: 38.3215 - val_loss: 2.0226 - val_root_mean_squared_error: 1.4222
# Epoch 2/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 3.8756 - root_mean_squared_error: 1.9686 - val_loss: 1.1934 - val_root_mean_squared_error: 1.0924
# Epoch 3/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 2.9586 - root_mean_squared_error: 1.7201 - val_loss: 11.0304 - val_root_mean_squared_error: 3.3212
# Epoch 4/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 3.4505 - root_mean_squared_error: 1.8575 - val_loss: 1.0113 - val_root_mean_squared_error: 1.0057
# Epoch 5/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 2.3461 - root_mean_squared_error: 1.5317 - val_loss: 3.5652 - val_root_mean_squared_error: 1.8882
# Epoch 6/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 2.7536 - root_mean_squared_error: 1.6594 - val_loss: 4.9828 - val_root_mean_squared_error: 2.2322
# Epoch 7/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 3.4120 - root_mean_squared_error: 1.8471 - val_loss: 0.5577 - val_root_mean_squared_error: 0.7468
# Epoch 8/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.9286 - root_mean_squared_error: 0.9637 - val_loss: 0.6360 - val_root_mean_squared_error: 0.7975
# Epoch 9/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.9783 - root_mean_squared_error: 0.9891 - val_loss: 0.4252 - val_root_mean_squared_error: 0.6521
# Epoch 10/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.2353 - root_mean_squared_error: 1.1114 - val_loss: 1.6475 - val_root_mean_squared_error: 1.2835
# Epoch 11/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.3976 - root_mean_squared_error: 1.1822 - val_loss: 0.9006 - val_root_mean_squared_error: 0.9490
# Epoch 12/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.4057 - root_mean_squared_error: 1.1856 - val_loss: 0.4330 - val_root_mean_squared_error: 0.6580
# Epoch 13/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.7008 - root_mean_squared_error: 1.3041 - val_loss: 1.0358 - val_root_mean_squared_error: 1.0177
# Epoch 14/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 2.6169 - root_mean_squared_error: 1.6177 - val_loss: 1.2425 - val_root_mean_squared_error: 1.1147
# Epoch 15/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.3265 - root_mean_squared_error: 1.1518 - val_loss: 0.4599 - val_root_mean_squared_error: 0.6782
# Epoch 16/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.5363 - root_mean_squared_error: 1.2395 - val_loss: 0.3599 - val_root_mean_squared_error: 0.5999
# Epoch 17/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.9522 - root_mean_squared_error: 0.9758 - val_loss: 0.3027 - val_root_mean_squared_error: 0.5502
# Epoch 18/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.0486 - root_mean_squared_error: 1.0240 - val_loss: 0.3156 - val_root_mean_squared_error: 0.5618
# Epoch 19/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 1.0509 - root_mean_squared_error: 1.0251 - val_loss: 1.2420 - val_root_mean_squared_error: 1.1145
# Epoch 20/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.9784 - root_mean_squared_error: 0.9891 - val_loss: 1.6712 - val_root_mean_squared_error: 1.2928
# Epoch 21/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.7998 - root_mean_squared_error: 0.8943 - val_loss: 0.2167 - val_root_mean_squared_error: 0.4656
# Epoch 22/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.6242 - root_mean_squared_error: 0.7901 - val_loss: 2.3275 - val_root_mean_squared_error: 1.5256
# Epoch 23/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 5.6973 - root_mean_squared_error: 2.3869 - val_loss: 0.3834 - val_root_mean_squared_error: 0.6192
# Epoch 24/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.7021 - root_mean_squared_error: 0.8379 - val_loss: 0.2154 - val_root_mean_squared_error: 0.4641
# Epoch 25/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.6047 - root_mean_squared_error: 0.7776 - val_loss: 0.3975 - val_root_mean_squared_error: 0.6305
# Epoch 26/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3867 - root_mean_squared_error: 0.6218 - val_loss: 0.3650 - val_root_mean_squared_error: 0.6041
# Epoch 27/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.4960 - root_mean_squared_error: 0.7042 - val_loss: 0.1350 - val_root_mean_squared_error: 0.3675
# Epoch 28/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3790 - root_mean_squared_error: 0.6156 - val_loss: 0.7948 - val_root_mean_squared_error: 0.8915
# Epoch 29/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3673 - root_mean_squared_error: 0.6060 - val_loss: 0.0990 - val_root_mean_squared_error: 0.3147
# Epoch 30/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3622 - root_mean_squared_error: 0.6018 - val_loss: 1.0625 - val_root_mean_squared_error: 1.0308
# Epoch 31/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.4696 - root_mean_squared_error: 0.6853 - val_loss: 0.3769 - val_root_mean_squared_error: 0.6139
# Epoch 32/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.4026 - root_mean_squared_error: 0.6345 - val_loss: 0.1287 - val_root_mean_squared_error: 0.3588
# Epoch 33/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3252 - root_mean_squared_error: 0.5703 - val_loss: 0.6964 - val_root_mean_squared_error: 0.8345
# Epoch 34/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2659 - root_mean_squared_error: 0.5157 - val_loss: 0.0917 - val_root_mean_squared_error: 0.3028
# Epoch 35/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2765 - root_mean_squared_error: 0.5258 - val_loss: 0.1581 - val_root_mean_squared_error: 0.3976
# Epoch 36/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2410 - root_mean_squared_error: 0.4910 - val_loss: 0.1850 - val_root_mean_squared_error: 0.4301
# Epoch 37/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.3660 - root_mean_squared_error: 0.6050 - val_loss: 0.1975 - val_root_mean_squared_error: 0.4444
# Epoch 38/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1880 - root_mean_squared_error: 0.4336 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2332
# Epoch 39/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1792 - root_mean_squared_error: 0.4233 - val_loss: 0.0523 - val_root_mean_squared_error: 0.2286
# Epoch 40/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1868 - root_mean_squared_error: 0.4323 - val_loss: 0.4061 - val_root_mean_squared_error: 0.6373
# Epoch 41/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2734 - root_mean_squared_error: 0.5229 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 42/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1462 - root_mean_squared_error: 0.3824 - val_loss: 0.0499 - val_root_mean_squared_error: 0.2233
# Epoch 43/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1659 - root_mean_squared_error: 0.4073 - val_loss: 0.1917 - val_root_mean_squared_error: 0.4378
# Epoch 44/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1695 - root_mean_squared_error: 0.4117 - val_loss: 0.0539 - val_root_mean_squared_error: 0.2323
# Epoch 45/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2033 - root_mean_squared_error: 0.4509 - val_loss: 0.0602 - val_root_mean_squared_error: 0.2454
# Epoch 46/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1818 - root_mean_squared_error: 0.4263 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2409
# Epoch 47/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1342 - root_mean_squared_error: 0.3663 - val_loss: 0.1672 - val_root_mean_squared_error: 0.4089
# Epoch 48/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1306 - root_mean_squared_error: 0.3614 - val_loss: 0.0995 - val_root_mean_squared_error: 0.3154
# Epoch 49/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1194 - root_mean_squared_error: 0.3455 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1790
# Epoch 50/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2580 - root_mean_squared_error: 0.5079 - val_loss: 0.0501 - val_root_mean_squared_error: 0.2239
# Epoch 51/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1056 - root_mean_squared_error: 0.3250 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1640
# Epoch 52/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1627 - root_mean_squared_error: 0.4033 - val_loss: 0.7917 - val_root_mean_squared_error: 0.8898
# Epoch 53/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1269 - root_mean_squared_error: 0.3562 - val_loss: 0.1087 - val_root_mean_squared_error: 0.3297
# Epoch 54/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1676 - root_mean_squared_error: 0.4094 - val_loss: 0.0997 - val_root_mean_squared_error: 0.3157
# Epoch 55/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0746 - root_mean_squared_error: 0.2732 - val_loss: 0.0623 - val_root_mean_squared_error: 0.2496
# Epoch 56/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1173 - root_mean_squared_error: 0.3425 - val_loss: 0.1135 - val_root_mean_squared_error: 0.3370
# Epoch 57/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1554 - root_mean_squared_error: 0.3942 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1574
# Epoch 58/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1192 - root_mean_squared_error: 0.3453 - val_loss: 0.0892 - val_root_mean_squared_error: 0.2987
# Epoch 59/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1533 - root_mean_squared_error: 0.3916 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3219
# Epoch 60/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0891 - root_mean_squared_error: 0.2985 - val_loss: 0.0311 - val_root_mean_squared_error: 0.1763
# Epoch 61/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0782 - root_mean_squared_error: 0.2797 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 62/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1104 - root_mean_squared_error: 0.3322 - val_loss: 0.1317 - val_root_mean_squared_error: 0.3629
# Epoch 63/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0967 - root_mean_squared_error: 0.3109 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2973
# Epoch 64/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1134 - root_mean_squared_error: 0.3368 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1374
# Epoch 65/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2198 - root_mean_squared_error: 0.4688 - val_loss: 0.1950 - val_root_mean_squared_error: 0.4416
# Epoch 66/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1146 - root_mean_squared_error: 0.3386 - val_loss: 0.1585 - val_root_mean_squared_error: 0.3981
# Epoch 67/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0869 - root_mean_squared_error: 0.2948 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1369
# Epoch 68/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1321 - root_mean_squared_error: 0.3634 - val_loss: 0.2420 - val_root_mean_squared_error: 0.4920
# Epoch 69/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1142 - root_mean_squared_error: 0.3379 - val_loss: 0.3254 - val_root_mean_squared_error: 0.5705
# Epoch 70/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0773 - root_mean_squared_error: 0.2781 - val_loss: 0.2276 - val_root_mean_squared_error: 0.4771
# Epoch 71/78
# 1445/1445 [==============================] - 2s 2ms/sample - loss: 0.0769 - root_mean_squared_error: 0.2773 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1757
# Epoch 72/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.5847 - root_mean_squared_error: 0.7646 - val_loss: 0.0629 - val_root_mean_squared_error: 0.2507
# Epoch 73/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1436 - root_mean_squared_error: 0.3789 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 74/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0754 - root_mean_squared_error: 0.2746 - val_loss: 0.1898 - val_root_mean_squared_error: 0.4356
# Epoch 75/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1536 - root_mean_squared_error: 0.3919 - val_loss: 0.1739 - val_root_mean_squared_error: 0.4170
# Epoch 76/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.1547 - root_mean_squared_error: 0.3933 - val_loss: 0.2417 - val_root_mean_squared_error: 0.4916
# Epoch 77/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.2029 - root_mean_squared_error: 0.4505 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2055
# Epoch 78/78
# 1445/1445 [==============================] - 2s 1ms/sample - loss: 0.0748 - root_mean_squared_error: 0.2736 - val_loss: 0.0611 - val_root_mean_squared_error: 0.2473
# Train on 1430 samples, validate on 159 samples
# Epoch 1/87
# 1430/1430 [==============================] - 1s 561us/sample - loss: 10188.6617 - root_mean_squared_error: 100.9389 - val_loss: 37.6641 - val_root_mean_squared_error: 6.1371
# Epoch 2/87
# 1430/1430 [==============================] - 0s 285us/sample - loss: 15.8992 - root_mean_squared_error: 3.9874 - val_loss: 10.6405 - val_root_mean_squared_error: 3.2620
# Epoch 3/87
# 1430/1430 [==============================] - 0s 289us/sample - loss: 9.2269 - root_mean_squared_error: 3.0376 - val_loss: 4.3763 - val_root_mean_squared_error: 2.0920
# Epoch 4/87
# 1430/1430 [==============================] - 0s 328us/sample - loss: 4.3742 - root_mean_squared_error: 2.0915 - val_loss: 2.6596 - val_root_mean_squared_error: 1.6308
# Epoch 5/87
# 1430/1430 [==============================] - 0s 300us/sample - loss: 2.3677 - root_mean_squared_error: 1.5387 - val_loss: 2.8944 - val_root_mean_squared_error: 1.7013
# Epoch 6/87
# 1430/1430 [==============================] - 0s 294us/sample - loss: 4.6754 - root_mean_squared_error: 2.1623 - val_loss: 1.9380 - val_root_mean_squared_error: 1.3921
# Epoch 7/87
# 1430/1430 [==============================] - 0s 291us/sample - loss: 2.5970 - root_mean_squared_error: 1.6115 - val_loss: 1.4706 - val_root_mean_squared_error: 1.2127
# Epoch 8/87
# 1430/1430 [==============================] - 0s 303us/sample - loss: 2.3020 - root_mean_squared_error: 1.5172 - val_loss: 2.7550 - val_root_mean_squared_error: 1.6598
# Epoch 9/87
# 1430/1430 [==============================] - 0s 307us/sample - loss: 2.5857 - root_mean_squared_error: 1.6080 - val_loss: 1.4008 - val_root_mean_squared_error: 1.1835
# Epoch 10/87
# 1430/1430 [==============================] - 0s 291us/sample - loss: 2.1055 - root_mean_squared_error: 1.4510 - val_loss: 3.3157 - val_root_mean_squared_error: 1.8209
# Epoch 11/87
# 1430/1430 [==============================] - 0s 303us/sample - loss: 2.4407 - root_mean_squared_error: 1.5623 - val_loss: 2.0408 - val_root_mean_squared_error: 1.4286
# Epoch 12/87
# 1430/1430 [==============================] - 0s 312us/sample - loss: 1.9239 - root_mean_squared_error: 1.3871 - val_loss: 4.0990 - val_root_mean_squared_error: 2.0246
# Epoch 13/87
# 1430/1430 [==============================] - 0s 292us/sample - loss: 2.7360 - root_mean_squared_error: 1.6541 - val_loss: 1.9437 - val_root_mean_squared_error: 1.3942
# Epoch 14/87
# 1430/1430 [==============================] - 0s 289us/sample - loss: 1.9293 - root_mean_squared_error: 1.3890 - val_loss: 0.9819 - val_root_mean_squared_error: 0.9909
# Epoch 15/87
# 1430/1430 [==============================] - 0s 289us/sample - loss: 1.8355 - root_mean_squared_error: 1.3548 - val_loss: 1.0936 - val_root_mean_squared_error: 1.0458
# Epoch 16/87
# 1430/1430 [==============================] - 0s 287us/sample - loss: 2.5329 - root_mean_squared_error: 1.5915 - val_loss: 9.6727 - val_root_mean_squared_error: 3.1101
# Epoch 17/87
# 1430/1430 [==============================] - 0s 324us/sample - loss: 2.6380 - root_mean_squared_error: 1.6242 - val_loss: 0.7203 - val_root_mean_squared_error: 0.8487
# Epoch 18/87
# 1430/1430 [==============================] - 0s 288us/sample - loss: 1.6716 - root_mean_squared_error: 1.2929 - val_loss: 3.5728 - val_root_mean_squared_error: 1.8902
# Epoch 19/87
# 1430/1430 [==============================] - 0s 289us/sample - loss: 2.6150 - root_mean_squared_error: 1.6171 - val_loss: 5.2961 - val_root_mean_squared_error: 2.3013
# Epoch 20/87
# 1430/1430 [==============================] - 0s 288us/sample - loss: 2.0297 - root_mean_squared_error: 1.4247 - val_loss: 5.0515 - val_root_mean_squared_error: 2.2476
# Epoch 21/87
# 1430/1430 [==============================] - 0s 312us/sample - loss: 1.3593 - root_mean_squared_error: 1.1659 - val_loss: 1.8332 - val_root_mean_squared_error: 1.3539
# Epoch 22/87
# 1430/1430 [==============================] - 0s 300us/sample - loss: 1.1933 - root_mean_squared_error: 1.0924 - val_loss: 1.1357 - val_root_mean_squared_error: 1.0657
# Epoch 23/87
# 1430/1430 [==============================] - 0s 307us/sample - loss: 1.8179 - root_mean_squared_error: 1.3483 - val_loss: 2.9355 - val_root_mean_squared_error: 1.7133
# Epoch 24/87
# 1430/1430 [==============================] - 0s 342us/sample - loss: 1.7477 - root_mean_squared_error: 1.3220 - val_loss: 4.7947 - val_root_mean_squared_error: 2.1897
# Epoch 25/87
# 1430/1430 [==============================] - 1s 351us/sample - loss: 2.4127 - root_mean_squared_error: 1.5533 - val_loss: 2.4255 - val_root_mean_squared_error: 1.5574
# Epoch 26/87
# 1430/1430 [==============================] - 0s 298us/sample - loss: 1.3133 - root_mean_squared_error: 1.1460 - val_loss: 0.9218 - val_root_mean_squared_error: 0.9601
# Epoch 27/87
# 1430/1430 [==============================] - 0s 290us/sample - loss: 2.6170 - root_mean_squared_error: 1.6177 - val_loss: 3.5540 - val_root_mean_squared_error: 1.8852
# ...
# Epoch 74/90
# 1420/1420 [==============================] - 5s 4ms/sample - loss: 0.0595 - root_mean_squared_error: 0.2440 - val_loss: 0.0758 - val_root_mean_squared_error: 0.2754
# Epoch 75/90
# 1420/1420 [==============================] - 5s 4ms/sample - loss: 0.0613 - root_mean_squared_error: 0.2476 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2195
# Epoch 76/90
# 1420/1420 [==============================] - 5s 4ms/sample - loss: 0.0795 - root_mean_squared_error: 0.2820 - val_loss: 0.0725 - val_root_mean_squared_error: 0.2693
# Epoch 77/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0712 - root_mean_squared_error: 0.2668 - val_loss: 0.0554 - val_root_mean_squared_error: 0.2353
# Epoch 78/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0597 - root_mean_squared_error: 0.2442 - val_loss: 0.2137 - val_root_mean_squared_error: 0.4622
# Epoch 79/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.1155 - root_mean_squared_error: 0.3398 - val_loss: 0.1684 - val_root_mean_squared_error: 0.4104
# Epoch 80/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0770 - root_mean_squared_error: 0.2775 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1437
# Epoch 81/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0867 - root_mean_squared_error: 0.2945 - val_loss: 0.0571 - val_root_mean_squared_error: 0.2389
# Epoch 82/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0637 - root_mean_squared_error: 0.2525 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1531
# Epoch 83/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0816 - root_mean_squared_error: 0.2856 - val_loss: 0.1847 - val_root_mean_squared_error: 0.4298
# Epoch 84/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0917 - root_mean_squared_error: 0.3028 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341
# Epoch 85/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0573 - root_mean_squared_error: 0.2393 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1602
# Epoch 86/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0631 - root_mean_squared_error: 0.2511 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1685
# Epoch 87/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0615 - root_mean_squared_error: 0.2479 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1613
# Epoch 88/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0730 - root_mean_squared_error: 0.2702 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3038
# Epoch 89/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0496 - root_mean_squared_error: 0.2227 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1456
# Epoch 90/90
# 1420/1420 [==============================] - 5s 3ms/sample - loss: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.1127 - val_root_mean_squared_error: 0.3357
# Train on 1456 samples, validate on 162 samples
# Epoch 1/71
# 1456/1456 [==============================] - 1s 481us/sample - loss: 9066.7155 - root_mean_squared_error: 95.2193 - val_loss: 18.0507 - val_root_mean_squared_error: 4.2486
# Epoch 2/71
# 1456/1456 [==============================] - 0s 214us/sample - loss: 17.1659 - root_mean_squared_error: 4.1432 - val_loss: 13.8418 - val_root_mean_squared_error: 3.7205
# Epoch 3/71
# 1456/1456 [==============================] - 0s 220us/sample - loss: 10.1960 - root_mean_squared_error: 3.1931 - val_loss: 7.6437 - val_root_mean_squared_error: 2.7647
# Epoch 4/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 6.9444 - root_mean_squared_error: 2.6352 - val_loss: 4.0833 - val_root_mean_squared_error: 2.0207
# Epoch 5/71
# 1456/1456 [==============================] - 0s 209us/sample - loss: 5.3101 - root_mean_squared_error: 2.3044 - val_loss: 2.5019 - val_root_mean_squared_error: 1.5817
# Epoch 6/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 4.9193 - root_mean_squared_error: 2.2180 - val_loss: 2.0339 - val_root_mean_squared_error: 1.4261
# Epoch 7/71
# 1456/1456 [==============================] - 0s 212us/sample - loss: 3.8300 - root_mean_squared_error: 1.9571 - val_loss: 2.8766 - val_root_mean_squared_error: 1.6961
# Epoch 8/71
# 1456/1456 [==============================] - 0s 225us/sample - loss: 3.5410 - root_mean_squared_error: 1.8818 - val_loss: 1.6081 - val_root_mean_squared_error: 1.2681
# Epoch 9/71
# 1456/1456 [==============================] - 0s 222us/sample - loss: 2.5133 - root_mean_squared_error: 1.5853 - val_loss: 5.1627 - val_root_mean_squared_error: 2.2722
# Epoch 10/71
# 1456/1456 [==============================] - 0s 208us/sample - loss: 3.7248 - root_mean_squared_error: 1.9300 - val_loss: 2.5744 - val_root_mean_squared_error: 1.6045
# Epoch 11/71
# 1456/1456 [==============================] - 0s 208us/sample - loss: 2.6775 - root_mean_squared_error: 1.6363 - val_loss: 1.3947 - val_root_mean_squared_error: 1.1810
# Epoch 12/71
# 1456/1456 [==============================] - 0s 222us/sample - loss: 1.9280 - root_mean_squared_error: 1.3885 - val_loss: 1.1893 - val_root_mean_squared_error: 1.0905
# Epoch 13/71
# 1456/1456 [==============================] - 0s 207us/sample - loss: 2.7124 - root_mean_squared_error: 1.6469 - val_loss: 1.9980 - val_root_mean_squared_error: 1.4135
# Epoch 14/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 2.8103 - root_mean_squared_error: 1.6764 - val_loss: 0.9976 - val_root_mean_squared_error: 0.9988
# Epoch 15/71
# 1456/1456 [==============================] - 0s 202us/sample - loss: 2.2720 - root_mean_squared_error: 1.5073 - val_loss: 1.2166 - val_root_mean_squared_error: 1.1030
# Epoch 16/71
# 1456/1456 [==============================] - 0s 203us/sample - loss: 1.8435 - root_mean_squared_error: 1.3578 - val_loss: 1.8781 - val_root_mean_squared_error: 1.3704
# Epoch 17/71
# 1456/1456 [==============================] - 0s 201us/sample - loss: 2.1012 - root_mean_squared_error: 1.4495 - val_loss: 1.0624 - val_root_mean_squared_error: 1.0307
# Epoch 18/71
# 1456/1456 [==============================] - 0s 199us/sample - loss: 1.8165 - root_mean_squared_error: 1.3478 - val_loss: 0.8654 - val_root_mean_squared_error: 0.9303
# Epoch 19/71
# 1456/1456 [==============================] - 0s 200us/sample - loss: 2.5216 - root_mean_squared_error: 1.5879 - val_loss: 5.2569 - val_root_mean_squared_error: 2.2928
# Epoch 20/71
# 1456/1456 [==============================] - 0s 221us/sample - loss: 2.1043 - root_mean_squared_error: 1.4506 - val_loss: 2.4076 - val_root_mean_squared_error: 1.5517
# Epoch 21/71
# 1456/1456 [==============================] - 0s 219us/sample - loss: 2.6805 - root_mean_squared_error: 1.6372 - val_loss: 4.5088 - val_root_mean_squared_error: 2.1234
# Epoch 22/71
# 1456/1456 [==============================] - 0s 219us/sample - loss: 1.9778 - root_mean_squared_error: 1.4064 - val_loss: 0.6948 - val_root_mean_squared_error: 0.8336
# Epoch 23/71
# 1456/1456 [==============================] - 0s 224us/sample - loss: 1.6224 - root_mean_squared_error: 1.2737 - val_loss: 2.3538 - val_root_mean_squared_error: 1.5342
# Epoch 24/71
# 1456/1456 [==============================] - 0s 228us/sample - loss: 2.2014 - root_mean_squared_error: 1.4837 - val_loss: 1.4406 - val_root_mean_squared_error: 1.2003
# Epoch 25/71
# 1456/1456 [==============================] - 0s 224us/sample - loss: 3.1892 - root_mean_squared_error: 1.7858 - val_loss: 5.1238 - val_root_mean_squared_error: 2.2636
# Epoch 26/71
# 1456/1456 [==============================] - 0s 214us/sample - loss: 3.0673 - root_mean_squared_error: 1.7514 - val_loss: 0.8320 - val_root_mean_squared_error: 0.9121
# Epoch 27/71
# 1456/1456 [==============================] - 0s 202us/sample - loss: 1.5178 - root_mean_squared_error: 1.2320 - val_loss: 0.6022 - val_root_mean_squared_error: 0.7760
# Epoch 28/71
# 1456/1456 [==============================] - 0s 201us/sample - loss: 2.1699 - root_mean_squared_error: 1.4730 - val_loss: 0.7706 - val_root_mean_squared_error: 0.8779
# Epoch 29/71
# 1456/1456 [==============================] - 0s 218us/sample - loss: 2.1304 - root_mean_squared_error: 1.4596 - val_loss: 1.0222 - val_root_mean_squared_error: 1.0111
# Epoch 30/71
# 1456/1456 [==============================] - 0s 215us/sample - loss: 2.0187 - root_mean_squared_error: 1.4208 - val_loss: 0.6942 - val_root_mean_squared_error: 0.8332
# Epoch 31/71
# 1456/1456 [==============================] - 0s 208us/sample - loss: 1.1433 - root_mean_squared_error: 1.0693 - val_loss: 3.5354 - val_root_mean_squared_error: 1.8803
# Epoch 32/71
# 1456/1456 [==============================] - 0s 208us/sample - loss: 1.9833 - root_mean_squared_error: 1.4083 - val_loss: 0.8947 - val_root_mean_squared_error: 0.9459
# Epoch 33/71
# 1456/1456 [==============================] - 0s 204us/sample - loss: 2.1825 - root_mean_squared_error: 1.4773 - val_loss: 1.3734 - val_root_mean_squared_error: 1.1719
# Epoch 34/71
# 1456/1456 [==============================] - 0s 208us/sample - loss: 2.1538 - root_mean_squared_error: 1.4676 - val_loss: 0.4181 - val_root_mean_squared_error: 0.6466
# Epoch 35/71
# 1456/1456 [==============================] - 0s 209us/sample - loss: 8.2796 - root_mean_squared_error: 2.8774 - val_loss: 0.6183 - val_root_mean_squared_error: 0.7863
# Epoch 36/71
# 1456/1456 [==============================] - 0s 213us/sample - loss: 2.0634 - root_mean_squared_error: 1.4365 - val_loss: 0.6824 - val_root_mean_squared_error: 0.8261
# Epoch 37/71
# 1456/1456 [==============================] - 0s 222us/sample - loss: 1.6683 - root_mean_squared_error: 1.2916 - val_loss: 0.6165 - val_root_mean_squared_error: 0.7852
# Epoch 38/71
# 1456/1456 [==============================] - 0s 230us/sample - loss: 1.2998 - root_mean_squared_error: 1.1401 - val_loss: 0.4378 - val_root_mean_squared_error: 0.6617
# Epoch 39/71
# 1456/1456 [==============================] - 0s 209us/sample - loss: 0.6827 - root_mean_squared_error: 0.8263 - val_loss: 0.4971 - val_root_mean_squared_error: 0.7050
# Epoch 40/71
# 1456/1456 [==============================] - 0s 203us/sample - loss: 0.8455 - root_mean_squared_error: 0.9195 - val_loss: 2.2216 - val_root_mean_squared_error: 1.4905
# Epoch 41/71
# 1456/1456 [==============================] - 0s 203us/sample - loss: 1.3478 - root_mean_squared_error: 1.1609 - val_loss: 2.3291 - val_root_mean_squared_error: 1.5261
# Epoch 42/71
# 1456/1456 [==============================] - 0s 204us/sample - loss: 0.7741 - root_mean_squared_error: 0.8798 - val_loss: 0.3010 - val_root_mean_squared_error: 0.5486
# Epoch 43/71
# 1456/1456 [==============================] - 0s 217us/sample - loss: 0.7906 - root_mean_squared_error: 0.8892 - val_loss: 2.1746 - val_root_mean_squared_error: 1.4747
# Epoch 44/71
# 1456/1456 [==============================] - 0s 211us/sample - loss: 2.2644 - root_mean_squared_error: 1.5048 - val_loss: 1.3949 - val_root_mean_squared_error: 1.1810
# Epoch 45/71
# 1456/1456 [==============================] - 0s 201us/sample - loss: 1.4835 - root_mean_squared_error: 1.2180 - val_loss: 0.2848 - val_root_mean_squared_error: 0.5336
# Epoch 46/71
# 1456/1456 [==============================] - 0s 201us/sample - loss: 0.7001 - root_mean_squared_error: 0.8367 - val_loss: 0.5231 - val_root_mean_squared_error: 0.7232
# Epoch 47/71
# 1456/1456 [==============================] - 0s 221us/sample - loss: 0.6368 - root_mean_squared_error: 0.7980 - val_loss: 0.7305 - val_root_mean_squared_error: 0.8547
# Epoch 48/71
# 1456/1456 [==============================] - 0s 209us/sample - loss: 0.4948 - root_mean_squared_error: 0.7034 - val_loss: 0.2208 - val_root_mean_squared_error: 0.4699
# Epoch 49/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 0.9021 - root_mean_squared_error: 0.9498 - val_loss: 2.0451 - val_root_mean_squared_error: 1.4301
# Epoch 50/71
# 1456/1456 [==============================] - 0s 198us/sample - loss: 0.6936 - root_mean_squared_error: 0.8328 - val_loss: 0.3291 - val_root_mean_squared_error: 0.5737
# Epoch 51/71
# 1456/1456 [==============================] - 0s 200us/sample - loss: 0.8236 - root_mean_squared_error: 0.9075 - val_loss: 0.2331 - val_root_mean_squared_error: 0.4828
# Epoch 52/71
# 1456/1456 [==============================] - 0s 199us/sample - loss: 0.6089 - root_mean_squared_error: 0.7803 - val_loss: 0.2341 - val_root_mean_squared_error: 0.4839
# Epoch 53/71
# 1456/1456 [==============================] - 0s 199us/sample - loss: 0.4653 - root_mean_squared_error: 0.6822 - val_loss: 1.5814 - val_root_mean_squared_error: 1.2575
# Epoch 54/71
# 1456/1456 [==============================] - 0s 200us/sample - loss: 1.1561 - root_mean_squared_error: 1.0752 - val_loss: 2.6696 - val_root_mean_squared_error: 1.6339
# Epoch 55/71
# 1456/1456 [==============================] - 0s 211us/sample - loss: 1.1014 - root_mean_squared_error: 1.0495 - val_loss: 0.2126 - val_root_mean_squared_error: 0.4611
# Epoch 56/71
# 1456/1456 [==============================] - 0s 230us/sample - loss: 0.7116 - root_mean_squared_error: 0.8435 - val_loss: 0.9038 - val_root_mean_squared_error: 0.9507
# Epoch 57/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 0.9092 - root_mean_squared_error: 0.9535 - val_loss: 1.3128 - val_root_mean_squared_error: 1.1458
# Epoch 58/71
# 1456/1456 [==============================] - 0s 204us/sample - loss: 0.6142 - root_mean_squared_error: 0.7837 - val_loss: 0.3470 - val_root_mean_squared_error: 0.5891
# Epoch 59/71
# 1456/1456 [==============================] - 0s 200us/sample - loss: 0.3336 - root_mean_squared_error: 0.5776 - val_loss: 0.1442 - val_root_mean_squared_error: 0.3798
# Epoch 60/71
# 1456/1456 [==============================] - 0s 201us/sample - loss: 1.0079 - root_mean_squared_error: 1.0039 - val_loss: 1.1508 - val_root_mean_squared_error: 1.0728
# Epoch 61/71
# 1456/1456 [==============================] - 0s 220us/sample - loss: 0.4261 - root_mean_squared_error: 0.6528 - val_loss: 1.3229 - val_root_mean_squared_error: 1.1502
# Epoch 62/71
# 1456/1456 [==============================] - 0s 225us/sample - loss: 0.6438 - root_mean_squared_error: 0.8024 - val_loss: 0.3733 - val_root_mean_squared_error: 0.6110
# Epoch 63/71
# 1456/1456 [==============================] - 0s 210us/sample - loss: 0.7491 - root_mean_squared_error: 0.8655 - val_loss: 0.9307 - val_root_mean_squared_error: 0.9647
# Epoch 64/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 0.6613 - root_mean_squared_error: 0.8132 - val_loss: 2.0064 - val_root_mean_squared_error: 1.4165
# Epoch 65/71
# 1456/1456 [==============================] - 0s 221us/sample - loss: 0.6544 - root_mean_squared_error: 0.8090 - val_loss: 1.0426 - val_root_mean_squared_error: 1.0211
# Epoch 66/71
# 1456/1456 [==============================] - 0s 211us/sample - loss: 0.5564 - root_mean_squared_error: 0.7459 - val_loss: 0.7939 - val_root_mean_squared_error: 0.8910
# Epoch 67/71
# 1456/1456 [==============================] - 0s 203us/sample - loss: 0.3800 - root_mean_squared_error: 0.6164 - val_loss: 1.4580 - val_root_mean_squared_error: 1.2075
# Epoch 68/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 0.5417 - root_mean_squared_error: 0.7360 - val_loss: 0.6045 - val_root_mean_squared_error: 0.7775
# Epoch 69/71
# 1456/1456 [==============================] - 0s 206us/sample - loss: 0.3589 - root_mean_squared_error: 0.5991 - val_loss: 0.3911 - val_root_mean_squared_error: 0.6254
# Epoch 70/71
# 1456/1456 [==============================] - 0s 211us/sample - loss: 0.2841 - root_mean_squared_error: 0.5330 - val_loss: 0.1279 - val_root_mean_squared_error: 0.3576
# Epoch 71/71
# 1456/1456 [==============================] - 0s 205us/sample - loss: 0.4203 - root_mean_squared_error: 0.6483 - val_loss: 0.5144 - val_root_mean_squared_error: 0.7172
# =================================================================================================
# Wall time: 1h 3min 16s

# %%
optimizer.max
# Out:
# {'target': -0.15620353348073138,
#  'params': {'batch_size': 3.6673518333094415,
#   'epochs': 73.96202978169758,
#   'hidden1': 570.1116853013305,
#   'hidden2': 595.2392363579096,
#   'hidden3': 697.0136267238864,
#   'n_steps': 204.6161307834657}}

# %% [markdown]
# Efectivamente, con la búsqueda local realizada en el paso anterior, disminuimos el rmse de **0.65** a **0.15**.
#
# Según los datos obtenidos, nos quedamos con el modelo entrenado con una red neuronal estándar, dado que es el que mejor se comporta con los datos no vistos durante en entrenamiento.

# %%
hiperpNN = optimizer.max

# %% [markdown]
# Procedemos a construir el modelo con los mejores hiperparámetros encontrados y analizar detalladamente su rendimiento.

# %%
hiperpNN
# Out:
# {'target': -0.15620353348073138,
#  'params': {'batch_size': 3.6673518333094415,
#   'epochs': 73.96202978169758,
#   'hidden1': 570.1116853013305,
#   'hidden2': 595.2392363579096,
#   'hidden3': 697.0136267238864,
#   'n_steps': 204.6161307834657}}

# %%
meses_pronosticados = fechas[205:]

meses_train = meses_pronosticados[:periodos_train]
meses_test = meses_pronosticados[periodos_train:]

meses_train = meses_pronosticados[:periodos_train]
meses_test = meses_pronosticados[periodos_train:]

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(1234)
np.random.seed(1234) 
    
# Generamos los datos con la mejor ventana encontrada. 
data = corteTransversal(205)
# Split
X_train, y_train, X_test, y_test = splitData(data)
    
#Pretratamiento de los datos
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.fit_transform(X_test)

# build graph
modelNN = models.Sequential()
modelNN.add(layers.Dense(units = 570, activation = 'relu', input_shape = (len(data.columns)-1,)))
modelNN.add(layers.Dense(units = 595, activation = 'relu'))
modelNN.add(layers.Dense(units = 697, activation = 'relu'))
modelNN.add(layers.Dense(units = 1, activation = 'linear'))
modelNN.compile(optimizer = 'adam', loss = 'mse', metrics = [tf.keras.metrics.RootMeanSquaredError()])

#fit
history = modelNN.fit(X_train, y_train, epochs = 74, batch_size = 4, validation_split=0.1, verbose = 2)
# Out:
# Train on 1431 samples, validate on 159 samples
# Epoch 1/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 2414.6512 - root_mean_squared_error: 49.1391 - val_loss: 3.9620 - val_root_mean_squared_error: 1.9905
# Epoch 2/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 5.3818 - root_mean_squared_error: 2.3199 - val_loss: 4.8621 - val_root_mean_squared_error: 2.2050
# Epoch 3/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 4.2347 - root_mean_squared_error: 2.0578 - val_loss: 1.5831 - val_root_mean_squared_error: 1.2582
# Epoch 4/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 3.9901 - root_mean_squared_error: 1.9975 - val_loss: 3.1636 - val_root_mean_squared_error: 1.7787
# Epoch 5/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 3.4023 - root_mean_squared_error: 1.8445 - val_loss: 1.0339 - val_root_mean_squared_error: 1.0168
# Epoch 6/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 3.6758 - root_mean_squared_error: 1.9172 - val_loss: 0.8847 - val_root_mean_squared_error: 0.9406
# Epoch 7/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 3.0079 - root_mean_squared_error: 1.7343 - val_loss: 0.9600 - val_root_mean_squared_error: 0.9798
# Epoch 8/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.9800 - root_mean_squared_error: 1.4071 - val_loss: 0.7223 - val_root_mean_squared_error: 0.8499
# Epoch 9/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 2.3443 - root_mean_squared_error: 1.5311 - val_loss: 3.9285 - val_root_mean_squared_error: 1.9820
# Epoch 10/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 2.2137 - root_mean_squared_error: 1.4879 - val_loss: 2.3381 - val_root_mean_squared_error: 1.5291
# Epoch 11/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 2.3097 - root_mean_squared_error: 1.5198 - val_loss: 0.5751 - val_root_mean_squared_error: 0.7583
# Epoch 12/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 1.2092 - root_mean_squared_error: 1.0996 - val_loss: 0.7319 - val_root_mean_squared_error: 0.8555
# Epoch 13/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.6473 - root_mean_squared_error: 1.2835 - val_loss: 4.8988 - val_root_mean_squared_error: 2.2133
# Epoch 14/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.2189 - root_mean_squared_error: 1.1041 - val_loss: 0.7300 - val_root_mean_squared_error: 0.8544
# Epoch 15/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.5954 - root_mean_squared_error: 1.2631 - val_loss: 0.3813 - val_root_mean_squared_error: 0.6175
# Epoch 16/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.0256 - root_mean_squared_error: 1.0127 - val_loss: 0.5319 - val_root_mean_squared_error: 0.7293
# Epoch 17/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 3.4076 - root_mean_squared_error: 1.8460 - val_loss: 6.5145 - val_root_mean_squared_error: 2.5523
# Epoch 18/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.6437 - root_mean_squared_error: 1.2821 - val_loss: 1.0772 - val_root_mean_squared_error: 1.0379
# Epoch 19/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.5321 - root_mean_squared_error: 1.2378 - val_loss: 1.0575 - val_root_mean_squared_error: 1.0283
# Epoch 20/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.3315 - root_mean_squared_error: 1.1539 - val_loss: 1.4416 - val_root_mean_squared_error: 1.2006
# Epoch 21/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.2165 - root_mean_squared_error: 1.1029 - val_loss: 0.3450 - val_root_mean_squared_error: 0.5874
# Epoch 22/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.9474 - root_mean_squared_error: 0.9734 - val_loss: 0.4532 - val_root_mean_squared_error: 0.6732
# Epoch 23/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.9920 - root_mean_squared_error: 0.9960 - val_loss: 1.5118 - val_root_mean_squared_error: 1.2296
# Epoch 24/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.6458 - root_mean_squared_error: 1.2829 - val_loss: 1.2315 - val_root_mean_squared_error: 1.1097
# Epoch 25/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 0.9164 - root_mean_squared_error: 0.9573 - val_loss: 1.0821 - val_root_mean_squared_error: 1.0403
# Epoch 26/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.3877 - root_mean_squared_error: 1.1780 - val_loss: 74.0483 - val_root_mean_squared_error: 8.6051
# Epoch 27/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 55.6083 - root_mean_squared_error: 7.4571 - val_loss: 1.2523 - val_root_mean_squared_error: 1.1191
# Epoch 28/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.3650 - root_mean_squared_error: 1.1683 - val_loss: 4.7161 - val_root_mean_squared_error: 2.1717
# Epoch 29/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 1.1743 - root_mean_squared_error: 1.0837 - val_loss: 0.2969 - val_root_mean_squared_error: 0.5449
# Epoch 30/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.7310 - root_mean_squared_error: 0.8550 - val_loss: 0.5375 - val_root_mean_squared_error: 0.7332
# Epoch 31/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.6688 - root_mean_squared_error: 0.8178 - val_loss: 0.5576 - val_root_mean_squared_error: 0.7467
# Epoch 32/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.7549 - root_mean_squared_error: 0.8688 - val_loss: 0.3928 - val_root_mean_squared_error: 0.6267
# Epoch 33/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.5601 - root_mean_squared_error: 0.7484 - val_loss: 0.8229 - val_root_mean_squared_error: 0.9071
# Epoch 34/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 0.4251 - root_mean_squared_error: 0.6520 - val_loss: 0.2948 - val_root_mean_squared_error: 0.5429
# Epoch 35/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.6666 - root_mean_squared_error: 0.8164 - val_loss: 0.4962 - val_root_mean_squared_error: 0.7044
# Epoch 36/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2762 - root_mean_squared_error: 0.5255 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3827
# Epoch 37/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.7733 - root_mean_squared_error: 0.8794 - val_loss: 0.8888 - val_root_mean_squared_error: 0.9427
# Epoch 38/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.5971 - root_mean_squared_error: 0.7727 - val_loss: 0.1221 - val_root_mean_squared_error: 0.3494
# Epoch 39/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.3777 - root_mean_squared_error: 0.6146 - val_loss: 0.1186 - val_root_mean_squared_error: 0.3444
# Epoch 40/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2974 - root_mean_squared_error: 0.5454 - val_loss: 0.3969 - val_root_mean_squared_error: 0.6300
# Epoch 41/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 0.5540 - root_mean_squared_error: 0.7443 - val_loss: 0.2220 - val_root_mean_squared_error: 0.4711
# Epoch 42/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2686 - root_mean_squared_error: 0.5183 - val_loss: 0.6832 - val_root_mean_squared_error: 0.8265
# Epoch 43/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 0.2570 - root_mean_squared_error: 0.5070 - val_loss: 0.5420 - val_root_mean_squared_error: 0.7362
# Epoch 44/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2181 - root_mean_squared_error: 0.4670 - val_loss: 0.1564 - val_root_mean_squared_error: 0.3955
# Epoch 45/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2879 - root_mean_squared_error: 0.5366 - val_loss: 0.2598 - val_root_mean_squared_error: 0.5097
# Epoch 46/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2947 - root_mean_squared_error: 0.5429 - val_loss: 0.0865 - val_root_mean_squared_error: 0.2942
# Epoch 47/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2246 - root_mean_squared_error: 0.4739 - val_loss: 0.1432 - val_root_mean_squared_error: 0.3784
# Epoch 48/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.2582 - root_mean_squared_error: 0.5082 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2387
# Epoch 49/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1282 - root_mean_squared_error: 0.3581 - val_loss: 0.4406 - val_root_mean_squared_error: 0.6638
# Epoch 50/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.3069 - root_mean_squared_error: 0.5540 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3709
# Epoch 51/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1512 - root_mean_squared_error: 0.3889 - val_loss: 0.8007 - val_root_mean_squared_error: 0.8948
# Epoch 52/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1748 - root_mean_squared_error: 0.4181 - val_loss: 0.2999 - val_root_mean_squared_error: 0.5476
# Epoch 53/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1849 - root_mean_squared_error: 0.4300 - val_loss: 0.1239 - val_root_mean_squared_error: 0.3519
# Epoch 54/74
# 1431/1431 [==============================] - 2s 2ms/sample - loss: 0.1117 - root_mean_squared_error: 0.3342 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2169
# Epoch 55/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1137 - root_mean_squared_error: 0.3372 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1756
# Epoch 56/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1838 - root_mean_squared_error: 0.4287 - val_loss: 0.2762 - val_root_mean_squared_error: 0.5256
# Epoch 57/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1440 - root_mean_squared_error: 0.3794 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1834
# Epoch 58/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1325 - root_mean_squared_error: 0.3639 - val_loss: 0.0897 - val_root_mean_squared_error: 0.2995
# Epoch 59/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1293 - root_mean_squared_error: 0.3596 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2186
# Epoch 60/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1580 - root_mean_squared_error: 0.3976 - val_loss: 0.3625 - val_root_mean_squared_error: 0.6021
# Epoch 61/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0910 - root_mean_squared_error: 0.3016 - val_loss: 0.0824 - val_root_mean_squared_error: 0.2870
# Epoch 62/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1015 - root_mean_squared_error: 0.3186 - val_loss: 0.3753 - val_root_mean_squared_error: 0.6126
# Epoch 63/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0934 - root_mean_squared_error: 0.3056 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1803
# Epoch 64/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0721 - root_mean_squared_error: 0.2685 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 65/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.4441 - val_root_mean_squared_error: 0.6664
# Epoch 66/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0733 - root_mean_squared_error: 0.2708 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1855
# Epoch 67/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1573 - root_mean_squared_error: 0.3966 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1599
# Epoch 68/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0709 - root_mean_squared_error: 0.2664 - val_loss: 0.0353 - val_root_mean_squared_error: 0.1878
# Epoch 69/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0930 - root_mean_squared_error: 0.3049 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
# Epoch 70/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0782 - root_mean_squared_error: 0.2796 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3898
# Epoch 71/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0807 - root_mean_squared_error: 0.2841 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 72/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0779 - root_mean_squared_error: 0.2790 - val_loss: 0.2320 - val_root_mean_squared_error: 0.4816
# Epoch 73/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.0747 - root_mean_squared_error: 0.2732 - val_loss: 0.1951 - val_root_mean_squared_error: 0.4417
# Epoch 74/74
# 1431/1431 [==============================] - 3s 2ms/sample - loss: 0.1206 - root_mean_squared_error: 0.3473 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1775

# %% [markdown]
# Realizamos el pronóstico de los valores de test y de train para conocer si tenemos sobreajuste en nuestro modelo

# %%
y_test_pred = modelNN.predict(X_test)
y_train_pred = modelNN.predict(X_train)

# %%
print("MSE (train): {:.4f}".format(mean_squared_error(y_train, y_train_pred)))
print("MSE (test) : {:.4f}".format(mean_squared_error(y_test, y_test_pred)))

print("R2  (train): {:.4f}".format(r2_score(y_train, y_train_pred)))
print("R2  (test) : {:.4f}".format(r2_score(y_test, y_test_pred)))

print("R2 adj (train): {:.4f}".format(r2adj(y_train, y_train_pred, X_train.shape[1])))
print("R2 adj (test): {:.4f}".format(r2adj(y_test, y_test_pred, X_test.shape[1])))
# Out:
# MSE (train): 0.0273
# MSE (test) : 0.0244
# R2  (train): 0.9982
# R2  (test) : 0.9984
# R2 adj (train): 0.9981
# R2 adj (test): 0.9982

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])

# %% [markdown]
# Graficamos el RMSE y el LOSS de train y test

# %%
fig, axs = plt.subplots(figsize=[15, 5], ncols=2, nrows=1)

axs[0].plot(history.history['root_mean_squared_error'])
axs[0].plot(history.history['val_root_mean_squared_error'])
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('RMSE')
axs[0].set_title('RMSE de train y de test')
axs[0].legend(['train', 'test'], loc='upper left')


axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('LOSS')
axs[1].set_title('LOSS de train y de test')
axs[1].legend(['train', 'test'], loc='upper left')


plt.show()

# %% [markdown]
# Graficamos el pronóstico

# %%
fig, axs = plt.subplots(figsize=[15, 5], ncols=2, nrows=1)

axs[0].plot(meses_train, y_train, label="training")
axs[0].plot(meses_test, y_test, c="g", label="test real")
axs[0].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Temperatura')
axs[0].set_title('Pronóstico de la temperatura')
axs[0].legend()
axs[0].set_xticks(np.arange(0,2193,720))


axs[1].plot(meses_test, y_test, c="g", label="test real")
axs[1].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[1].set_xlabel('Anio')
axs[1].set_ylabel('Temperatura')
axs[1].set_title('Pronóstico de la temperatura')
axs[1].legend()
axs[1].set_xticks(np.arange(0,120,24))

plt.show()

# %%
print(history.history.keys())

# %%
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
periodos_test = round(len(data) * 0.2)
periodos_train = len(data) - periodos_test

meses_pronosticados = fechas[151:,]
meses_train = meses_pronosticados[:periodos_train]
meses_test = meses_pronosticados[periodos_train:]

# %%
fig, axs = plt.subplots(figsize=[15, 5], ncols=2, nrows=1)

axs[0].plot(meses_train, y_train, label="training")
axs[0].plot(meses_test, y_test, c="g", label="test real")
axs[0].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[0].set_xlabel('Anio')
axs[0].set_ylabel('Temperatura')
axs[0].set_title('Evolución de la temperatura..')
axs[0].legend()
axs[0].set_xticks(np.arange(0,2193,720))


axs[1].plot(meses_test, y_test, c="g", label="test real")
axs[1].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[1].set_xlabel('Anio')
axs[1].set_ylabel('Temperatura')
axs[1].set_title('Evolución de la temperatura..')
axs[1].legend()
axs[1].set_xticks(np.arange(0,120,24))

plt.show()

# %% [markdown]
# # Parte 2: Modelos convolucionales

# %% [markdown]
# # CNN

# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow.keras as keras
print(keras.__version__)
from tensorflow.keras import models, layers

from bayes_opt import BayesianOptimization

# %% [markdown]
# ## Tensores

# %%
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        end_ix = i + n_steps
        if end_ix > len(sequences)-1:
            break
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, 7]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
def standarize(df):
    scaler = StandardScaler()
    n0, n1, n2 = df.shape[0], df.shape[1], df.shape[2]
    df = scaler.fit_transform(df.reshape(n0, n1 * n2))
    df = df.reshape(n0, n1, n2)
    return df

# %%
#n_steps = 100

# %%
#X, y = split_sequences(df_ori.to_numpy(), n_steps)

# %%
#meses_pronosticados = fechas[n_steps:,]
#meses_pronosticados

# %% [markdown]
# ## Split

# %%
#periodos_test = round(len(X) * 0.1) #10% de los datos para test
#periodos_train = X.shape[0] - periodos_test
#print('Periodos train {} -- Periodos test {}'.format(periodos_train, periodos_test))

# %%
#X_train = X[:periodos_train]
#X_test = X[periodos_train:]
#y_train = y[:periodos_train]
#y_test = y[periodos_train:]
#meses_train = meses_pronosticados[:periodos_train]
#meses_test = meses_pronosticados[periodos_train:]
#print("X_train: {}, y_train: {}\nX_test: {}, y_test: {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))

# %%
#np.random.seed(12345)
#X_train, y_train = shuffle(X_train, y_train, random_state=0)

# %%
#X_train = standarize(X_train)
#X_test = standarize(X_test)

#print(X_train.shape)
#print(X_test.shape)

# %%
def preprocessData(data, n_steps):
    np.random.seed(1234)

    # Generate sequences
    X, y = split_sequences(data.to_numpy(), n_steps)
    
    # % Train / Test
    periodos_test = round(len(X) * 0.1) #10% de los datos para test
    periodos_train = X.shape[0] - periodos_test
    
    #Split train / test
    X_train = X[:periodos_train]
    X_test = X[periodos_train:]
    y_train = y[:periodos_train]
    y_test = y[periodos_train:]
    
    # Shuffle
    X_train, y_train = shuffle(X_train, y_train, random_state=0)
    
    return X_train, y_train, X_test, y_test

# %%
model = models.Sequential()
model.add(layers.Conv1D(filters = 32, 
                            kernel_size = 9, 
                            activation='relu', 
                            input_shape=(100, 20),
                            kernel_regularizer=keras.regularizers.l2(0.01)
                           ))
    
model.add(layers.MaxPooling1D(pool_size = 2))
model.add(layers.Conv1D(filters = 64, kernel_size = 9, activation='relu'))
model.add(layers.MaxPooling1D(pool_size = 2))
    #model.add(layers.Conv1D(filters = 128, kernel_size = kernel_s_3, activation='relu'))
    #model.add(layers.MaxPooling1D(pool_size = 2))

model.add(layers.Flatten())
model.add(layers.Dense(units = 100, activation = 'relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(units = 100, activation = 'relu'))
model.add(layers.Dense(units = 1, activation = 'linear'))

model.summary()

# %% [markdown]
# Para entrenar esta red y buscar los mejores hiperparámetros con optimización bayesiana, tuvimos que tener en cuenta un rango para la ventana que va desde 40 a n.
#
# No buscamos el learning rate porque llegábamos a lo que se conoce como desvanecimiento del gradiente incluso usando Adam.

# %%
def buildModelCNN(epochs, 
                  batch_size, 
                  hidden_1, 
                  hidden_2, 
                  kernel_s_1, 
                  kernel_s_2,
                  kernel_s_3, 
                  n_steps, 
                  dropout_1, 
                  dropout_2, 
                  regularizer_1,
                  regularizer_2
                  ):
    
    #capa_regularizada = layers.Dense(n1, activation='tanh', input_shape=(n0,), kernel_regularizer=regularizers.l2(0.01))
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(1234)
    np.random.seed(1234)
    
    epochs = int(round(epochs))
    batch_size = int(round(batch_size))
    hidden_1 = int(round(hidden_1))
    hidden_2 = int(round(hidden_2))
    kernel_s_1 = int(round(kernel_s_1))
    kernel_s_2 = int(round(kernel_s_2))
    kernel_s_3 = int(round(kernel_s_3))
    n_steps = int(round(n_steps))
    
    # Serie de tiempo - Split - Shuffle    
    X_train, y_train, X_test, y_test = preprocessData(df_ori, n_steps) # df original
    
    # Standarize
    X_train = standarize(X_train)
    X_test = standarize(X_test)
    
    # build graph
    model = models.Sequential()
    model.add(layers.Conv1D(filters = 32, 
                            kernel_size = kernel_s_1, 
                            activation='relu', 
                            input_shape=(n_steps, len(df_ori.columns)),
                            kernel_regularizer=keras.regularizers.l2(regularizer_1)
                           ))
    
    model.add(layers.MaxPooling1D(pool_size = 2))
    
    model.add(layers.Conv1D(filters = 64, 
                            kernel_size = kernel_s_2, 
                            activation='relu', 
                            kernel_regularizer = keras.regularizers.l2(regularizer_2)
                           ))
    model.add(layers.MaxPooling1D(pool_size = 2))
    
    model.add(layers.Conv1D(filters = 128, 
                            kernel_size = kernel_s_3, 
                            activation='relu'))
    model.add(layers.MaxPooling1D(pool_size = 1)) # tamaño 1 para evitar problemas

    model.add(layers.Flatten())
    model.add(layers.Dropout(dropout_1))
    model.add(layers.Dense(units = hidden_1, activation = 'relu'))
    model.add(layers.Dropout(dropout_2))
    model.add(layers.Dense(units = hidden_2, activation = 'relu'))
    model.add(layers.Dense(units = 1, activation = 'linear'))
        
    #optimizerTf = keras.optimizers.Adam(learning_rate = learning_rate)
    optimizerTf = keras.optimizers.Adam()
    
    model.compile(optimizer = optimizerTf, loss=tf.keras.losses.MeanSquaredError(), metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
    history = model.fit(X_train, y_train, epochs = epochs, batch_size = batch_size, validation_split=0.1, verbose = 1)
    y_pred = model.predict(X_test)
    
    #print("RMSE:", sqrt(mean_squared_error(y_test, y_pred)), 
    #  ", MAE:", mean_absolute_error(y_test, y_pred), 
    #  ", R2:", r2_score(y_test, y_pred), "\n")
    rmse = sqrt(mean_squared_error(y_test, y_pred))    
    print('RMSE {}'.format(rmse))
    return -rmse


pbounds = {'epochs': (1, 100), 
           'batch_size' : (32,  len(df_ori)),
           'hidden_1': (10, 1000), 
           'hidden_2': (10, 1000),
           'kernel_s_1': (1, 9), 
           'kernel_s_2': (1, 9),
           'kernel_s_3': (1, 9),
           'n_steps': (40, 1000), #40 valor mínimo para evitar errores en el maxxpooling
           'dropout_1' : (0, 0.5),
           'dropout_2' : (0, 0.5),
           'regularizer_1': (0, 1),
           'regularizer_2': (0, 1),
           #'learning_rate': (0.01, 1), # no lo usamos por el desvanecimiento 
          }

optimizer = BayesianOptimization(
    f = buildModelCNN,
    pbounds = pbounds,
    random_state = 1,
    verbose = 2
)

# %%
# %%time
optimizer.maximize(
    init_points=5,
    n_iter=15,
)

# %%
optimizer.max

# %%
'''
{'target': -6.1947740742622655,
 'params': {'batch_size': 32.0,
  'epochs': 1.0,
  'hidden_1': 1000.0,
  'hidden_2': 682.3472723671795,
  'kernel_s_1': 9.0,
  'kernel_s_2': 9.0,
  'kernel_s_3': 9.0,
  'n_steps': 200.0}}
  ////
  {'target': -3.706167948127196,
 'params': {'batch_size': 128.0,
  'dropout': 0.0,
  'epochs': 1.0,
  'hidden_1': 357.05674214234017,
  'hidden_2': 559.4264802945545,
  'kernel_s_1': 1.0,
  'kernel_s_2': 1.0,
  'n_steps': 881.6736914907946,
  'regularizer': 0.0}}
  ----
  {'target': -3.9908294542555884,
 'params': {'batch_size': 1065.6936906898534,
  'dropout_1': 0.33066533472517295,
  'dropout_2': 0.0,
  'epochs': 23.102938188619206,
  'hidden_1': 313.9208377123251,
  'hidden_2': 99.96832622620352,
  'kernel_s_1': 4.755961312504796,
  'kernel_s_2': 5.265856732819483,
  'n_steps': 749.4381641669852,
  'regularizer_1': 0.40609005431829676,
  'regularizer_2': 0.21138309663922197}}
'''

# %%
model = models.Sequential()
model.add(layers.Conv1D(filters = 32, kernel_size = 8, activation='relu', input_shape=(100, 20)))
model.add(layers.MaxPooling1D(pool_size = 2))
model.add(layers.Conv1D(filters = 64, kernel_size = 7, activation='relu'))
model.add(layers.MaxPooling1D(pool_size = 2))
model.add(layers.Conv1D(filters = 128, kernel_size = 9, activation='relu'))
model.add(layers.MaxPooling1D(pool_size = 2))

model.add(layers.Flatten())

model.add(layers.Dense(units = 819, activation = 'relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(units = 480, activation = 'relu'))
model.add(layers.Dense(units = 1, activation = 'linear'))
        
model.compile(optimizer = keras.optimizers.Adam(), loss='mean_squared_error', metrics=[tf.keras.metrics.MeanSquaredError()])
    
history = model.fit(X_train, y_train, epochs = 58, batch_size = 73, validation_split=0.1, verbose = 1)

y_pred = model.predict(X_test)

# %%
print("RMSE:", sqrt(mean_squared_error(y_test, y_pred)), 
      ", MAE:", mean_absolute_error(y_test, y_pred), 
      ", R2:", r2_score(y_test, y_pred), "\n")

# %%
#x_pred = model.predict(X_train)
#train_loss, train_rmse = model.evaluate(X_train, x_pred)

#testMse = mean_squared_error(y_test, y_pred)
#trainMse = mean_squared_error(y_train, x_pred)
history.history.keys()

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('model mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
test_loss, test_rmse = model.evaluate(X_test, y_test)

# %%
fig, axs = plt.subplots(figsize=[15, 5], ncols=2, nrows=1)

axs[0].plot(meses_train, y_train, label="training")
axs[0].plot(meses_test, y_test, c="g", label="test real")
axs[0].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Temperatura')
axs[0].set_title('Pronóstico de la temperatura')
axs[0].legend()
axs[0].set_xticks(np.arange(0,X.shape[0],720))


axs[1].plot(meses_test, y_test, c="g", label="test real")
axs[1].plot(meses_test, y_pred, c="r", label="test pronóstico")
axs[1].set_xlabel('Anio')
axs[1].set_ylabel('Temperatura')
axs[1].set_title('Pronóstico de la temperatura')
axs[1].legend()
axs[1].set_xticks(np.arange(0,len(X_test),48))

plt.show()

# %% [markdown]
# El mejor modelo es X, con ventana W.
